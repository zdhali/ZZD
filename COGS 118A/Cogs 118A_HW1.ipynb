# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import matplotlib.image as mpimg
from sklearn import datasets
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from random import *

# %% [markdown]
# Zafrin Dhali
# A121222669
# Cogs 118A
# HW 1
#
# 1 On Previous Sheet
#
# 2 One Hot Encoding Problem
#
# Samples= x1,x2,x3,x4,x5 (5)
#
# Features = Length, Height, Toyota, BMW, Ford, Blue, Silver, Red, Black (9)

# %%
S=[[183,62,1,0,0,1,0,0,0],
  [181,65,0,1,0,0,1,0,0],
  [182,59,0,1,0,0,0,0,1,0],
  [179,68,0,0,1,1,0,0,0,0],
   [182,53,1,0,0,0,0,0,0,1]]
print ("#2 S:")
S
# Out:
# #2 S:
# [[183, 62, 1, 0, 0, 1, 0, 0, 0],
#  [181, 65, 0, 1, 0, 0, 1, 0, 0],
#  [182, 59, 0, 1, 0, 0, 0, 0, 1, 0],
#  [179, 68, 0, 0, 1, 1, 0, 0, 0, 0],
#  [182, 53, 1, 0, 0, 0, 0, 0, 0, 1]]

# %% [markdown]
# 3 Basic Matrix Operations Using NumPy
#
# A =
# [1 2
# 3 4
# 5 6]
#
# B =
# [1 −1
# −1 1
# 1 −1]

# %%
A=np.array([[1,2],[3,4],[5,6]])
B=np.array([[1,-1],[-1,1],[1,-1]])

# %%
#A+B
print ("Element sum:",np.add(A, B))

# A * B (Element-wise product)
print ("Element product:",np.multiply(A, B))

#TRANSPOSE
At=np.transpose(A)
Bt=np.transpose(B)

#Dimensions
Ashape=A.shape
Bshape=B.shape
Atshape=At.shape
Btshape=Bt.shape
#A^TB
print ('A^T *B')
print ("Dimensions of At x B", Atshape, Bshape)
print (np.dot(At, B))

#AB^T
print('AB^T')
print ("Shape of A:", A.shape)
print ("Shape of Bt:", Bt.shape)
print ('AB^T=', np.dot(A , Bt))

#AB
print('AB')
#print (np.dot(A,B))
print ("Dimensions of A x B", Ashape, Bshape)
print ('Impossible: matrix multiplication between A and B is not possible due to the dimensions')
# Out:
# Element sum: [[2 1]
#  [2 5]
#  [6 5]]
# Element product: [[ 1 -2]
#  [-3  4]
#  [ 5 -6]]
# A^T *B
# Dimensions of At x B (2, 3) (3, 2)
# [[ 3 -3]
#  [ 4 -4]]
# AB^T
# Shape of A: (3, 2)
# Shape of Bt: (2, 3)
# AB^T= [[-1  1 -1]
#  [-1  1 -1]
#  [-1  1 -1]]
# AB
# Dimensions of A x B (3, 2) (3, 2)
# Impossible: matrix multiplication between A and B is not possible due to the dimensions

# %% [markdown]
# 4 Basic Plots Using Matplotlib

# %%
np.random.seed(0)
space = np.linspace(0,10, num=50)
sine = np.sin(space)
sine_5=sine
for i in range(5):
    sine_5= sine_5+ np.random.normal(scale =0.1, size=50)
plt.scatter(space,sine,color ='b', label='sine_curve')
plt.plot(space, sine_5, color= 'r', label='noise_5_iters')
plt.legend(loc='upper right')
plt.title('Original Curve: 20 Iterations')
plt.savefig('./Q4.png')
plt.show()

# %%
np.random.seed(0)
space = np.linspace(0,10, num=50)
sine = np.sin(space)
sine_5=sine
for i in range(5):
    sine_5= sine_5+ np.random.normal(scale =0.1, size=50)
plt.scatter(space,sine,color ='b', label='sine_curve')
plt.plot(space, sine_5, color= 'r', label='noise_5_iters')


#20 

sine_20=sine
for i in range(20):
    sine_20= sine_20+ np.random.normal(scale =0.1, size=50)
plt.plot(space, sine_20, color= 'g', label='noise_20_iters')

#100

sine_100=sine
for i in range(20):
    sine_100= sine_100+ np.random.normal(scale =0.1, size=50)
plt.plot(space, sine_100, color= 'm', label='noise_100_iters')


plt.legend(loc='upper right')
plt.title('Original Curve: 5, 20, 100 Iterations')
plt.savefig('./Q4_modified.png')
plt.show()

# %% [markdown]
# 5 Basic Image Operations Using Matplotlib

# %%
img=plt.imread('cat.jpg')
imgplot = plt.imshow(img)
plt.show()
print ('image dimensions', img.shape)
# Out:
# image dimensions (183, 275, 3)

# %% [markdown]
# 6 Data and Visualization

# %%
iris = datasets.load_iris()
X = iris.data[:, :]
y = iris.target

# %%
X_reduced = PCA(n_components=2).fit_transform(iris.data)
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, alpha=0.5, marker='o')
plt.xlabel("1st eigenvector")
plt.ylabel("2nd eigenvector")
plt.legend(loc='upper left')
plt.title("First two PCA directions")
plt.show()

# %%
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
X_reduced = PCA(n_components=2).fit_transform(iris.data)
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y,
           cmap=plt.cm.Set1, edgecolor='k', s=40)
ax.set_title("First two PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])

plt.show()

# %%
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
X_reduced = PCA(n_components=3).fit_transform(iris.data)
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=y,
           cmap=plt.cm.Set1, edgecolor='k', s=40)
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])

plt.show()

# %% [markdown]
# 7 Data Manipulation

# %%
#1
print ("#1: ", X[0:5,0:3])
# Out:
# #1:  [[ 5.1  3.5  1.4]
#  [ 4.9  3.   1.4]
#  [ 4.7  3.2  1.3]
#  [ 4.6  3.1  1.5]
#  [ 5.   3.6  1.4]]

# %%
#2
print ("#2 Average Col 3: ", X[:,2].mean())
print ("#2 Variance Col 3: ", np.var(X[:,2]))
# Out:
# #2 Average Col 3:  3.75866666667
# #2 Variance Col 3:  3.09242488889

# %%
#3
w=np.array([1,2,3,4])
lp=np.dot(X,w)
print ("#3 Average of Linear Projections", lp.mean())
# Out:
# #3 Average of Linear Projections 28.022

# %%
#4
def sample_row(X):
    x_row=randint(0, 150)
    data=X[x_row,:]
    print ("Random Index:", x_row)
    print ("Data", data)
    return x_row, data

# %%
print ('#4')
sample_row(X)
# Out:
# #4
# Random Index: 21
# Data [ 5.1  3.7  1.5  0.4]
# (21, array([ 5.1,  3.7,  1.5,  0.4]))

# %%
#5
ft_5=np.ones((150,1))
X_feat=np.concatenate((X,ft_5),axis = 1)
print ("#5 New Feature, Row 1: ", X_feat[0,:])
# Out:
# #5 New Feature, Row 1:  [ 5.1  3.5  1.4  0.2  1. ]

# %%
#6
new_row=X[0,:]
new_row=new_row.reshape(1,4)
X_data=np.concatenate((X, new_row), axis=0)
print ("#6 First row of new array:", X_data[0,:])
# Out:
# #6 First row of new array: [ 5.1  3.5  1.4  0.2]
