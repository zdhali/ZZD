# %% [markdown]
# # Import Packages

# %%
#import package
from cobra import Model, Reaction, Metabolite
import cobra
import pandas as pd 
from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)

# %%
import os
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import json
import scipy 
import re


import requests 
from bs4 import BeautifulSoup
import html.parser

# %% [markdown]
# ***
# # Locate Data
#
# SBML File location: C:\Users\zafri\Documents\Senior_Design\Data\Models\Download_bigg_web

# %%
cwd=os.getcwd()
cwd
os.chdir(os.path.join(cwd , 'Data/Models/Download_bigg_web'))

# %%
# %pwd
# Out:
# 'C:\\Users\\zafri\\Documents\\Senior_Design\\Data\\Models\\Download_bigg_web'

# %%
def data_locate(rel_path_to_input,a):
    cwd = os.getcwd()
    stem=cwd
    for i in range(a):
        stem=os.path.abspath(os.path.join(stem, '..'))
    data_loc=os.path.join(stem , rel_path_to_input)
    os.chdir(data_loc)
    sub_files = os.listdir(data_loc)
    print ("Current Directory: ", cwd)
    print ("Data location: " , data_loc)
    print (sub_files)
    return data_loc, sub_files

# %% [markdown]
# ***
# ***
# ***
# # LOAD SBML MODEL

# %%
RECON3d = cobra.io.read_sbml_model("Recon3D.xml")
RECON3d
# Out:
# <Model Recon3D at 0x19070b51a90>

# %%
print (RECON3d.reactions.G3PD.annotation.get('ec-code'))
# Out:
# ['1.1.5.3', '1.1.99.5']

# %% [markdown]
# ## Check the number of reactions with EC in annotation
# * obtain a realistic number of reactions that we are mapping against

# %%
EC_List=[]
RXN_List=[]
for reaction in RECON3d.reactions:
    RXN_List.append(reaction.id)
    EC_List.append(reaction.annotation.get("ec-code"))

# %%
df1=pd.DataFrame({"reaction": RXN_List, "ec" : EC_List})

# %%
t,f=df1["ec"].isnull().value_counts()
print (df1["ec"].isnull().value_counts())
print ("No EC: ", t)
print ("With EC: ", f)
print ("sanity check: total equals # with and without ec : ", t+f==df1.shape[0] )

# %% [markdown]
# # Load reactions from Dan Matlab Model
#
# * work previously done:
#     * Dan had previous condensed model of central metabolism in humans
#             * Total of 384 Reactions
#             * *Shortened metabolite list was appended as well*
#          * Mapped Matlab Model ID to SBML model id based upon reaction string
#              * Problem: Some did not map --> Now we have less than 384
#
#
# ## LOAD REACTION EC DICTIONARY (CSV FORM)

# %%
data_loc, sub_files=data_locate("Dan Matlab\code\datafiles_zaf", 1)

# %%
RXN_EC_DICT=pd.read_csv("USE_THIS_Dan_matlab_Model_wstrings - SBML ANNOT DICTIONARY.csv")

# %%
RXN_EC_DICT.shape

# %%
RXN_EC_DICT

# %%
#print (RXN_EC_DICT["Reaction"].isnull().value_counts())
f, t=RXN_EC_DICT["Reaction"].isnull().value_counts()
print ("No Mapped Reaction: ", t)
print ("With Mapped Reaction: ", f)
print ("sanity check: total equals # with and without rxn : ", t+f==RXN_EC_DICT.shape[0] )

# %%
#drop last four rows (sum of na rows etc)

RXN_EC_DICT=RXN_EC_DICT.drop([380,381,382,383], axis=0)

# %%
#print (RXN_EC_DICT["Reaction"].isnull().value_counts())
f, t=RXN_EC_DICT["Reaction"].isnull().value_counts()
print ("No Mapped Reaction: ", t)
print ("With Mapped Reaction: ", f)
print ("sanity check: total equals # with and without ec : ", t+f==RXN_EC_DICT.shape[0] )
print ("Anticipated DF shape : ", RXN_EC_DICT.shape[0]-t )

# %%
#drop if no reaction (means we were unable to find a recon3d reaction match for that reaction from Matlab model)
print ("shape before: ", RXN_EC_DICT.shape)
RXN_EC_DICT=RXN_EC_DICT.dropna(subset=['Reaction'])
print ("shape after: ", RXN_EC_DICT.shape)

# %%
RXN_EC_DICT.shape
RXN_EC_DICT.head()

# %%
RXN_EC_DICT=RXN_EC_DICT.drop(['Unnamed: 4','Unnamed: 5'], axis=1)

# %%
print (RXN_EC_DICT.shape)
RXN_EC_DICT

# %% [markdown]
# # SBML ids to list (365 rxns)
#
# ## double check all sbml ids mapped are in recon3d and can be mapped

# %%
sbml_rxn_short_list=RXN_EC_DICT["ID in MODEL SBML"].values.tolist()
sbml_rxn_short_list

# %%
reactions_found=[]
for reaction in RECON3d.reactions:
    for rxn in sbml_rxn_short_list:
        if reaction.id ==str(rxn):
            reactions_found.append(reaction.id)

# %%
if len(reactions_found)==len(sbml_rxn_short_list):
    print ("all reactions matched" )

print (len(reactions_found))
print (len(sbml_rxn_short_list))

# %% [markdown]
# ## all reactions from matlab were successfully mapped to RECON3d
#
# * total of 366 reactions
#
# ## Reaction ids (for condensed model) mapped to --> model --> Pull info from Recon3d Model

# %%
#Pulls following information
#RXN_ID=[] bigg id
#ANNOT=[]
#ANNOT_KEYS=[]
#ANNOT_VALUES=[]
#RXN_STRING=[]
#ANNOT_EC=[]
#ANNOT_BIGG=[]
#ANNOT_METANET=[]


def Pull_Model_info_rxn(rxn_list_query, model):
    RXN_ID=[]
    ANNOT=[]
    ANNOT_KEYS=[]
    ANNOT_VALUES=[]
    RXN_STRING=[]
    ANNOT_EC=[]
    ANNOT_BIGG=[]
    ANNOT_METANET=[]

    c=0
    for rxn_id in RECON3d.reactions:
        if str(rxn_id.id) in rxn_id_short:
            RXN_ID.append(rxn_id.id)
            RXN_STRING.append(rxn_id.reaction)
            ANNOT.append(rxn_id.annotation)
            ANNOT_KEYS.append(rxn_id.annotation.keys())
            ANNOT_EC.append(rxn_id.annotation.get('ec-code'))
            ANNOT_BIGG.append(rxn_id.annotation.get('bigg.reaction'))
            ANNOT_METANET.append(rxn_id.annotation.get('metanetx.reaction'))

        
            ANNOT_VALUES.append(rxn_id.annotation.values())
        
            
            c+=1
            print (rxn_id)
    print (c)

# %%
RXN_ID=[]
ANNOT=[]
ANNOT_KEYS=[]
ANNOT_VALUES=[]
RXN_STRING=[]
ANNOT_EC=[]
ANNOT_BIGG=[]
ANNOT_METANET=[]

c=0
for rxn_id in RECON3d.reactions:
    if str(rxn_id.id) in sbml_rxn_short_list:
        RXN_ID.append(rxn_id.id)
        RXN_STRING.append(rxn_id.reaction)
        ANNOT.append(rxn_id.annotation)
        ANNOT_KEYS.append(rxn_id.annotation.keys())
        ANNOT_EC.append(rxn_id.annotation.get('ec-code'))
        ANNOT_BIGG.append(rxn_id.annotation.get('bigg.reaction'))
        ANNOT_METANET.append(rxn_id.annotation.get('metanetx.reaction'))

        
        ANNOT_VALUES.append(rxn_id.annotation.values())
        
        
        c+=1
        print (rxn_id)
print (c)

# %%
SBML_All_Rows_df=pd.DataFrame({"rxn_id": RXN_ID, "rxn_string": RXN_STRING, "Full Annotation": ANNOT, 
                  "Annot Keys": ANNOT_KEYS, "Annot Values": ANNOT_VALUES, "ANNOT_EC":ANNOT_EC,
                  "ANNOT_BIGG": ANNOT_BIGG, "ANNOT_METANET": ANNOT_METANET})

# %%
SBML_All_Rows_df

# %% [markdown]
# * not every reaction in the model is annotated with 'ec-code'
#     * Lets check how much EC coverage we have

# %%
SBML_All_Rows_df["ANNOT_EC"][364] is None

# %% [markdown]
# ## EC annotation coverage not great-- losing reactions
# * Metanet annot has good coverage

# %%
SBML_All_Rows_df["ANNOT_METANET"].isnull().value_counts()

# %%
Metanetx_list=SBML_All_Rows_df["ANNOT_METANET"].tolist()

# %%
print (Metanetx_list[-1])

# %%
def lookup_ec_metnetx(METXID):
    url1='https://www.metanetx.org/equa_info/' + str(METXID)
    #print (url1)
    r=requests.get(url1)
    if r.status_code==200:
        soup = BeautifulSoup(r.text, 'html.parser')
        #print(soup.prettify())
        table = soup.find('table', attrs = {"class" : "mnx_table"}) 
        td_tags = table.findAll('td')
        for i in range(len(td_tags)):
            if str(td_tags[i])=="<td>EC number</td>":
                METANET_EC=str(td_tags[i+1])
                


    else:
        print ("/n METID DID NOT WORK /n")
        print (METXID)
    
    return METANET_EC

# %%
METANET_EC_RESULTS=[]
for ID in Metanetx_list:
    if ID=="" or ID is None:
        METANET_EC_RESULTS.append("")
    else:
        METANET_EC_RESULTS.append(lookup_ec_metnetx(ID))
    print (len(METANET_EC_RESULTS),(len(METANET_EC_RESULTS)/len(Metanetx_list)))

# %%
METANET_EC_RESULTS

# %%
#append metanet ECs 
# make final EC column
SBML_All_Rows_df["METANETX_EC"]= METANET_EC_RESULTS
SBML_All_Rows_df["EC_Comp"]=SBML_All_Rows_df["ANNOT_EC"]

# %%
SBML_All_Rows_df.isnull()

# %%
for index in range(len(SBML_All_Rows_df)):
    if SBML_All_Rows_df["EC_Comp"][index] is None:
        if SBML_All_Rows_df["METANETX_EC"][index]=="<td>NA</td>":
            SBML_All_Rows_df["EC_Comp"][index]="MISSING EC STILL"
        else:
            SBML_All_Rows_df["EC_Comp"][index]=SBML_All_Rows_df["METANETX_EC"][index]

# %%
SBML_All_Rows_df["EC_Comp"]

# %%
#Count the still empty EC
c=0
for i in SBML_All_Rows_df["EC_Comp"]:
    if i =="MISSING EC STILL":
        c+=1
    elif i =="":
        c+=1

#sanity check
print ("number of reactions with no ec mapping: ", c, str(c/len(SBML_All_Rows_df["EC_Comp"]))+"%")
d=(len(SBML_All_Rows_df["EC_Comp"])-c)
print ("number of reactions with ec mapping: ",d, str(d/len(SBML_All_Rows_df["EC_Comp"]))+"%")
print (c+d)

# %%
#drop the rows without EC
df_EC=SBML_All_Rows_df[SBML_All_Rows_df.EC_Comp != 'MISSING EC STILL']
df_EC=df_EC[df_EC.EC_Comp != '']

# %%
df_EC

# %%
df_EC.shape

# %%
writer = pd.ExcelWriter('RXN_W_EC_Dict_FINAL', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df_EC.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
df_EC

# %%
len(df_EC.ANNOT_EC[3])
type(df_EC.ANNOT_EC[1])

# %%
# Save DF_EC so we dont need to run the scrape everytime
writer = pd.ExcelWriter('df_ec.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df_EC.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# # Note: THERE IS A BREAK IN THE WORKFLOW HERE:
#
#
# ### CONTENTS:
#
# * Split EC lists into individual list of ECs
#     * Initial workflow to drop and select scraped data
#     * use unique list of EC from df_EC to drop rows of kinetic data
#         * **abandoned due to wanting of model reaction string in feature matrix to create metabolite and structural features more easily in the future **
#         * can also add flux and data from model if needed --> but dan has provided most of these already from previous work
#
#
#
# ***
#
#
#
#
#
# ### Split EC lists into individual list of ECs
#
#
# ### EC from SBML model has type list and str
#
# #### Create a list of just EC from model

# %%
individual_ec_list=[]
for i in df_EC.ANNOT_EC:
    if type(i)==list:
        for n in i:
            individual_ec_list.append(n)          
    if type(i)==str:
        individual_ec_list.append(n)

# %%
individual_ec_list

# %%
len(individual_ec_list)

# %%
EC_only=pd.DataFrame({"EC list": individual_ec_list})

# %%
writer = pd.ExcelWriter('EC_ONLY_260_FINAL', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
EC_only.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
# %pwd

# %% [markdown]
# # dropping rows from scraped data
#
# ## data had been pre-appended together
#
# ### had it broken into old scraped rows and new scraped rows
#
#
#
#
# # Protocol
#
# <br>
#
# ## remove all rows with empty ec
# ## remove all rows where EC does not match Individual_EC_List (261 ec #)
#
# # output: saved as Kinetic_dropped

# %%
Kinetic_df=pd.read_excel("APPENDED_RECON_SCRAPE_DATA_ALL.xlsx")

# %%
Kinetic_df.head()

# %%
Kinetic_df.shape

# %%
Kinetic_df.columns

# %%
len(Kinetic_df["EC Number"].unique())

# %%
#lets get a rough look at how many ec match / how much preprocessing is needed
c_drop=0
c_keep=0
kinetic_EC_unique=Kinetic_df["EC Number"].unique()
c_total=len(kinetic_EC_unique)
for ec in kinetic_EC_unique:
    if ec in individual_ec_list:
        c_keep+=1
        print (ec)
    else:
        c_drop+=1
print ("Total # Unique EC", c_total)
print ("Keep : ", c_keep ,"     ", (c_keep/c_total) , "%")
print ( "Drop : ", c_drop,"     ", (c_drop/c_total) , "%")

# %% [markdown]
# # Drop Rows without EC
#
#
# ** around 700 data points in scrape did not have EC**

# %%
print (Kinetic_df.shape)
Kinetic_df=Kinetic_df.dropna(subset=['EC Number'])

# %%
Kinetic_df.shape

# %%
def strip_space(string):
    
    string = string.strip()
    
    return string

# %%
Kinetic_df["EC Number"]= Kinetic_df["EC Number"].apply(strip_space)

# %% [markdown]
# # Create a list of EC
#
# ### ANNOT

# %%
for i in individual_ec_list:
    i=i.strip()

# %%
#actually drop rows 
Row_Status=[]
c_keep=0
c_drop=0
for ec in Kinetic_df["EC Number"]:
    if ec in individual_ec_list:
        Row_Status.append("Keep")
        c_keep+=1
    else:
        c_drop+=1
        Row_Status.append("Drop")
print ("Keep : ", c_keep )
print ( "Drop : ", c_drop)

# %%
#sanity check
len(Row_Status)==len(Kinetic_df["EC Number"])

# %%
#Append row status to dataframe
Kinetic_df["Row_Status"]=Row_Status

# %%
Kinetic_df

# %%
Kinetic_df_dropped = Kinetic_df[Kinetic_df.Row_Status != 'Drop']

# %%
Kinetic_df_dropped.head()

# %%
#final shape
Kinetic_df_dropped.shape

# %%
print (Kinetic_df_dropped["EC Number"].unique())
len(Kinetic_df_dropped["EC Number"].unique())

# %% [markdown]
# # START SECOND WORKFLOW HERE:
#
# ## go backwards --> map reaction string, annot, to kinetic data

# %% [markdown]
# # note to self
#
# * df_EC --> model info
# * Kinetic_df_dropped --> Kinetic data rows where the EC matched the individual EC pulled from df_EC["ANNOT_EC"]
#     * (df_EC had EC in list and string)
#     * created a list of individual EC numbers ( like if had done df_EC["ANNOT_EC"].unique())

# %%
# Run if starting from here ---> Keep going else
data_locate("Dan Matlab\code\datafiles_zaf", 1)
# Out:
# Current Directory:  C:\Users\zafri\Documents\Senior_Design\Data\Models\Download_bigg_web
# Data location:  C:\Users\zafri\Documents\Senior_Design\Data\Models\Dan Matlab\code\datafiles_zaf
# ['190RXN_EC_Dict_FINAL', 'APPENDED_RECON_SCRAPE_DATA_ALL.xlsx', 'Dan_matlab_Model_wstrings.xlsx', 'df_ec', 'df_ec.xlsx', 'EC_ONLY_260_FINAL', 'EC_ONLY_260_FINAL.xlsx', 'Features Sheet - Metabolite Features_zaf.csv', 'file.txt', 'KINETIC_DATASET_FINAL(EC_matched)', 'KINETIC_DATASET_FINAL(EC_matched).xlsx', 'Kinetic__matched(beforemanualcuration.xlsx', 'Kinetic__matched_CURATECopy.xlsx', 'network_info.txt', 'RECONcuration_done_FROM_HONG.xlsx', 'RECON_newrxn_done_FROM_HONG.xlsx', 'RXN_EC_Dict_260_FINAL', 'RXN_EC_Dict_260_FINAL.xlsx', 'RXN_W_EC_Dict_FINAL', 'USE_THIS_Dan_matlab_Model_wstrings - SBML ANNOT DICTIONARY.csv']
# ('C:\\Users\\zafri\\Documents\\Senior_Design\\Data\\Models\\Dan Matlab\\code\\datafiles_zaf',
#  ['190RXN_EC_Dict_FINAL',
#   'APPENDED_RECON_SCRAPE_DATA_ALL.xlsx',
#   'Dan_matlab_Model_wstrings.xlsx',
#   'df_ec',
#   'df_ec.xlsx',
#   'EC_ONLY_260_FINAL',
#   'EC_ONLY_260_FINAL.xlsx',
#   'Features Sheet - Metabolite Features_zaf.csv',
#   'file.txt',
#   'KINETIC_DATASET_FINAL(EC_matched)',
#   'KINETIC_DATASET_FINAL(EC_matched).xlsx',
#   'Kinetic__matched(beforemanualcuration.xlsx',
#   'Kinetic__matched_CURATECopy.xlsx',
#   'network_info.txt',
#   'RECONcuration_done_FROM_HONG.xlsx',
#   'RECON_newrxn_done_FROM_HONG.xlsx',
#   'RXN_EC_Dict_260_FINAL',
#   'RXN_EC_Dict_260_FINAL.xlsx',
#   'RXN_W_EC_Dict_FINAL',
#   'USE_THIS_Dan_matlab_Model_wstrings - SBML ANNOT DICTIONARY.csv'])

# %%
# load df_EC from Excel
df_EC=pd.read_excel("df_EC.xlsx")
Kinetic_df=pd.read_excel("APPENDED_RECON_SCRAPE_DATA_ALL.xlsx")

# %%
df_EC
# Out:
#     ANNOT_BIGG                                        ANNOT_EC ANNOT_METANET  \
# 1    2OXOADOXm  ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']     MNXR94818
# 3      34HPPOR                                      1.13.11.27     MNXR94843
# 4       3DSPHR                                       1.1.1.102     MNXR94866
# 5         3HAO                                       1.13.11.6     MNXR94889
# 6    3HBCOAHLm                                         3.1.2.4     MNXR94891
# 10     AASAD3m                                        1.2.1.31     MNXR95158
# 11        AATA                                        2.6.1.39     MNXR95160
# 12    ACACT10m                         ['2.3.1.16', '2.3.1.9']     MNXR95195
# 13     ACACT1m                                         2.3.1.9     MNXR95194
# 15       ACITL                          ['2.3.3.8', '4.1.3.6']     MNXR95268
# 16    ACOAD10m                                        1.3.99.3     MNXR95306
# 17     ACOAD8m             ['1.3.8.4', '1.3.8.7', '1.3.99.10']     MNXR95318
# 18     ACOAD9m                         ['1.3.8.-', '1.3.99.3']     MNXR95319
# 19      ACONTm                                         4.2.1.3     MNXR95384
# 21        ADK3                         ['2.7.4.10', '2.7.4.4']     MNXR95452
# 23      ADSL1r                                         4.3.2.2     MNXR95493
# 24      ADSL2r                                         4.3.2.2     MNXR95494
# 26       AIRCr                                        4.1.1.21     MNXR95646
# 27       AKGDm  ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']     MNXR95655
# 29     ALATA_L                                         2.6.1.2     MNXR95698
# 30      AMCOXO                                         1.5.1.-     MNXR95807
# 31       ARGNm                                         3.5.3.1     MNXR95945
# 32       ARGSS                                         6.3.4.5     MNXR95949
# 37       ASNNm              ['3.5.1.1', '3.5.1.38', '3.5.5.4']     MNXR96056
# 38       ASNS1                                         6.3.5.4     MNXR96059
# 41       ASPCT                                         2.1.3.2     MNXR96080
# 44      ASPTAm                                         2.6.1.1     MNXR96079
# 45       ATPtm                                         2.7.4.6     MNXR96123
# 52      CBPSam                         ['6.3.4.16', '6.3.5.5']     MNXR96486
# 56     CHLPCTD                                        2.7.7.15     MNXR96686
# ..         ...                                             ...           ...
# 312      PRPPS                                         2.7.6.1    MNXR103215
# 313      PSERT                                        2.6.1.52    MNXR103225
# 314      PSP_L                                         3.1.3.3    MNXR103260
# 315      RNDR1                                        1.17.4.1    MNXR104060
# 316      RNDR2                                        1.17.4.1    MNXR104062
# 317      RNDR3                                        1.17.4.1    MNXR104064
# 318      RNDR4                                        1.17.4.1    MNXR104066
# 319        RPE                                         5.1.3.1    MNXR104083
# 320        RPI                                         5.3.1.6    MNXR104084
# 321       TALA                                         2.2.1.2    MNXR104715
# 322       TKT1                                         2.2.1.1    MNXR104868
# 323       TKT2                                         2.2.1.1    MNXR104869
# 324        TPI                                         5.3.1.1    MNXR104918
# 325       UMPK             ['2.7.4.14', '2.7.4.22', '2.7.4.4']    MNXR105118
# 327      VALTA                         ['2.6.1.42', '2.6.1.6']     MNXR96230
# 328     ACCOAC                                         6.4.1.2     MNXR95219
# 340     AICART                                         2.1.2.3     MNXR95639
# 341      ARGSL                                         4.3.2.1     MNXR95948
# 345     GLUPRT                                        2.4.2.14    MNXR100287
# 346       IMPC                         ['2.1.2.3', '3.5.4.10']    MNXR100783
# 347      LDH_L                                        1.1.1.27    MNXR101040
# 348        MDH                       ['1.1.1.299', '1.1.1.37']    MNXR101439
# 349      MI1PP                                        3.1.3.25    MNXR101570
# 350        PFK                                        2.7.1.11    MNXR102507
# 351      PRFGS                                         6.3.5.3    MNXR103165
# 352        PYK                                        2.7.1.40    MNXR103371
# 353       TMDS                                        2.1.1.45    MNXR104889
# 354      TYRTA   ['2.6.1.1', '2.6.1.5', '2.6.1.57', '2.6.1.9']    MNXR105000
# 355     AACOAT                                        6.2.1.16     MNXR95136
# 358   HMGCOARx                                        1.1.1.34    MNXR100659
#
#                                             Annot Keys  \
# 1    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 3    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 4    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 5    dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 6    dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 10   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 11   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 12   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 13   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 15   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 16   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 17   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 18   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 19   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 21   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 23   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 24   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 26   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 27   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 29   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 30   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 31   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 32   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 37   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 38   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 41   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 44   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 45   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 52   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 56   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# ..                                                 ...
# 312  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 313  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 314  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 315  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 316  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 317  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 318  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 319  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 320  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 321  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 322  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 323  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 324  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 325  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 327  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 328  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 340  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 341  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 345  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 346  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 347  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 348  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 349  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 350  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 351  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 352  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 353  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 354  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 355  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 358  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
#
#                                           Annot Values  \
# 1    dict_values(['SBO:0000375', '2OXOADOXm', 'META...
# 3    dict_values(['SBO:0000375', '34HPPOR', 'META:4...
# 4    dict_values(['SBO:0000375', '3DSPHR', 'META:3-...
# 5    dict_values(['SBO:0000375', '3HAO', '1.13.11.6...
# 6    dict_values(['SBO:0000375', '3HBCOAHLm', '3.1....
# 10   dict_values(['SBO:0000375', 'AASAD3m', 'META:A...
# 11   dict_values(['SBO:0000375', 'AATA', 'META:2-AM...
# 12   dict_values(['SBO:0000375', 'ACACT10m', 'META:...
# 13   dict_values(['SBO:0000375', 'ACACT1m', 'META:A...
# 15   dict_values(['SBO:0000375', 'ACITL', 'META:ATP...
# 16   dict_values(['SBO:0000375', 'ACOAD10m', '1.3.9...
# 17   dict_values(['SBO:0000375', 'ACOAD8m', 'META:R...
# 18   dict_values(['SBO:0000375', 'ACOAD9m', 'META:M...
# 19   dict_values(['SBO:0000375', 'ACONTm', '4.2.1.3...
# 21   dict_values(['SBO:0000375', 'ADK3', 'META:RXN-...
# 23   dict_values(['SBO:0000375', 'ADSL1r', 'META:AM...
# 24   dict_values(['SBO:0000375', 'ADSL2r', 'META:AI...
# 26   dict_values(['SBO:0000375', 'AIRCr', '4.1.1.21...
# 27   dict_values(['SBO:0000375', 'AKGDm', 'META:2OX...
# 29   dict_values(['SBO:0000375', 'ALATA_L', ['META:...
# 30   dict_values(['SBO:0000375', 'AMCOXO', '1.5.1.-...
# 31   dict_values(['SBO:0000375', 'ARGNm', 'META:ARG...
# 32   dict_values(['SBO:0000375', 'ARGSS', 'META:ARG...
# 37   dict_values(['SBO:0000375', 'ASNNm', 'META:ASP...
# 38   dict_values(['SBO:0000375', 'ASNS1', 'META:ASN...
# 41   dict_values(['SBO:0000375', 'ASPCT', 'META:ASP...
# 44   dict_values(['SBO:0000375', 'ASPTAm', ['META:A...
# 45   dict_values(['SBO:0000375', 'ATPtm', '2.7.4.6'...
# 52   dict_values(['SBO:0000375', 'CBPSam', 'META:RX...
# 56   dict_values(['SBO:0000375', 'CHLPCTD', 'META:2...
# ..                                                 ...
# 312  dict_values(['SBO:0000375', 'PRPPS', '2.7.6.1'...
# 313  dict_values(['SBO:0000375', 'PSERT', 'META:PSE...
# 314  dict_values(['SBO:0000375', 'PSP_L', 'META:RXN...
# 315  dict_values(['SBO:0000375', 'RNDR1', 'META:ADP...
# 316  dict_values(['SBO:0000375', 'RNDR2', 'META:GDP...
# 317  dict_values(['SBO:0000375', 'RNDR3', 'META:CDP...
# 318  dict_values(['SBO:0000375', 'RNDR4', 'META:UDP...
# 319  dict_values(['SBO:0000375', 'RPE', 'META:RIBUL...
# 320  dict_values(['SBO:0000375', 'RPI', '5.3.1.6', ...
# 321  dict_values(['SBO:0000375', 'TALA', 'META:TRAN...
# 322  dict_values(['SBO:0000375', 'TKT1', '2.2.1.1',...
# 323  dict_values(['SBO:0000375', 'TKT2', 'META:2TRA...
# 324  dict_values(['SBO:0000375', 'TPI', 'META:TRIOS...
# 325  dict_values(['SBO:0000375', 'UMPK', 'META:RXN-...
# 327  dict_values(['SBO:0000375', 'VALTA', 'META:BRA...
# 328  dict_values(['SBO:0000375', 'ACCOAC', 'META:AC...
# 340  dict_values(['SBO:0000375', 'AICART', '2.1.2.3...
# 341  dict_values(['SBO:0000375', 'ARGSL', 'META:ARG...
# 345  dict_values(['SBO:0000375', 'GLUPRT', 'META:PR...
# 346  dict_values(['SBO:0000375', 'IMPC', 'META:IMPC...
# 347  dict_values(['SBO:0000375', 'LDH_L', 'META:L-L...
# 348  dict_values(['SBO:0000375', 'MDH', 'META:MALAT...
# 349  dict_values(['SBO:0000375', 'MI1PP', 'META:RXN...
# 350  dict_values(['SBO:0000375', 'PFK', '2.7.1.11',...
# 351  dict_values(['SBO:0000375', 'PRFGS', '6.3.5.3'...
# 352  dict_values(['SBO:0000375', 'PYK', 'META:PEPDE...
# 353  dict_values(['SBO:0000375', 'TMDS', '2.1.1.45'...
# 354  dict_values(['SBO:0000375', 'TYRTA', 'META:TYR...
# 355  dict_values(['SBO:0000375', 'AACOAT', 'META:AC...
# 358  dict_values(['SBO:0000375', 'HMGCOARx', '1.1.1...
#
#                                        Full Annotation     rxn_id  \
# 1    {'SBO': 'SBO:0000375', 'bigg.reaction': '2OXOA...  2OXOADOXm
# 3    {'SBO': 'SBO:0000375', 'bigg.reaction': '34HPP...    34HPPOR
# 4    {'SBO': 'SBO:0000375', 'bigg.reaction': '3DSPH...     3DSPHR
# 5    {'SBO': 'SBO:0000375', 'bigg.reaction': '3HAO'...       3HAO
# 6    {'SBO': 'SBO:0000375', 'bigg.reaction': '3HBCO...  3HBCOAHLm
# 10   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AASAD...    AASAD3m
# 11   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AATA'...       AATA
# 12   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACACT...   ACACT10m
# 13   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACACT...    ACACT1m
# 15   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACITL...      ACITL
# 16   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...   ACOAD10m
# 17   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...    ACOAD8m
# 18   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...    ACOAD9m
# 19   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACONT...     ACONTm
# 21   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADK3'...       ADK3
# 23   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADSL1...     ADSL1r
# 24   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADSL2...     ADSL2r
# 26   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AIRCr...      AIRCr
# 27   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AKGDm...      AKGDm
# 29   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ALATA...    ALATA_L
# 30   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AMCOX...     AMCOXO
# 31   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGNm...      ARGNm
# 32   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGSS...      ARGSS
# 37   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASNNm...      ASNNm
# 38   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASNS1...      ASNS1
# 41   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASPCT...      ASPCT
# 44   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASPTA...     ASPTAm
# 45   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ATPtm...      ATPtm
# 52   {'SBO': 'SBO:0000375', 'bigg.reaction': 'CBPSa...     CBPSam
# 56   {'SBO': 'SBO:0000375', 'bigg.reaction': 'CHLPC...    CHLPCTD
# ..                                                 ...        ...
# 312  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PRPPS...      PRPPS
# 313  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PSERT...      PSERT
# 314  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PSP_L...      PSP_L
# 315  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR1...      RNDR1
# 316  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR2...      RNDR2
# 317  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR3...      RNDR3
# 318  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR4...      RNDR4
# 319  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RPE',...        RPE
# 320  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RPI',...        RPI
# 321  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TALA'...       TALA
# 322  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TKT1'...       TKT1
# 323  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TKT2'...       TKT2
# 324  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TPI',...        TPI
# 325  {'SBO': 'SBO:0000375', 'bigg.reaction': 'UMPK'...       UMPK
# 327  {'SBO': 'SBO:0000375', 'bigg.reaction': 'VALTA...      VALTA
# 328  {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACCOA...     ACCOAC
# 340  {'SBO': 'SBO:0000375', 'bigg.reaction': 'AICAR...     AICART
# 341  {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGSL...      ARGSL
# 345  {'SBO': 'SBO:0000375', 'bigg.reaction': 'GLUPR...     GLUPRT
# 346  {'SBO': 'SBO:0000375', 'bigg.reaction': 'IMPC'...       IMPC
# 347  {'SBO': 'SBO:0000375', 'bigg.reaction': 'LDH_L...      LDH_L
# 348  {'SBO': 'SBO:0000375', 'bigg.reaction': 'MDH',...        MDH
# 349  {'SBO': 'SBO:0000375', 'bigg.reaction': 'MI1PP...      MI1PP
# 350  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PFK',...        PFK
# 351  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PRFGS...      PRFGS
# 352  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PYK',...        PYK
# 353  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TMDS'...       TMDS
# 354  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TYRTA...      TYRTA
# 355  {'SBO': 'SBO:0000375', 'bigg.reaction': 'AACOA...     AACOAT
# 358  {'SBO': 'SBO:0000375', 'bigg.reaction': 'HMGCO...   HMGCOARx
#
#                                             rxn_string  \
# 1    2oxoadp_m + coa_m + nad_m --> co2_m + glutcoa_...
# 3                 34hpp_c + o2_c --> co2_c + hgentis_c
# 4       3dsphgn_c + h_c + nadph_c --> nadp_c + sphgn_c
# 5                  3hanthrn_c + o2_c --> cmusa_c + h_c
# 6         3hibutcoa_m + h2o_m --> 3hmp_m + coa_m + h_m
# 10   L2aadp6sa_m + h2o_m + nad_m --> L2aadp_m + 2.0...
# 11           2oxoadp_c + glu__L_c <=> L2aadp_c + akg_c
# 12             2maacoa_m + coa_m <=> accoa_m + ppcoa_m
# 13                     2.0 accoa_m --> aacoa_m + coa_m
# 15   atp_c + cit_c + coa_c --> accoa_c + adp_c + oa...
# 16            2mbcoa_m + fad_m --> 2mb2coa_m + fadh2_m
# 17             fad_m + ivcoa_m --> 3mb2coa_m + fadh2_m
# 18             fad_m + ibcoa_m --> 2mp2coa_m + fadh2_m
# 19                                    cit_m <=> icit_m
# 21                     amp_c + gtp_c <=> adp_c + gdp_c
# 23                           dcamp_c --> amp_c + fum_c
# 24                        25aics_c --> aicar_c + fum_c
# 26                     air_c + co2_c <=> 5aizc_c + h_c
# 27   akg_m + coa_m + nad_m --> co2_m + nadh_m + suc...
# 29               akg_c + ala__L_c <=> glu__L_c + pyr_c
# 30   amuco_c + h2o_c + h_c + nadph_c --> 2oxoadp_c ...
# 31                 arg__L_m + h2o_m --> orn_m + urea_m
# 32   asp__L_c + atp_c + citr__L_c --> amp_c + argsu...
# 37               asn__L_m + h2o_m --> asp__L_m + nh4_m
# 38   asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c ...
# 41           asp__L_c + cbp_c <=> cbasp_c + h_c + pi_c
# 44               akg_m + asp__L_m <=> glu__L_m + oaa_m
# 45                     adp_c + atp_m --> adp_m + atp_c
# 52   2.0 atp_m + hco3_m + nh4_m --> 2.0 adp_m + cbp...
# 56         cholp_c + ctp_c + h_c --> cdpchol_c + ppi_c
# ..                                                 ...
# 312             atp_c + r5p_c --> amp_c + h_c + prpp_c
# 313            3php_c + glu__L_c --> akg_c + pser__L_c
# 314              h2o_c + pser__L_c --> pi_c + ser__L_c
# 315       adp_c + trdrd_c --> dadp_c + h2o_c + trdox_c
# 316       gdp_c + trdrd_c --> dgdp_c + h2o_c + trdox_c
# 317       cdp_c + trdrd_c --> dcdp_c + h2o_c + trdox_c
# 318       trdrd_c + udp_c --> dudp_c + h2o_c + trdox_c
# 319                            ru5p__D_c <=> xu5p__D_c
# 320                                r5p_c <=> ru5p__D_c
# 321                    g3p_c + s7p_c <=> e4p_c + f6p_c
# 322                r5p_c + xu5p__D_c <=> g3p_c + s7p_c
# 323                e4p_c + xu5p__D_c <=> f6p_c + g3p_c
# 324                                   dhap_c <=> g3p_c
# 325                    atp_c + ump_c <=> adp_c + udp_c
# 327             akg_c + val__L_c <=> 3mob_c + glu__L_c
# 328  accoa_c + atp_c + hco3_c --> adp_c + h_c + mal...
# 340            10fthf_c + aicar_c <=> fprica_c + thf_c
# 341                      argsuc_c <=> arg__L_c + fum_c
# 345  gln__L_c + h2o_c + prpp_c --> glu__L_c + ppi_c...
# 346                         h2o_c + imp_c <=> fprica_c
# 347          lac__L_c + nad_c <=> h_c + nadh_c + pyr_c
# 348          mal__L_c + nad_c <=> h_c + nadh_c + oaa_c
# 349               h2o_c + mi1p__D_c --> inost_c + pi_c
# 350              atp_c + f6p_c --> adp_c + fdp_c + h_c
# 351  atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + ...
# 352              adp_c + h_c + pep_c --> atp_c + pyr_c
# 353                dump_c + mlthf_c --> dhf_c + dtmp_c
# 354            akg_c + tyr__L_c <=> 34hpp_c + glu__L_c
# 355  acac_c + atp_c + coa_c --> aacoa_c + amp_c + p...
# 358  2.0 h_x + hmgcoa_x + 2.0 nadph_x --> coa_x + m...
#
#                                            METANETX_EC  \
# 1    <td>1.2.1.52<br>1.2.4.2<br>1.8.1.4<br>2.3.1.61...
# 3                                  <td>1.13.11.27</td>
# 4                                   <td>1.1.1.102</td>
# 5                                   <td>1.13.11.6</td>
# 6                                     <td>3.1.2.4</td>
# 10                                   <td>1.2.1.31</td>
# 11                                   <td>2.6.1.39</td>
# 12                   <td>2.3.1.16<br>2.3.1.9</br></td>
# 13                                    <td>2.3.1.9</td>
# 15                    <td>2.3.3.8<br>4.1.3.6</br></td>
# 16                                   <td>1.3.99.3</td>
# 17   <td>1.3.8.4<br>1.3.8.7<br>1.3.99.10</br></br><...
# 18                     <td>1.3.8<br>1.3.99.3</br></td>
# 19                                    <td>4.2.1.3</td>
# 21                   <td>2.7.4.10<br>2.7.4.4</br></td>
# 23                                    <td>4.3.2.2</td>
# 24                                    <td>4.3.2.2</td>
# 26                                   <td>4.1.1.21</td>
# 27   <td>1.2.1.52<br>1.2.4.2<br>1.8.1.4<br>2.3.1.61...
# 29                                    <td>2.6.1.2</td>
# 30                                    <td>1.5.1.-</td>
# 31                                    <td>3.5.3.1</td>
# 32                                    <td>6.3.4.5</td>
# 37   <td>3.5.1.1<br>3.5.1.38<br>3.5.5.4</br></br></td>
# 38                                    <td>6.3.5.4</td>
# 41                                    <td>2.1.3.2</td>
# 44                                    <td>2.6.1.1</td>
# 45                                    <td>2.7.4.6</td>
# 52                   <td>6.3.4.16<br>6.3.5.5</br></td>
# 56                                   <td>2.7.7.15</td>
# ..                                                 ...
# 312                                   <td>2.7.6.1</td>
# 313                                  <td>2.6.1.52</td>
# 314                                   <td>3.1.3.3</td>
# 315                                  <td>1.17.4.1</td>
# 316                                  <td>1.17.4.1</td>
# 317                 <td>1.17.4.1<br>1.17.4.2</br></td>
# 318                                  <td>1.17.4.1</td>
# 319                                   <td>5.1.3.1</td>
# 320                                   <td>5.3.1.6</td>
# 321                                   <td>2.2.1.2</td>
# 322                                   <td>2.2.1.1</td>
# 323                                   <td>2.2.1.1</td>
# 324                                   <td>5.3.1.1</td>
# 325  <td>2.7.4.14<br>2.7.4.22<br>2.7.4.4</br></br><...
# 327                  <td>2.6.1.42<br>2.6.1.6</br></td>
# 328                                   <td>6.4.1.2</td>
# 340                                   <td>2.1.2.3</td>
# 341                                   <td>4.3.2.1</td>
# 345                                  <td>2.4.2.14</td>
# 346                  <td>2.1.2.3<br>3.5.4.10</br></td>
# 347                                  <td>1.1.1.27</td>
# 348                <td>1.1.1.299<br>1.1.1.37</br></td>
# 349                                  <td>3.1.3.25</td>
# 350                                  <td>2.7.1.11</td>
# 351                                   <td>6.3.5.3</td>
# 352                                  <td>2.7.1.40</td>
# 353                                  <td>2.1.1.45</td>
# 354  <td>2.6.1.1<br>2.6.1.5<br>2.6.1.57<br>2.6.1.9<...
# 355                                  <td>6.2.1.16</td>
# 358                                  <td>1.1.1.34</td>
#
#                                             EC_Comp
# 1    ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 3                                        1.13.11.27
# 4                                         1.1.1.102
# 5                                         1.13.11.6
# 6                                           3.1.2.4
# 10                                         1.2.1.31
# 11                                         2.6.1.39
# 12                          ['2.3.1.16', '2.3.1.9']
# 13                                          2.3.1.9
# 15                           ['2.3.3.8', '4.1.3.6']
# 16                                         1.3.99.3
# 17              ['1.3.8.4', '1.3.8.7', '1.3.99.10']
# 18                          ['1.3.8.-', '1.3.99.3']
# 19                                          4.2.1.3
# 21                          ['2.7.4.10', '2.7.4.4']
# 23                                          4.3.2.2
# 24                                          4.3.2.2
# 26                                         4.1.1.21
# 27   ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 29                                          2.6.1.2
# 30                                          1.5.1.-
# 31                                          3.5.3.1
# 32                                          6.3.4.5
# 37               ['3.5.1.1', '3.5.1.38', '3.5.5.4']
# 38                                          6.3.5.4
# 41                                          2.1.3.2
# 44                                          2.6.1.1
# 45                                          2.7.4.6
# 52                          ['6.3.4.16', '6.3.5.5']
# 56                                         2.7.7.15
# ..                                              ...
# 312                                         2.7.6.1
# 313                                        2.6.1.52
# 314                                         3.1.3.3
# 315                                        1.17.4.1
# 316                                        1.17.4.1
# 317                                        1.17.4.1
# 318                                        1.17.4.1
# 319                                         5.1.3.1
# 320                                         5.3.1.6
# 321                                         2.2.1.2
# 322                                         2.2.1.1
# 323                                         2.2.1.1
# 324                                         5.3.1.1
# 325             ['2.7.4.14', '2.7.4.22', '2.7.4.4']
# 327                         ['2.6.1.42', '2.6.1.6']
# 328                                         6.4.1.2
# 340                                         2.1.2.3
# 341                                         4.3.2.1
# 345                                        2.4.2.14
# 346                         ['2.1.2.3', '3.5.4.10']
# 347                                        1.1.1.27
# 348                       ['1.1.1.299', '1.1.1.37']
# 349                                        3.1.3.25
# 350                                        2.7.1.11
# 351                                         6.3.5.3
# 352                                        2.7.1.40
# 353                                        2.1.1.45
# 354   ['2.6.1.1', '2.6.1.5', '2.6.1.57', '2.6.1.9']
# 355                                        6.2.1.16
# 358                                        1.1.1.34
#
# [190 rows x 10 columns]

# %%
Kinetic_df
# Out:
#      Entry ID                            Recommended Enzyme Name  \
# 28         29                              alcohol dehydrogenase
# 29         30                              alcohol dehydrogenase
# 36         37                              alcohol dehydrogenase
# 41         42                              alcohol dehydrogenase
# 42         43                              alcohol dehydrogenase
# 43         44                              alcohol dehydrogenase
# 44         45                              alcohol dehydrogenase
# 58         59                              alcohol dehydrogenase
# 59         60                              alcohol dehydrogenase
# 60         61                              alcohol dehydrogenase
# 61         62                              alcohol dehydrogenase
# 62         63                              alcohol dehydrogenase
# 63         64                              alcohol dehydrogenase
# 64         65                              alcohol dehydrogenase
# 71         72                              alcohol dehydrogenase
# 72         73                              alcohol dehydrogenase
# 73         74                              alcohol dehydrogenase
# 74         75                              alcohol dehydrogenase
# 75         76                              alcohol dehydrogenase
# 76         77                              alcohol dehydrogenase
# 77         78                              alcohol dehydrogenase
# 78         79                              alcohol dehydrogenase
# 79         80                              alcohol dehydrogenase
# 80         81                              alcohol dehydrogenase
# 81         82                              alcohol dehydrogenase
# 82         83                              alcohol dehydrogenase
# 83         84                              alcohol dehydrogenase
# 84         85                              alcohol dehydrogenase
# 85         86                              alcohol dehydrogenase
# 86         87                              alcohol dehydrogenase
# ..        ...                                                ...
# 63         64       glutamate--cysteine ligase catalytic subunit
# 64         65       glutamate--cysteine ligase catalytic subunit
# 65         66       glutamate--cysteine ligase catalytic subunit
# 26         27                         argininosuccinate synthase
# 27         28                         argininosuccinate synthase
# 28         29                         argininosuccinate synthase
# 144       145                  Argininosuccinate synthaseCurated
# 145       146                  Argininosuccinate synthaseCurated
# 41         42                             Biotin--protein ligase
# 14         15              Glutamine-dependent NAD(+) synthetase
# 15         16              Glutamine-dependent NAD(+) synthetase
# 16         17              Glutamine-dependent NAD(+) synthetase
# 17         18              Glutamine-dependent NAD(+) synthetase
# 63         64                           Acetyl-CoA carboxylase 2
# 64         65                           Acetyl-CoA carboxylase 2
# 65         66                           Acetyl-CoA carboxylase 2
# 66         67                           Acetyl-CoA carboxylase 2
# 67         68                           Acetyl-CoA carboxylase 2
# 68         69                           Acetyl-CoA carboxylase 2
# 116       117                         creatine kinase BB isoform
# 117       118                         creatine kinase BB isoform
# 118       119                         creatine kinase BB isoform
# 119       120                         creatine kinase MM isoform
# 120       121                         creatine kinase MM isoform
# 121       122           ubiquitous mitochondrial creatine kinase
# 122       123           ubiquitous mitochondrial creatine kinase
# 123       124           sarcomeric mitochondrial creatine kinase
# 124       125           sarcomeric mitochondrial creatine kinase
# 120       121  KetohexokinaseImported\n\n<p>Manually validate...
# 121       122  KetohexokinaseImported\n\n<p>Manually validate...
#
#                                  Reaction ID  Enzymatic Activity EC Number  \
# 28                                       NaN                 NaN   1.1.1.1
# 29                                       NaN                 NaN   1.1.1.1
# 36                                       NaN                 NaN   1.1.1.1
# 41                                       NaN                 NaN   1.1.1.1
# 42                                       NaN                 NaN   1.1.1.1
# 43                                       NaN                 NaN   1.1.1.1
# 44                                       NaN                 NaN   1.1.1.1
# 58                                       NaN                 NaN   1.1.1.1
# 59                                       NaN                 NaN   1.1.1.1
# 60                                       NaN                 NaN   1.1.1.1
# 61                                       NaN                 NaN   1.1.1.1
# 62                                       NaN                 NaN   1.1.1.1
# 63                                       NaN                 NaN   1.1.1.1
# 64                                       NaN                 NaN   1.1.1.1
# 71                                       NaN                 NaN   1.1.1.1
# 72                                       NaN                 NaN   1.1.1.1
# 73                                       NaN                 NaN   1.1.1.1
# 74                                       NaN                 NaN   1.1.1.1
# 75                                       NaN                 NaN   1.1.1.1
# 76                                       NaN                 NaN   1.1.1.1
# 77                                       NaN                 NaN   1.1.1.1
# 78                                       NaN                 NaN   1.1.1.1
# 79                                       NaN                 NaN   1.1.1.1
# 80                                       NaN                 NaN   1.1.1.1
# 81                                       NaN                 NaN   1.1.1.1
# 82                                       NaN                 NaN   1.1.1.1
# 83                                       NaN                 NaN   1.1.1.1
# 84                                       NaN                 NaN   1.1.1.1
# 85                                       NaN                 NaN   1.1.1.1
# 86                                       NaN                 NaN   1.1.1.1
# ..                                       ...                 ...       ...
# 63                                       NaN                 NaN   6.3.2.2
# 64                                       NaN                 NaN   6.3.2.2
# 65                                       NaN                 NaN   6.3.2.2
# 26                                       NaN                 NaN   6.3.4.5
# 27                                       NaN                 NaN   6.3.4.5
# 28                                       NaN                 NaN   6.3.4.5
# 144             Citrulline--aspartate ligase                 NaN       NaN
# 145             Citrulline--aspartate ligase                 NaN       NaN
# 41                 Biotin apo-protein ligase                 NaN       NaN
# 14   NAD(+) synthase [glutamine-hydrolyzing]                 NaN       NaN
# 15   NAD(+) synthase [glutamine-hydrolyzing]                 NaN       NaN
# 16   NAD(+) synthase [glutamine-hydrolyzing]                 NaN       NaN
# 17   NAD(+) synthase [glutamine-hydrolyzing]                 NaN       NaN
# 63                                  ACC-beta                 NaN       NaN
# 64                                  ACC-beta                 NaN       NaN
# 65                                  ACC-beta                 NaN       NaN
# 66                                  ACC-beta                 NaN       NaN
# 67                                  ACC-beta                 NaN       NaN
# 68                                  ACC-beta                 NaN       NaN
# 116                                      NaN                 NaN   2.7.3.2
# 117                                      NaN                 NaN   2.7.3.2
# 118                                      NaN                 NaN   2.7.3.2
# 119                                      NaN                 NaN   2.7.3.2
# 120                                      NaN                 NaN   2.7.3.2
# 121                                      NaN                 NaN   2.7.3.2
# 122                                      NaN                 NaN   2.7.3.2
# 123                                      NaN                 NaN   2.7.3.2
# 124                                      NaN                 NaN   2.7.3.2
# 120                     Hepatic fructokinase                 NaN       NaN
# 121                     Hepatic fructokinase                 NaN       NaN
#
#         Gene      Organism Strain/Tissue  \
# 28       NaN  Homo sapiens           NaN
# 29       NaN  Homo sapiens           NaN
# 36       NaN  Homo sapiens           NaN
# 41       NaN  Homo sapiens           NaN
# 42       NaN  Homo sapiens           NaN
# 43       NaN  Homo sapiens           NaN
# 44       NaN  Homo sapiens           NaN
# 58       NaN  Homo sapiens           NaN
# 59       NaN  Homo sapiens           NaN
# 60       NaN  Homo sapiens           NaN
# 61       NaN  Homo sapiens           NaN
# 62       NaN  Homo sapiens           NaN
# 63       NaN  Homo sapiens           NaN
# 64       NaN  Homo sapiens           NaN
# 71       NaN  Homo sapiens           NaN
# 72       NaN  Homo sapiens           NaN
# 73       NaN  Homo sapiens           NaN
# 74       NaN  Homo sapiens           NaN
# 75       NaN  Homo sapiens           NaN
# 76       NaN  Homo sapiens           NaN
# 77       NaN  Homo sapiens           NaN
# 78       NaN  Homo sapiens           NaN
# 79       NaN  Homo sapiens           NaN
# 80       NaN  Homo sapiens           NaN
# 81       NaN  Homo sapiens           NaN
# 82       NaN  Homo sapiens           NaN
# 83       NaN  Homo sapiens           NaN
# 84       NaN  Homo sapiens           NaN
# 85       NaN  Homo sapiens           NaN
# 86       NaN  Homo sapiens           NaN
# ..       ...           ...           ...
# 63      GCLC  Homo sapiens           NaN
# 64      GCLC  Homo sapiens           NaN
# 65      GCLC  Homo sapiens           NaN
# 26      ASS1  Homo sapiens           NaN
# 27      ASS1  Homo sapiens           NaN
# 28      ASS1  Homo sapiens           NaN
# 144     ASS1  Homo sapiens         Human
# 145     ASS1  Homo sapiens         Human
# 41      HLCS  Homo sapiens         Human
# 14   NADSYN1  Homo sapiens         Human
# 15   NADSYN1  Homo sapiens         Human
# 16   NADSYN1  Homo sapiens         Human
# 17   NADSYN1  Homo sapiens         Human
# 63     ACACB  Homo sapiens         Human
# 64     ACACB  Homo sapiens         Human
# 65     ACACB  Homo sapiens         Human
# 66     ACACB  Homo sapiens         Human
# 67     ACACB  Homo sapiens         Human
# 68     ACACB  Homo sapiens         Human
# 116      CKB  Homo sapiens           NaN
# 117      CKB  Homo sapiens           NaN
# 118      CKB  Homo sapiens           NaN
# 119      CKM  Homo sapiens           NaN
# 120      CKM  Homo sapiens           NaN
# 121   CKMT1B  Homo sapiens           NaN
# 122   CKMT1B  Homo sapiens           NaN
# 123    CKMT2  Homo sapiens           NaN
# 124    CKMT2  Homo sapiens           NaN
# 120      KHK  Homo sapiens         Human
# 121      KHK  Homo sapiens         Human
#
#                                               Reaction      Cofactor   ...    \
# 28   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 29   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 36   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 41   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 42   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 43   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 44   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 58   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 59   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 60   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 61   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 62   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 63   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 64   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 71   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 72   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 73   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 74   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 75   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 76   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 77   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 78   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 79   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 80   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 81   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 82   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 83   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 84   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 85   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 86   a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# ..                                                 ...           ...   ...
# 63   L-glutamate + L-cysteine + ATP  →  γ-L-glutamy...           NaN   ...
# 64   L-glutamate + L-cysteine + ATP  →  γ-L-glutamy...           NaN   ...
# 65   L-glutamate + L-cysteine + ATP  →  γ-L-glutamy...           NaN   ...
# 26   L-aspartate + L-citrulline + ATP  →  L-arginin...           NaN   ...
# 27   L-aspartate + L-citrulline + ATP  →  L-arginin...           NaN   ...
# 28   L-aspartate + L-citrulline + ATP  →  L-arginin...           NaN   ...
# 144  ATP + L-citrulline + L-aspartate = AMP + dipho...           NaN   ...
# 145  ATP + L-citrulline + L-aspartate = AMP + dipho...           NaN   ...
# 41   ATP + biotin + apo-[methylmalonyl-CoA:pyruvate...           NaN   ...
# 14   ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 15   ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 16   ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 17   ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 63   ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 64   ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 65   ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 66   ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 67   ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 68   ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 116  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 117  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 118  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 119  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 120  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 121  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 122  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 123  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 124  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 120    ATP + D-fructose = ADP + D-fructose 1-phosphate           NaN   ...
# 121    ATP + D-fructose = ADP + D-fructose 1-phosphate           NaN   ...
#
#                              pH Temp (°C) Buffer/Media         Uniprot  \
# 28                          7.5      25.0          NaN             NaN
# 29                          7.5      25.0          NaN             NaN
# 36                          NaN       NaN          NaN             NaN
# 41                          NaN      23.0          NaN  P00326, P08319
# 42                          NaN      23.0          NaN  P00326, P08319
# 43                          NaN      23.0          NaN  P00326, P08319
# 44                          NaN      23.0          NaN  P00326, P08319
# 58                          NaN      23.0          NaN  P00326, P08319
# 59                          NaN      23.0          NaN  P00326, P08319
# 60                          NaN      23.0          NaN  P00326, P08319
# 61                          NaN      23.0          NaN  P00326, P08319
# 62                          7.5      25.0          NaN             NaN
# 63                          7.5      25.0          NaN             NaN
# 64                          7.5      25.0          NaN             NaN
# 71                          7.5      25.0          NaN             NaN
# 72                          7.5      25.0          NaN             NaN
# 73                          NaN       NaN          NaN             NaN
# 74                          NaN       NaN          NaN             NaN
# 75                          NaN       NaN          NaN             NaN
# 76                          NaN       NaN          NaN             NaN
# 77                          NaN      23.0          NaN  P00326, P08319
# 78                          NaN       NaN          NaN             NaN
# 79                          NaN       NaN          NaN             NaN
# 80                          NaN      23.0          NaN  P00326, P08319
# 81                          NaN      23.0          NaN  P00326, P08319
# 82                          7.5      25.0          NaN             NaN
# 83                          7.5      25.0          NaN             NaN
# 84                          7.5      25.0          NaN             NaN
# 85                          NaN       NaN          NaN             NaN
# 86                          7.5      25.0          NaN             NaN
# ..                          ...       ...          ...             ...
# 63   Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 64   Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 65   Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 26            Act. Allosteric;        NaN          NaN             NaN
# 27            Act. Allosteric;        NaN          NaN             NaN
# 28            Act. Allosteric;        NaN          NaN             NaN
# 144                         NaN       7.0          NaN             NaN
# 145                         NaN       7.0          NaN             NaN
# 41                          NaN       NaN          NaN             NaN
# 14                          NaN       NaN          NaN             NaN
# 15                          NaN       NaN          NaN             NaN
# 16                          NaN       NaN          NaN             NaN
# 17                          NaN       NaN          NaN             NaN
# 63                          NaN       NaN          NaN             NaN
# 64                          NaN       NaN          NaN             NaN
# 65                          NaN       NaN          NaN             NaN
# 66                          NaN       NaN          NaN             NaN
# 67                          NaN       NaN          NaN             NaN
# 68                          NaN       NaN          NaN             NaN
# 116  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 117  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 118  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 119                         NaN       NaN          NaN             NaN
# 120                         NaN       NaN          NaN             NaN
# 121                         NaN       NaN          NaN             NaN
# 122                         NaN       NaN          NaN             NaN
# 123                         NaN       NaN          NaN             NaN
# 124                         NaN       NaN          NaN             NaN
# 120                         NaN       NaN           25             NaN
# 121                         NaN       NaN           25             NaN
#
#      References Data Point                                          Notes  \
# 28          RF4        NaN                                 isozyme ADH1B2
# 29          RF4        NaN                                 isozyme ADH1B1
# 36          RF7        NaN                                            NaN
# 41          RF2        NaN                           isozyme ADH1C at 21-
# 42          RF2        NaN                            isozyme ADH2 at 21-
# 43          RF2        NaN                            isozyme ADH4 at 21-
# 44          RF2        NaN                            isozyme ADH3 at 21-
# 58          RF2        NaN                            isozyme ADH3 at 21-
# 59          RF2        NaN                           isozyme ADH1C at 21-
# 60          RF2        NaN                            isozyme ADH4 at 21-
# 61          RF2        NaN                            isozyme ADH2 at 21-
# 62          RF8        NaN                                              4
# 63          RF8        NaN                                            1B1
# 64          RF8        NaN                                            1B2
# 71          RF4        NaN                                 isozyme ADH1B1
# 72          RF4        NaN                                 isozyme ADH1B2
# 73          RF1        NaN                           isoenzyme beta1beta1
# 74          RF1        NaN  isoenzyme gamma2gamma2; isoenzymes beta2beta2
# 75          RF1        NaN                          isoenzymes beta2beta2
# 76          RF1        NaN                         isoenzyme gamma1gamma1
# 77          RF2        NaN                           isozyme ADH1C at 21-
# 78          RF1        NaN                           isoenzyme beta3beta3
# 79          RF1        NaN                           isoenzyme alphaalpha
# 80          RF2        NaN                            isozyme ADH4 at 21-
# 81          RF2        NaN                            isozyme ADH2 at 21-
# 82          RF8        NaN                                            1B1
# 83          RF8        NaN                                            1B2
# 84          RF8        NaN                                              4
# 85          RF1        NaN                                            NaN
# 86          RF8        NaN                                              4
# ..          ...        ...                                            ...
# 63       P48506        RF1                                            NaN
# 64       P48506        RF1                                            NaN
# 65       P48506        RF1                                            NaN
# 26       P00966        RF6                                            NaN
# 27       P00966        RF6                                            NaN
# 28       P00966        RF6                                            NaN
# 144      P00966       RF11                                            NaN
# 145      P00966       RF11                                            NaN
# 41       P50747        RF2                                            NaN
# 14       Q6IA69        RF2                                            NaN
# 15       Q6IA69        RF2                                            NaN
# 16       Q6IA69        RF2                                            NaN
# 17       Q6IA69        RF2                                            NaN
# 63       O00763        RF5                                            NaN
# 64       O00763        RF5                                            NaN
# 65       O00763        RF5                                            NaN
# 66       O00763        RF5                                            NaN
# 67       O00763        RF5                                            NaN
# 68       O00763        RF5                                            NaN
# 116      P12277       RF14                                            NaN
# 117      P12277       RF14                                            NaN
# 118      P12277       RF14                                            NaN
# 119      P06732       RF15                                            NaN
# 120      P06732       RF15                                            NaN
# 121      P12532        RF2                                            NaN
# 122      P12532        RF2                                            NaN
# 123      P17540        RF2                                            NaN
# 124      P17540        RF2                                            NaN
# 120      P50053        RF1                                            NaN
# 121      P50053        RF1                                            NaN
#
#     BIGG ID     BIGG NAME KEEPing
# 28      NaN           NaN       X
# 29      NaN           NaN       X
# 36      NaN           NaN       X
# 41      NaN           NaN       X
# 42      NaN           NaN       X
# 43      NaN           NaN       X
# 44      NaN           NaN       X
# 58      NaN           NaN       X
# 59      NaN           NaN       X
# 60      NaN           NaN       X
# 61      NaN           NaN       X
# 62      NaN           NaN       X
# 63      NaN           NaN       X
# 64      NaN           NaN       X
# 71      NaN           NaN       X
# 72      NaN           NaN       X
# 73    acald  acetaldehyde     NaN
# 74    acald  acetaldehyde     NaN
# 75    acald  acetaldehyde     NaN
# 76    acald  acetaldehyde     NaN
# 77    acald  acetaldehyde     NaN
# 78    acald  acetaldehyde     NaN
# 79    acald  acetaldehyde     NaN
# 80    acald  acetaldehyde     NaN
# 81    acald  acetaldehyde     NaN
# 82      NaN           NaN       X
# 83      NaN           NaN       X
# 84      NaN           NaN       X
# 85      NaN           NaN       X
# 86      NaN           NaN       X
# ..      ...           ...     ...
# 63      NaN           NaN     NaN
# 64      NaN           NaN     NaN
# 65      NaN           NaN     NaN
# 26      NaN           NaN     NaN
# 27      NaN           NaN     NaN
# 28      NaN           NaN     NaN
# 144     NaN           NaN     NaN
# 145     NaN           NaN     NaN
# 41      NaN           NaN     NaN
# 14      NaN           NaN     NaN
# 15      NaN           NaN     NaN
# 16      NaN           NaN     NaN
# 17      NaN           NaN     NaN
# 63      NaN           NaN     NaN
# 64      NaN           NaN     NaN
# 65      NaN           NaN     NaN
# 66      NaN           NaN     NaN
# 67      NaN           NaN     NaN
# 68      NaN           NaN     NaN
# 116     NaN           NaN     NaN
# 117     NaN           NaN     NaN
# 118     NaN           NaN     NaN
# 119     NaN           NaN     NaN
# 120     NaN           NaN     NaN
# 121     NaN           NaN     NaN
# 122     NaN           NaN     NaN
# 123     NaN           NaN     NaN
# 124     NaN           NaN     NaN
# 120     NaN           NaN     NaN
# 121     NaN           NaN     NaN
#
# [8762 rows x 29 columns]

# %% [markdown]
# * Now what we need to do
#
#
#     * Function goal:
#     for every ec in kinetic data["ec"]
#         for every ec in df
#             if df list
#                 if ec in list
#                     append row#locationindf
#             if df string
#                 if  ec==str
#                     append row#locationindf
#
#
#    * Kinetic DF has non consecutive and repeating indexes right now
#        * RESET

# %%
Kinetic_df.index
# Out:
# Int64Index([ 28,  29,  36,  41,  42,  43,  44,  58,  59,  60,
#             ...
#             117, 118, 119, 120, 121, 122, 123, 124, 120, 121],
#            dtype='int64', length=8762)

# %%
Kinetic_df.index=range(len(Kinetic_df.index))
df_EC.index=range(len(df_EC.index))

# %%
Kinetic_df=Kinetic_df.rename(columns={"EC Number": "EC_Number"})
Kinetic_df.columns = Kinetic_df.columns.str.strip()
df_EC.columns = df_EC.columns.str.strip()

# %%
### Lets try a data frame approach--> dictionary
# want loc in df_ec for every input from kinetic

def dataframe_find_loc(df1,df1_col, df2, df2_col): 
    dictionary={}
    loc_list=[]
    for row_val1 in df1[df1_col]:
        df1_row_=str(row_val1)
        lookupstring=re.compile(df1_row_)
        loc=[]
        for row_2 in range(len(df2[df2_col])):
            lookin_string=str(df2[df2_col][row_2])
            match=lookupstring.search(lookin_string)
            if match!=None and [row_2, df2_col] not in loc:
                loc.append([row_2, df2_col])
        
        dictionary[df1_row_]=loc
        #rxns.append(df1_row_)
        #loc_list.append(loc)
                
    #all_matches.append(match_rxn)
    return dictionary

# %%
dictionary =dataframe_find_loc(Kinetic_df,"EC_Number", df_EC, "EC_Comp")

# %%
# LOTS OF sanity check

print (len(dictionary.keys()))
key_list=[dictionary.keys]
# Out:
# 405

# %%
print (len(dictionary.keys()))
key_list=[dictionary.keys]
# Out:
# 405

# %%
len(Kinetic_df["EC_Number"].unique())
# Out:
# 405

# %%
dictionary["1.1.1.1"]
# Out:
# [[2, 'EC_Comp'], [64, 'EC_Comp']]

# %%
dictionary.items()
# Out:
# dict_items([('1.1.1.1', [[2, 'EC_Comp'], [64, 'EC_Comp']]), ('1.1.1.2', [[2, 'EC_Comp'], [70, 'EC_Comp'], [79, 'EC_Comp'], [142, 'EC_Comp'], [180, 'EC_Comp'], [181, 'EC_Comp']]), ('1.1.1.8', [[64, 'EC_Comp'], [120, 'EC_Comp']]), ('1.1.1.10', [[2, 'EC_Comp']]), ('1.1.1.14', []), ('1.1.1.19', []), ('1.1.1.21', []), ('1.1.1.22', []), ('1.1.1.27', [[180, 'EC_Comp']]), ('1.1.1.31', [[66, 'EC_Comp']]), ('1.1.1.34', [[189, 'EC_Comp']]), ('1.1.1.35', [[63, 'EC_Comp'], [64, 'EC_Comp']]), ('1.1.1.37', [[79, 'EC_Comp'], [181, 'EC_Comp']]), ('1.1.1.38', []), ('1.1.1.39', []), ('1.1.1.40', [[80, 'EC_Comp'], [81, 'EC_Comp']]), ('1.1.1.41', [[70, 'EC_Comp']]), ('1.1.1.42', [[71, 'EC_Comp']]), ('1.1.1.44', []), ('1.1.1.45', []), ('1.1.1.49', [[133, 'EC_Comp']]), ('1.1.1.50', []), ('1.1.1.51', []), ('1.1.1.62', []), ('1.1.1.64', []), ('1.1.1.71', []), ('1.1.1.79', []), ('1.1.1.95', [[103, 'EC_Comp']]), ('nan', []), ('1.1.1.102', [[2, 'EC_Comp']]), ('1.1.1.105', []), ('1.1.1.145', []), ('1.1.1.146', []), ('1.1.1.149', []), ('1.1.1.153', []), ('1.1.1.184', []), ('1.1.1.189', []), ('1.1.1.197', []), ('1.1.1.205', [[142, 'EC_Comp']]), ('1.1.1.209', []), ('1.1.1.213', []), ('1.1.1.239', []), ('1.1.1.300', []), ('1.1.1.315', []), ('1.1.3.15', []), ('1.2.1.3', [[5, 'EC_Comp'], [116, 'EC_Comp']]), ('1.2.1.5', [[0, 'EC_Comp'], [18, 'EC_Comp'], [102, 'EC_Comp'], [135, 'EC_Comp']]), ('1.2.1.8', [[98, 'EC_Comp']]), ('1.2.1.12', [[135, 'EC_Comp']]), ('1.2.1.19', []), ('1.2.1.24', []), ('1.2.1.25', [[93, 'EC_Comp'], [94, 'EC_Comp'], [95, 'EC_Comp']]), ('1.2.1.31', [[5, 'EC_Comp']]), ('1.2.1.36', []), ('1.2.1.47', []), ('1.2.1.88', [[98, 'EC_Comp']]), ('1.2.3.1', []), ('1.2.4.1', [[102, 'EC_Comp']]), ('1.2.4.2', [[0, 'EC_Comp'], [18, 'EC_Comp']]), ('1.3.1.2', [[34, 'EC_Comp']]), ('1.3.1.3', []), ('1.3.1.21', [[34, 'EC_Comp']]), ('1.3.1.22', []), ('1.3.3.3', []), ('1.3.3.4', []), ('1.3.3.6', []), ('1.3.8.1', []), ('1.3.8.4', [[11, 'EC_Comp']]), ('1.3.8.6', [[57, 'EC_Comp']]), ('1.3.8.7', [[11, 'EC_Comp']]), ('1.4.1.3', [[54, 'EC_Comp'], [55, 'EC_Comp']]), ('1.4.3.1', []), ('1.4.3.3', []), ('1.4.3.4', []), ('1.4.3.5', []), ('1.4.3.21', []), ('1.4.3.22', []), ('1.5.1.2', [[99, 'EC_Comp']]), ('1.5.1.3', [[119, 'EC_Comp'], [127, 'EC_Comp'], [129, 'EC_Comp']]), ('1.5.1.5', [[145, 'EC_Comp']]), ('1.5.1.6', [[45, 'EC_Comp']]), ('1.5.1.8', [[107, 'EC_Comp']]), ('1.5.1.9', [[108, 'EC_Comp']]), ('1.5.1.15', [[89, 'EC_Comp']]), ('1.5.1.20', []), ('1.5.1.34', [[129, 'EC_Comp']]), ('1.6.3.1', []), ('1.7.1.7', []), ('1.8.1.4', [[0, 'EC_Comp'], [18, 'EC_Comp'], [52, 'EC_Comp'], [102, 'EC_Comp']]), ('1.8.1.7', []), ('1.8.1.9', [[114, 'EC_Comp']]), ('1.11.1.6', []), ('1.11.1.7', []), ('1.11.1.8', []), ('1.11.1.9', []), ('1.13.11.5', [[65, 'EC_Comp'], [115, 'EC_Comp']]), ('1.13.11.11', [[115, 'EC_Comp']]), ('1.13.11.20', []), ('1.13.11.33', []), ('1.13.11.34', []), ('1.13.11.52', [[115, 'EC_Comp']]), ('1.13.11.63', []), ('1.13.99.1', []), ('1.14.11.1', []), ('1.14.11.2', []), ('1.14.11.18', []), ('1.14.13.9', [[74, 'EC_Comp']]), ('1.14.13.15', []), ('1.14.13.39', []), ('1.14.13.98', []), ('1.14.14.1', [[110, 'EC_Comp']]), ('1.14.15.4', []), ('1.14.15.6', []), ('1.14.16.1', []), ('1.14.17.1', []), ('1.14.18.1', []), ('1.14.99.9', []), ('1.14.99.36', []), ('1.15.1.1', []), ('1.16.1.3', []), ('1.17.1.4', []), ('1.17.3.2', []), ('2.1.1.1', []), ('2.1.1.5', []), ('2.1.1.6', []), ('2.1.1.20', []), ('2.1.1.28', []), ('2.1.1.37', []), ('2.1.1.45', [[186, 'EC_Comp']]), ('2.1.1.49', []), ('2.1.2.1', [[51, 'EC_Comp'], [136, 'EC_Comp']]), ('2.1.2.3', [[176, 'EC_Comp'], [179, 'EC_Comp']]), ('2.1.3.3', [[92, 'EC_Comp']]), ('2.1.4.1', [[59, 'EC_Comp']]), ('2.2.1.1', [[170, 'EC_Comp'], [171, 'EC_Comp']]), ('2.3.1.1', [[7, 'EC_Comp'], [102, 'EC_Comp']]), ('2.3.1.4', [[73, 'EC_Comp']]), ('2.3.1.6', [[0, 'EC_Comp'], [18, 'EC_Comp']]), ('2.3.1.7', [[32, 'EC_Comp'], [33, 'EC_Comp']]), ('2.3.1.9', [[7, 'EC_Comp'], [8, 'EC_Comp'], [121, 'EC_Comp']]), ('2.3.1.16', [[7, 'EC_Comp']]), ('2.3.1.17', []), ...

# %%
count=0
for ec, loc in dictionary.items():
    if loc==[]:
        count+=1
    print (ec, loc)
# Out:
# 1.1.1.1 [[2, 'EC_Comp'], [64, 'EC_Comp']]
# 1.1.1.2 [[2, 'EC_Comp'], [70, 'EC_Comp'], [79, 'EC_Comp'], [142, 'EC_Comp'], [180, 'EC_Comp'], [181, 'EC_Comp']]
# 1.1.1.8 [[64, 'EC_Comp'], [120, 'EC_Comp']]
# 1.1.1.10 [[2, 'EC_Comp']]
# 1.1.1.14 []
# 1.1.1.19 []
# 1.1.1.21 []
# 1.1.1.22 []
# 1.1.1.27 [[180, 'EC_Comp']]
# 1.1.1.31 [[66, 'EC_Comp']]
# 1.1.1.34 [[189, 'EC_Comp']]
# 1.1.1.35 [[63, 'EC_Comp'], [64, 'EC_Comp']]
# 1.1.1.37 [[79, 'EC_Comp'], [181, 'EC_Comp']]
# 1.1.1.38 []
# 1.1.1.39 []
# 1.1.1.40 [[80, 'EC_Comp'], [81, 'EC_Comp']]
# 1.1.1.41 [[70, 'EC_Comp']]
# 1.1.1.42 [[71, 'EC_Comp']]
# 1.1.1.44 []
# 1.1.1.45 []
# 1.1.1.49 [[133, 'EC_Comp']]
# 1.1.1.50 []
# 1.1.1.51 []
# 1.1.1.62 []
# 1.1.1.64 []
# 1.1.1.71 []
# 1.1.1.79 []
# 1.1.1.95 [[103, 'EC_Comp']]
# nan []
# 1.1.1.102 [[2, 'EC_Comp']]
# 1.1.1.105 []
# 1.1.1.145 []
# 1.1.1.146 []
# 1.1.1.149 []
# 1.1.1.153 []
# 1.1.1.184 []
# 1.1.1.189 []
# 1.1.1.197 []
# 1.1.1.205 [[142, 'EC_Comp']]
# 1.1.1.209 []
# 1.1.1.213 []
# 1.1.1.239 []
# 1.1.1.300 []
# 1.1.1.315 []
# 1.1.3.15 []
# 1.2.1.3 [[5, 'EC_Comp'], [116, 'EC_Comp']]
# 1.2.1.5 [[0, 'EC_Comp'], [18, 'EC_Comp'], [102, 'EC_Comp'], [135, 'EC_Comp']]
# 1.2.1.8 [[98, 'EC_Comp']]
# 1.2.1.12 [[135, 'EC_Comp']]
# 1.2.1.19 []
# 1.2.1.24 []
# 1.2.1.25 [[93, 'EC_Comp'], [94, 'EC_Comp'], [95, 'EC_Comp']]
# 1.2.1.31 [[5, 'EC_Comp']]
# 1.2.1.36 []
# 1.2.1.47 []
# 1.2.1.88 [[98, 'EC_Comp']]
# 1.2.3.1 []
# 1.2.4.1 [[102, 'EC_Comp']]
# 1.2.4.2 [[0, 'EC_Comp'], [18, 'EC_Comp']]
# 1.3.1.2 [[34, 'EC_Comp']]
# 1.3.1.3 []
# 1.3.1.21 [[34, 'EC_Comp']]
# 1.3.1.22 []
# 1.3.3.3 []
# 1.3.3.4 []
# 1.3.3.6 []
# 1.3.8.1 []
# 1.3.8.4 [[11, 'EC_Comp']]
# 1.3.8.6 [[57, 'EC_Comp']]
# 1.3.8.7 [[11, 'EC_Comp']]
# 1.4.1.3 [[54, 'EC_Comp'], [55, 'EC_Comp']]
# 1.4.3.1 []
# 1.4.3.3 []
# 1.4.3.4 []
# 1.4.3.5 []
# 1.4.3.21 []
# 1.4.3.22 []
# 1.5.1.2 [[99, 'EC_Comp']]
# 1.5.1.3 [[119, 'EC_Comp'], [127, 'EC_Comp'], [129, 'EC_Comp']]
# 1.5.1.5 [[145, 'EC_Comp']]
# 1.5.1.6 [[45, 'EC_Comp']]
# 1.5.1.8 [[107, 'EC_Comp']]
# 1.5.1.9 [[108, 'EC_Comp']]
# 1.5.1.15 [[89, 'EC_Comp']]
# 1.5.1.20 []
# 1.5.1.34 [[129, 'EC_Comp']]
# 1.6.3.1 []
# 1.7.1.7 []
# 1.8.1.4 [[0, 'EC_Comp'], [18, 'EC_Comp'], [52, 'EC_Comp'], [102, 'EC_Comp']]
# 1.8.1.7 []
# 1.8.1.9 [[114, 'EC_Comp']]
# 1.11.1.6 []
# 1.11.1.7 []
# 1.11.1.8 []
# 1.11.1.9 []
# 1.13.11.5 [[65, 'EC_Comp'], [115, 'EC_Comp']]
# 1.13.11.11 [[115, 'EC_Comp']]
# 1.13.11.20 []
# 1.13.11.33 []
# 1.13.11.34 []
# 1.13.11.52 [[115, 'EC_Comp']]
# 1.13.11.63 []
# 1.13.99.1 []
# 1.14.11.1 []
# 1.14.11.2 []
# 1.14.11.18 []
# 1.14.13.9 [[74, 'EC_Comp']]
# 1.14.13.15 []
# 1.14.13.39 []
# 1.14.13.98 []
# 1.14.14.1 [[110, 'EC_Comp']]
# 1.14.15.4 []
# 1.14.15.6 []
# 1.14.16.1 []
# 1.14.17.1 []
# 1.14.18.1 []
# 1.14.99.9 []
# 1.14.99.36 []
# 1.15.1.1 []
# 1.16.1.3 []
# 1.17.1.4 []
# 1.17.3.2 []
# 2.1.1.1 []
# 2.1.1.5 []
# 2.1.1.6 []
# 2.1.1.20 []
# 2.1.1.28 []
# 2.1.1.37 []
# 2.1.1.45 [[186, 'EC_Comp']]
# 2.1.1.49 []
# 2.1.2.1 [[51, 'EC_Comp'], [136, 'EC_Comp']]
# 2.1.2.3 [[176, 'EC_Comp'], [179, 'EC_Comp']]
# 2.1.3.3 [[92, 'EC_Comp']]
# 2.1.4.1 [[59, 'EC_Comp']]
# 2.2.1.1 [[170, 'EC_Comp'], [171, 'EC_Comp']]
# 2.3.1.1 [[7, 'EC_Comp'], [102, 'EC_Comp']]
# 2.3.1.4 [[73, 'EC_Comp']]
# 2.3.1.6 [[0, 'EC_Comp'], [18, 'EC_Comp']]
# 2.3.1.7 [[32, 'EC_Comp'], [33, 'EC_Comp']]
# 2.3.1.9 [[7, 'EC_Comp'], [8, 'EC_Comp'], [121, 'EC_Comp']]
# 2.3.1.16 [[7, 'EC_Comp']]
# 2.3.1.17 []
# 2.3.1.21 []
# 2.3.1.37 [[60, 'EC_Comp']]
# 2.3.1.41 [[73, 'EC_Comp']]
# 2.3.1.50 [[109, 'EC_Comp']]
# 2.3.1.51 []
# 2.3.1.57 []
# 2.3.1.65 []
# 2.3.1.85 [[73, 'EC_Comp']]
# 2.3.1.87 []
# 2.3.2.2 []
# 2.3.3.8 [[9, 'EC_Comp']]
# 2.3.3.10 [[68, 'EC_Comp']]
# 2.4.1.17 []
# 2.4.1.22 []
# 2.4.1.69 []
# 2.4.1.95 []
# 2.4.2.1 [[97, 'EC_Comp'], [178, 'EC_Comp']]
# 2.4.2.3 []
# 2.4.2.4 []
# 2.4.2.7 []
# 2.4.2.8 []
# 2.4.2.10 [[97, 'EC_Comp']]
# 2.4.2.12 []
# 2.4.2.14 [[178, 'EC_Comp']]
# 2.4.2.19 []
# 2.4.2.28 []
# 2.5.1.6 []
# 2.5.1.17 []
# 2.5.1.21 [[111, 'EC_Comp']]
# 2.5.1.22 []
# 2.5.1.29 []
# 2.5.1.57 []
# 2.5.1.61 []
# 2.6.1.1 [[26, 'EC_Comp'], [96, 'EC_Comp'], [124, 'EC_Comp'], [187, 'EC_Comp']]
# 2.6.1.2 [[19, 'EC_Comp']]
# 2.6.1.5 [[161, 'EC_Comp'], [187, 'EC_Comp']]
# 2.6.1.7 []
# 2.6.1.13 [[96, 'EC_Comp']]
# 2.6.1.16 []
# 2.6.1.19 []
# 2.6.1.39 [[6, 'EC_Comp']]
# 2.6.1.42 [[141, 'EC_Comp'], [143, 'EC_Comp'], [174, 'EC_Comp']]
# 2.6.1.44 []
# 2.7.1.1 [[140, 'EC_Comp'], [183, 'EC_Comp']]
# 2.7.1.2 [[140, 'EC_Comp']]
# 2.7.1.6 []
# 2.7.1.11 [[183, 'EC_Comp']]
# 2.7.1.15 []
# 2.7.1.20 []
# 2.7.1.21 []
# 2.7.1.23 []
# 2.7.1.24 []
# 2.7.1.25 []
# 2.7.1.31 []
# 2.7.1.32 [[30, 'EC_Comp']]
# 2.7.1.33 []
# 2.7.1.35 []
# 2.7.1.36 [[82, 'EC_Comp']]
# 2.7.1.40 [[185, 'EC_Comp']]
# 2.7.1.48 []
# 2.7.1.59 []
# 2.7.1.60 []
# 2.7.1.74 []
# 2.7.1.76 []
# 2.7.1.82 []
# 2.7.1.91 []
# 2.7.1.113 []
# 2.7.1.127 []
# 2.7.1.157 []
# 2.7.1.173 []
# 2.7.4.2 [[104, 'EC_Comp'], [173, 'EC_Comp']]
# 2.7.4.3 [[122, 'EC_Comp']]
# 2.7.4.4 [[14, 'EC_Comp'], [173, 'EC_Comp']]
# 2.7.4.6 [[27, 'EC_Comp'], [91, 'EC_Comp'], [146, 'EC_Comp'], [147, 'EC_Comp'], [148, 'EC_Comp'], [149, 'EC_Comp'], [150, 'EC_Comp'], [151, 'EC_Comp'], [152, 'EC_Comp']]
# 2.7.4.8 [[137, 'EC_Comp']]
# 2.7.4.9 [[130, 'EC_Comp']]
# 2.7.4.14 [[173, 'EC_Comp']]
# 2.7.6.1 [[160, 'EC_Comp']]
# 2.7.6.2 []
# 2.7.7.1 [[29, 'EC_Comp']]
# 2.7.7.2 []
# 2.7.7.3 []
# 2.7.7.4 []
# 2.7.7.9 [[134, 'EC_Comp']]
# 2.7.7.12 []
# 2.7.7.18 []
# 2.7.7.23 []
# 2.7.7.30 []
# 2.7.7.43 []
# 2.7.7.83 []
# 2.8.1.1 []
# 2.8.1.2 []
# 2.8.2.1 []
# 2.8.2.2 []
# 2.8.2.4 []
# 2.8.2.11 []
# 2.8.2.14 []
# 2.8.2.15 []
# 3.1.1.7 []
# 3.1.1.8 []
# 3.1.1.84 []
# 3.1.2.2 [[118, 'EC_Comp']]
# 3.1.2.4 [[4, 'EC_Comp']]
# 3.1.2.22 []
# 3.1.3.1 []
# 3.1.3.2 [[182, 'EC_Comp']]
# 3.1.3.3 [[162, 'EC_Comp']]
# 3.1.3.4 []
# 3.1.3.5 []
# 3.1.3.9 []
# 3.1.3.11 []
# 3.1.3.29 []
# 3.1.3.74 []
# 3.1.3.91 []
# 3.1.4.2 []
# 3.1.4.17 []
# 3.1.4.35 []
# 3.1.4.53 []
# 3.1.6.2 []
# 3.2.1.10 []
# 3.2.1.20 []
# 3.2.1.21 []
# 3.2.1.22 []
# 3.2.1.35 []
# 3.2.1.48 []
# 3.2.1.108 []
# 3.2.2.5 []
# 3.2.2.6 []
# 3.3.1.1 []
# 3.3.2.6 []
# 3.4.13.18 []
# 3.4.13.19 []
# 3.4.19.14 []
# 3.5.1.1 [[23, 'EC_Comp']]
# 3.5.1.2 [[56, 'EC_Comp']]
# 3.5.1.14 []
# 3.5.3.1 [[21, 'EC_Comp']]
# 3.5.3.11 []
# 3.5.4.3 []
# 3.5.4.4 []
# 3.5.4.5 []
# 3.5.4.6 []
# 3.5.4.9 [[88, 'EC_Comp'], [144, 'EC_Comp']]
# 3.5.4.10 [[179, 'EC_Comp']]
# 3.5.4.12 []
# 3.5.4.16 []
# 3.5.99.6 []
# 3.6.1.1 [[159, 'EC_Comp']]
# 3.6.1.3 []
# 3.6.1.5 []
# 3.6.1.7 []
# 3.6.1.9 []
# 3.6.1.11 []
# 3.6.1.12 []
# 3.6.1.13 []
# 3.6.1.15 []
# 3.6.1.19 []
# 3.6.1.23 [[90, 'EC_Comp']]
# 3.6.1.28 []
# 3.6.1.39 []
# 3.6.1.52 []
# 3.6.1.64 []
# 3.6.3.21 [[58, 'EC_Comp']]
# 3.6.5.1 []
# 3.6.5.2 []
# 3.6.5.5 []
# 3.7.1.2 [[46, 'EC_Comp']]
# 3.7.1.3 [[67, 'EC_Comp']]
# 4.1.1.9 []
# 4.1.1.15 []
# 4.1.1.22 []
# 4.1.1.23 [[153, 'EC_Comp']]
# 4.1.1.28 []
# 4.1.1.32 []
# 4.1.1.33 [[36, 'EC_Comp']]
# 4.1.1.37 []
# 4.1.2.4 []
# 4.1.2.13 [[132, 'EC_Comp']]
# 4.1.2.27 []
# 4.1.3.4 [[69, 'EC_Comp']]
# 4.2.1.1 [[38, 'EC_Comp'], [39, 'EC_Comp'], [40, 'EC_Comp'], [62, 'EC_Comp'], [83, 'EC_Comp'], [131, 'EC_Comp'], [139, 'EC_Comp']]
# 4.2.1.17 [[38, 'EC_Comp'], [39, 'EC_Comp'], [40, 'EC_Comp']]
# 4.2.1.18 [[83, 'EC_Comp']]
# 4.2.1.22 []
# 4.2.1.24 []
# 4.2.1.47 []
# 4.2.1.75 []
# 4.3.1.17 []
# 4.3.1.19 []
# 4.3.2.1 [[177, 'EC_Comp']]
# 4.3.2.2 [[15, 'EC_Comp'], [16, 'EC_Comp']]
# 4.4.1.1 []
# 4.4.1.20 []
# 4.6.1.1 []
# 4.6.1.2 []
# 4.99.1.1 []
# 5.1.3.2 []
# 5.1.3.8 []
# 5.2.1.2 [[77, 'EC_Comp']]
# 5.3.1.8 []
# 5.3.3.1 []
# 5.3.3.2 [[72, 'EC_Comp']]
# 5.3.3.5 [[37, 'EC_Comp']]
# 5.3.99.2 []
# 5.3.99.3 []
# 5.3.99.4 []
# 5.3.99.5 []
# 5.4.2.2 [[158, 'EC_Comp']]
# 5.4.2.8 [[158, 'EC_Comp']]
# 5.4.2.11 [[157, 'EC_Comp']]
# 5.4.99.2 [[86, 'EC_Comp']]
# 5.5.1.4 [[84, 'EC_Comp']]
# 6.2.1.1 [[188, 'EC_Comp']]
# 6.2.1.2 []
# 6.3.1.2 []
# 6.3.2.2 []
# 6.3.2.5 []
# 6.3.3.2 []
# 6.3.4.2 [[56, 'EC_Comp'], [126, 'EC_Comp']]
# 6.3.4.3 []
# 6.3.4.4 [[123, 'EC_Comp']]
# 6.3.4.5 [[22, 'EC_Comp']]
# 6.3.4.15 []
# 6.3.5.1 []
# 6.3.5.2 [[56, 'EC_Comp'], [138, 'EC_Comp']]
# 6.3.5.4 [[24, 'EC_Comp'], [56, 'EC_Comp']]
# 6.4.1.2 [[175, 'EC_Comp']]
# 6.4.1.3 []
# 6.4.1.4 [[78, 'EC_Comp']]
# 2.7.3.2 []
# 2.7.1.3 [[30, 'EC_Comp'], [82, 'EC_Comp']]
# 6.4.1.1 [[101, 'EC_Comp']]
# 5.3.1.9 [[154, 'EC_Comp']]
# 2.7.2.3 [[155, 'EC_Comp']]
# 5.3.1.1 [[172, 'EC_Comp']]
# 1.2.3.- []
# 1.2.1.- [[93, 'EC_Comp'], [95, 'EC_Comp'], [102, 'EC_Comp']]
# 1.13.11.6 [[3, 'EC_Comp']]
# 1.13.11.11/1.13.11.52 []
# 1.10.3.- []
# 2.1.1.8 []
# 2.5.1.10 [[61, 'EC_Comp']]
# 2.5.1.16 []
# 2.5.1.103 []
# 2.6.1.5/2.6.1.57 []
# 2.7.1.74/2.7.1.76/2.7.1.145 []
# 2.7.1.- []
# 2.7.1.134 []
# 2.7.4.9/2.7.4.12/2.7.4.13 []
# 2.7.4.14/2.7.4.25 []
# 3.1.3.25 [[182, 'EC_Comp']]
# 3.1.3.64 []
# 3.1.3.66 []
# 3.2.1.23/3.2.1.108 []
# 2.7.8.11 []
# 3.5.1.15 []
# 3.6.1.60 []
# 3.6.1.14 []
# 4.1.1.45 [[100, 'EC_Comp']]
# 4.2.1.2 [[47, 'EC_Comp']]
# 4.2.3.12 []
# 5.4.2.7 []
# 5.4.2.3 []

# %%
print ("no matching reaction in model: ", count)
print ("EC to bigg reaction found :", 403-count)
# Out:
# no matching reaction in model:  265
# EC to bigg reaction found : 138

# %%
# add dictionary results to kinetic df
#take a closer look at kinetic df before appending
Kinetic_df
# Out:
#       Entry ID                            Recommended Enzyme Name  \
# 0           29                              alcohol dehydrogenase
# 1           30                              alcohol dehydrogenase
# 2           37                              alcohol dehydrogenase
# 3           42                              alcohol dehydrogenase
# 4           43                              alcohol dehydrogenase
# 5           44                              alcohol dehydrogenase
# 6           45                              alcohol dehydrogenase
# 7           59                              alcohol dehydrogenase
# 8           60                              alcohol dehydrogenase
# 9           61                              alcohol dehydrogenase
# 10          62                              alcohol dehydrogenase
# 11          63                              alcohol dehydrogenase
# 12          64                              alcohol dehydrogenase
# 13          65                              alcohol dehydrogenase
# 14          72                              alcohol dehydrogenase
# 15          73                              alcohol dehydrogenase
# 16          74                              alcohol dehydrogenase
# 17          75                              alcohol dehydrogenase
# 18          76                              alcohol dehydrogenase
# 19          77                              alcohol dehydrogenase
# 20          78                              alcohol dehydrogenase
# 21          79                              alcohol dehydrogenase
# 22          80                              alcohol dehydrogenase
# 23          81                              alcohol dehydrogenase
# 24          82                              alcohol dehydrogenase
# 25          83                              alcohol dehydrogenase
# 26          84                              alcohol dehydrogenase
# 27          85                              alcohol dehydrogenase
# 28          86                              alcohol dehydrogenase
# 29          87                              alcohol dehydrogenase
# ...        ...                                                ...
# 8732        64       glutamate--cysteine ligase catalytic subunit
# 8733        65       glutamate--cysteine ligase catalytic subunit
# 8734        66       glutamate--cysteine ligase catalytic subunit
# 8735        27                         argininosuccinate synthase
# 8736        28                         argininosuccinate synthase
# 8737        29                         argininosuccinate synthase
# 8738       145                  Argininosuccinate synthaseCurated
# 8739       146                  Argininosuccinate synthaseCurated
# 8740        42                             Biotin--protein ligase
# 8741        15              Glutamine-dependent NAD(+) synthetase
# 8742        16              Glutamine-dependent NAD(+) synthetase
# 8743        17              Glutamine-dependent NAD(+) synthetase
# 8744        18              Glutamine-dependent NAD(+) synthetase
# 8745        64                           Acetyl-CoA carboxylase 2
# 8746        65                           Acetyl-CoA carboxylase 2
# 8747        66                           Acetyl-CoA carboxylase 2
# 8748        67                           Acetyl-CoA carboxylase 2
# 8749        68                           Acetyl-CoA carboxylase 2
# 8750        69                           Acetyl-CoA carboxylase 2
# 8751       117                         creatine kinase BB isoform
# 8752       118                         creatine kinase BB isoform
# 8753       119                         creatine kinase BB isoform
# 8754       120                         creatine kinase MM isoform
# 8755       121                         creatine kinase MM isoform
# 8756       122           ubiquitous mitochondrial creatine kinase
# 8757       123           ubiquitous mitochondrial creatine kinase
# 8758       124           sarcomeric mitochondrial creatine kinase
# 8759       125           sarcomeric mitochondrial creatine kinase
# 8760       121  KetohexokinaseImported\n\n<p>Manually validate...
# 8761       122  KetohexokinaseImported\n\n<p>Manually validate...
#
#                                   Reaction ID  Enzymatic Activity EC_Number  \
# 0                                         NaN                 NaN   1.1.1.1
# 1                                         NaN                 NaN   1.1.1.1
# 2                                         NaN                 NaN   1.1.1.1
# 3                                         NaN                 NaN   1.1.1.1
# 4                                         NaN                 NaN   1.1.1.1
# 5                                         NaN                 NaN   1.1.1.1
# 6                                         NaN                 NaN   1.1.1.1
# 7                                         NaN                 NaN   1.1.1.1
# 8                                         NaN                 NaN   1.1.1.1
# 9                                         NaN                 NaN   1.1.1.1
# 10                                        NaN                 NaN   1.1.1.1
# 11                                        NaN                 NaN   1.1.1.1
# 12                                        NaN                 NaN   1.1.1.1
# 13                                        NaN                 NaN   1.1.1.1
# 14                                        NaN                 NaN   1.1.1.1
# 15                                        NaN                 NaN   1.1.1.1
# 16                                        NaN                 NaN   1.1.1.1
# 17                                        NaN                 NaN   1.1.1.1
# 18                                        NaN                 NaN   1.1.1.1
# 19                                        NaN                 NaN   1.1.1.1
# 20                                        NaN                 NaN   1.1.1.1
# 21                                        NaN                 NaN   1.1.1.1
# 22                                        NaN                 NaN   1.1.1.1
# 23                                        NaN                 NaN   1.1.1.1
# 24                                        NaN                 NaN   1.1.1.1
# 25                                        NaN                 NaN   1.1.1.1
# 26                                        NaN                 NaN   1.1.1.1
# 27                                        NaN                 NaN   1.1.1.1
# 28                                        NaN                 NaN   1.1.1.1
# 29                                        NaN                 NaN   1.1.1.1
# ...                                       ...                 ...       ...
# 8732                                      NaN                 NaN   6.3.2.2
# 8733                                      NaN                 NaN   6.3.2.2
# 8734                                      NaN                 NaN   6.3.2.2
# 8735                                      NaN                 NaN   6.3.4.5
# 8736                                      NaN                 NaN   6.3.4.5
# 8737                                      NaN                 NaN   6.3.4.5
# 8738             Citrulline--aspartate ligase                 NaN       NaN
# 8739             Citrulline--aspartate ligase                 NaN       NaN
# 8740                Biotin apo-protein ligase                 NaN       NaN
# 8741  NAD(+) synthase [glutamine-hydrolyzing]                 NaN       NaN
# 8742  NAD(+) synthase [glutamine-hydrolyzing]                 NaN       NaN
# 8743  NAD(+) synthase [glutamine-hydrolyzing]                 NaN       NaN
# 8744  NAD(+) synthase [glutamine-hydrolyzing]                 NaN       NaN
# 8745                                 ACC-beta                 NaN       NaN
# 8746                                 ACC-beta                 NaN       NaN
# 8747                                 ACC-beta                 NaN       NaN
# 8748                                 ACC-beta                 NaN       NaN
# 8749                                 ACC-beta                 NaN       NaN
# 8750                                 ACC-beta                 NaN       NaN
# 8751                                      NaN                 NaN   2.7.3.2
# 8752                                      NaN                 NaN   2.7.3.2
# 8753                                      NaN                 NaN   2.7.3.2
# 8754                                      NaN                 NaN   2.7.3.2
# 8755                                      NaN                 NaN   2.7.3.2
# 8756                                      NaN                 NaN   2.7.3.2
# 8757                                      NaN                 NaN   2.7.3.2
# 8758                                      NaN                 NaN   2.7.3.2
# 8759                                      NaN                 NaN   2.7.3.2
# 8760                     Hepatic fructokinase                 NaN       NaN
# 8761                     Hepatic fructokinase                 NaN       NaN
#
#          Gene      Organism Strain/Tissue  \
# 0         NaN  Homo sapiens           NaN
# 1         NaN  Homo sapiens           NaN
# 2         NaN  Homo sapiens           NaN
# 3         NaN  Homo sapiens           NaN
# 4         NaN  Homo sapiens           NaN
# 5         NaN  Homo sapiens           NaN
# 6         NaN  Homo sapiens           NaN
# 7         NaN  Homo sapiens           NaN
# 8         NaN  Homo sapiens           NaN
# 9         NaN  Homo sapiens           NaN
# 10        NaN  Homo sapiens           NaN
# 11        NaN  Homo sapiens           NaN
# 12        NaN  Homo sapiens           NaN
# 13        NaN  Homo sapiens           NaN
# 14        NaN  Homo sapiens           NaN
# 15        NaN  Homo sapiens           NaN
# 16        NaN  Homo sapiens           NaN
# 17        NaN  Homo sapiens           NaN
# 18        NaN  Homo sapiens           NaN
# 19        NaN  Homo sapiens           NaN
# 20        NaN  Homo sapiens           NaN
# 21        NaN  Homo sapiens           NaN
# 22        NaN  Homo sapiens           NaN
# 23        NaN  Homo sapiens           NaN
# 24        NaN  Homo sapiens           NaN
# 25        NaN  Homo sapiens           NaN
# 26        NaN  Homo sapiens           NaN
# 27        NaN  Homo sapiens           NaN
# 28        NaN  Homo sapiens           NaN
# 29        NaN  Homo sapiens           NaN
# ...       ...           ...           ...
# 8732     GCLC  Homo sapiens           NaN
# 8733     GCLC  Homo sapiens           NaN
# 8734     GCLC  Homo sapiens           NaN
# 8735     ASS1  Homo sapiens           NaN
# 8736     ASS1  Homo sapiens           NaN
# 8737     ASS1  Homo sapiens           NaN
# 8738     ASS1  Homo sapiens         Human
# 8739     ASS1  Homo sapiens         Human
# 8740     HLCS  Homo sapiens         Human
# 8741  NADSYN1  Homo sapiens         Human
# 8742  NADSYN1  Homo sapiens         Human
# 8743  NADSYN1  Homo sapiens         Human
# 8744  NADSYN1  Homo sapiens         Human
# 8745    ACACB  Homo sapiens         Human
# 8746    ACACB  Homo sapiens         Human
# 8747    ACACB  Homo sapiens         Human
# 8748    ACACB  Homo sapiens         Human
# 8749    ACACB  Homo sapiens         Human
# 8750    ACACB  Homo sapiens         Human
# 8751      CKB  Homo sapiens           NaN
# 8752      CKB  Homo sapiens           NaN
# 8753      CKB  Homo sapiens           NaN
# 8754      CKM  Homo sapiens           NaN
# 8755      CKM  Homo sapiens           NaN
# 8756   CKMT1B  Homo sapiens           NaN
# 8757   CKMT1B  Homo sapiens           NaN
# 8758    CKMT2  Homo sapiens           NaN
# 8759    CKMT2  Homo sapiens           NaN
# 8760      KHK  Homo sapiens         Human
# 8761      KHK  Homo sapiens         Human
#
#                                                Reaction      Cofactor   ...    \
# 0     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 1     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 2     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 3     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 4     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 5     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 6     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 7     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 8     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 9     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 10    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 11    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 12    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 13    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 14    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 15    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 16    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 17    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 18    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 19    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 20    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 21    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 22    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 23    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 24    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 25    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 26    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 27    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 28    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 29    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# ...                                                 ...           ...   ...
# 8732  L-glutamate + L-cysteine + ATP  →  γ-L-glutamy...           NaN   ...
# 8733  L-glutamate + L-cysteine + ATP  →  γ-L-glutamy...           NaN   ...
# 8734  L-glutamate + L-cysteine + ATP  →  γ-L-glutamy...           NaN   ...
# 8735  L-aspartate + L-citrulline + ATP  →  L-arginin...           NaN   ...
# 8736  L-aspartate + L-citrulline + ATP  →  L-arginin...           NaN   ...
# 8737  L-aspartate + L-citrulline + ATP  →  L-arginin...           NaN   ...
# 8738  ATP + L-citrulline + L-aspartate = AMP + dipho...           NaN   ...
# 8739  ATP + L-citrulline + L-aspartate = AMP + dipho...           NaN   ...
# 8740  ATP + biotin + apo-[methylmalonyl-CoA:pyruvate...           NaN   ...
# 8741  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8742  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8743  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8744  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8745  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8746  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8747  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8748  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8749  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8750  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8751  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8752  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8753  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8754  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8755  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8756  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8757  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8758  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8759  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8760    ATP + D-fructose = ADP + D-fructose 1-phosphate           NaN   ...
# 8761    ATP + D-fructose = ADP + D-fructose 1-phosphate           NaN   ...
#
#                               pH Temp (°C) Buffer/Media         Uniprot  \
# 0                            7.5      25.0          NaN             NaN
# 1                            7.5      25.0          NaN             NaN
# 2                            NaN       NaN          NaN             NaN
# 3                            NaN      23.0          NaN  P00326, P08319
# 4                            NaN      23.0          NaN  P00326, P08319
# 5                            NaN      23.0          NaN  P00326, P08319
# 6                            NaN      23.0          NaN  P00326, P08319
# 7                            NaN      23.0          NaN  P00326, P08319
# 8                            NaN      23.0          NaN  P00326, P08319
# 9                            NaN      23.0          NaN  P00326, P08319
# 10                           NaN      23.0          NaN  P00326, P08319
# 11                           7.5      25.0          NaN             NaN
# 12                           7.5      25.0          NaN             NaN
# 13                           7.5      25.0          NaN             NaN
# 14                           7.5      25.0          NaN             NaN
# 15                           7.5      25.0          NaN             NaN
# 16                           NaN       NaN          NaN             NaN
# 17                           NaN       NaN          NaN             NaN
# 18                           NaN       NaN          NaN             NaN
# 19                           NaN       NaN          NaN             NaN
# 20                           NaN      23.0          NaN  P00326, P08319
# 21                           NaN       NaN          NaN             NaN
# 22                           NaN       NaN          NaN             NaN
# 23                           NaN      23.0          NaN  P00326, P08319
# 24                           NaN      23.0          NaN  P00326, P08319
# 25                           7.5      25.0          NaN             NaN
# 26                           7.5      25.0          NaN             NaN
# 27                           7.5      25.0          NaN             NaN
# 28                           NaN       NaN          NaN             NaN
# 29                           7.5      25.0          NaN             NaN
# ...                          ...       ...          ...             ...
# 8732  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8733  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8734  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8735           Act. Allosteric;        NaN          NaN             NaN
# 8736           Act. Allosteric;        NaN          NaN             NaN
# 8737           Act. Allosteric;        NaN          NaN             NaN
# 8738                         NaN       7.0          NaN             NaN
# 8739                         NaN       7.0          NaN             NaN
# 8740                         NaN       NaN          NaN             NaN
# 8741                         NaN       NaN          NaN             NaN
# 8742                         NaN       NaN          NaN             NaN
# 8743                         NaN       NaN          NaN             NaN
# 8744                         NaN       NaN          NaN             NaN
# 8745                         NaN       NaN          NaN             NaN
# 8746                         NaN       NaN          NaN             NaN
# 8747                         NaN       NaN          NaN             NaN
# 8748                         NaN       NaN          NaN             NaN
# 8749                         NaN       NaN          NaN             NaN
# 8750                         NaN       NaN          NaN             NaN
# 8751  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8752  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8753  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8754                         NaN       NaN          NaN             NaN
# 8755                         NaN       NaN          NaN             NaN
# 8756                         NaN       NaN          NaN             NaN
# 8757                         NaN       NaN          NaN             NaN
# 8758                         NaN       NaN          NaN             NaN
# 8759                         NaN       NaN          NaN             NaN
# 8760                         NaN       NaN           25             NaN
# 8761                         NaN       NaN           25             NaN
#
#       References Data Point                                          Notes  \
# 0            RF4        NaN                                 isozyme ADH1B2
# 1            RF4        NaN                                 isozyme ADH1B1
# 2            RF7        NaN                                            NaN
# 3            RF2        NaN                           isozyme ADH1C at 21-
# 4            RF2        NaN                            isozyme ADH2 at 21-
# 5            RF2        NaN                            isozyme ADH4 at 21-
# 6            RF2        NaN                            isozyme ADH3 at 21-
# 7            RF2        NaN                            isozyme ADH3 at 21-
# 8            RF2        NaN                           isozyme ADH1C at 21-
# 9            RF2        NaN                            isozyme ADH4 at 21-
# 10           RF2        NaN                            isozyme ADH2 at 21-
# 11           RF8        NaN                                              4
# 12           RF8        NaN                                            1B1
# 13           RF8        NaN                                            1B2
# 14           RF4        NaN                                 isozyme ADH1B1
# 15           RF4        NaN                                 isozyme ADH1B2
# 16           RF1        NaN                           isoenzyme beta1beta1
# 17           RF1        NaN  isoenzyme gamma2gamma2; isoenzymes beta2beta2
# 18           RF1        NaN                          isoenzymes beta2beta2
# 19           RF1        NaN                         isoenzyme gamma1gamma1
# 20           RF2        NaN                           isozyme ADH1C at 21-
# 21           RF1        NaN                           isoenzyme beta3beta3
# 22           RF1        NaN                           isoenzyme alphaalpha
# 23           RF2        NaN                            isozyme ADH4 at 21-
# 24           RF2        NaN                            isozyme ADH2 at 21-
# 25           RF8        NaN                                            1B1
# 26           RF8        NaN                                            1B2
# 27           RF8        NaN                                              4
# 28           RF1        NaN                                            NaN
# 29           RF8        NaN                                              4
# ...          ...        ...                                            ...
# 8732      P48506        RF1                                            NaN
# 8733      P48506        RF1                                            NaN
# 8734      P48506        RF1                                            NaN
# 8735      P00966        RF6                                            NaN
# 8736      P00966        RF6                                            NaN
# 8737      P00966        RF6                                            NaN
# 8738      P00966       RF11                                            NaN
# 8739      P00966       RF11                                            NaN
# 8740      P50747        RF2                                            NaN
# 8741      Q6IA69        RF2                                            NaN
# 8742      Q6IA69        RF2                                            NaN
# 8743      Q6IA69        RF2                                            NaN
# 8744      Q6IA69        RF2                                            NaN
# 8745      O00763        RF5                                            NaN
# 8746      O00763        RF5                                            NaN
# 8747      O00763        RF5                                            NaN
# 8748      O00763        RF5                                            NaN
# 8749      O00763        RF5                                            NaN
# 8750      O00763        RF5                                            NaN
# 8751      P12277       RF14                                            NaN
# 8752      P12277       RF14                                            NaN
# 8753      P12277       RF14                                            NaN
# 8754      P06732       RF15                                            NaN
# 8755      P06732       RF15                                            NaN
# 8756      P12532        RF2                                            NaN
# 8757      P12532        RF2                                            NaN
# 8758      P17540        RF2                                            NaN
# 8759      P17540        RF2                                            NaN
# 8760      P50053        RF1                                            NaN
# 8761      P50053        RF1                                            NaN
#
#      BIGG ID     BIGG NAME KEEPing
# 0        NaN           NaN       X
# 1        NaN           NaN       X
# 2        NaN           NaN       X
# 3        NaN           NaN       X
# 4        NaN           NaN       X
# 5        NaN           NaN       X
# 6        NaN           NaN       X
# 7        NaN           NaN       X
# 8        NaN           NaN       X
# 9        NaN           NaN       X
# 10       NaN           NaN       X
# 11       NaN           NaN       X
# 12       NaN           NaN       X
# 13       NaN           NaN       X
# 14       NaN           NaN       X
# 15       NaN           NaN       X
# 16     acald  acetaldehyde     NaN
# 17     acald  acetaldehyde     NaN
# 18     acald  acetaldehyde     NaN
# 19     acald  acetaldehyde     NaN
# 20     acald  acetaldehyde     NaN
# 21     acald  acetaldehyde     NaN
# 22     acald  acetaldehyde     NaN
# 23     acald  acetaldehyde     NaN
# 24     acald  acetaldehyde     NaN
# 25       NaN           NaN       X
# 26       NaN           NaN       X
# 27       NaN           NaN       X
# 28       NaN           NaN       X
# 29       NaN           NaN       X
# ...      ...           ...     ...
# 8732     NaN           NaN     NaN
# 8733     NaN           NaN     NaN
# 8734     NaN           NaN     NaN
# 8735     NaN           NaN     NaN
# 8736     NaN           NaN     NaN
# 8737     NaN           NaN     NaN
# 8738     NaN           NaN     NaN
# 8739     NaN           NaN     NaN
# 8740     NaN           NaN     NaN
# 8741     NaN           NaN     NaN
# 8742     NaN           NaN     NaN
# 8743     NaN           NaN     NaN
# 8744     NaN           NaN     NaN
# 8745     NaN           NaN     NaN
# 8746     NaN           NaN     NaN
# 8747     NaN           NaN     NaN
# 8748     NaN           NaN     NaN
# 8749     NaN           NaN     NaN
# 8750     NaN           NaN     NaN
# 8751     NaN           NaN     NaN
# 8752     NaN           NaN     NaN
# 8753     NaN           NaN     NaN
# 8754     NaN           NaN     NaN
# 8755     NaN           NaN     NaN
# 8756     NaN           NaN     NaN
# 8757     NaN           NaN     NaN
# 8758     NaN           NaN     NaN
# 8759     NaN           NaN     NaN
# 8760     NaN           NaN     NaN
# 8761     NaN           NaN     NaN
#
# [8762 rows x 29 columns]

# %% [markdown]
# # CLEANUP
# ### A) <br>
# * Check how many rows had their metabolite mapped to a bigg id
#     * check null in bigg ID column --> (This was the part that was curated by hong manually)
#
# ### B)
#
# * **Things to Consider**
#     * IF kinetic EC is missing--> row will be dropped (for right now- TBD)
#     *
#
#
#         * **Do not drop rows with empty parameter (km/kcat) column --> Mentioned earlier by hong

# %%
#A) 
Kinetic_df["BIGG ID"].isnull().value_counts()
# Out:
# False    5225
# True     3537
# Name: BIGG ID, dtype: int64

# %%
Kinetic_df.EC_Number.isnull().value_counts()
# Out:
# False    8033
# True      729
# Name: EC_Number, dtype: int64

# %%
a= Kinetic_df['BIGG ID'] [0]
Kinetic_df['BIGG ID']=Kinetic_df['BIGG ID'].astype(str)
Kinetic_df['EC_Number']=Kinetic_df['EC_Number'].astype(str)

# %%
Kinetic_df
# Out:
#       Entry ID                            Recommended Enzyme Name  \
# 0           29                              alcohol dehydrogenase
# 1           30                              alcohol dehydrogenase
# 2           37                              alcohol dehydrogenase
# 3           42                              alcohol dehydrogenase
# 4           43                              alcohol dehydrogenase
# 5           44                              alcohol dehydrogenase
# 6           45                              alcohol dehydrogenase
# 7           59                              alcohol dehydrogenase
# 8           60                              alcohol dehydrogenase
# 9           61                              alcohol dehydrogenase
# 10          62                              alcohol dehydrogenase
# 11          63                              alcohol dehydrogenase
# 12          64                              alcohol dehydrogenase
# 13          65                              alcohol dehydrogenase
# 14          72                              alcohol dehydrogenase
# 15          73                              alcohol dehydrogenase
# 16          74                              alcohol dehydrogenase
# 17          75                              alcohol dehydrogenase
# 18          76                              alcohol dehydrogenase
# 19          77                              alcohol dehydrogenase
# 20          78                              alcohol dehydrogenase
# 21          79                              alcohol dehydrogenase
# 22          80                              alcohol dehydrogenase
# 23          81                              alcohol dehydrogenase
# 24          82                              alcohol dehydrogenase
# 25          83                              alcohol dehydrogenase
# 26          84                              alcohol dehydrogenase
# 27          85                              alcohol dehydrogenase
# 28          86                              alcohol dehydrogenase
# 29          87                              alcohol dehydrogenase
# ...        ...                                                ...
# 8732        64       glutamate--cysteine ligase catalytic subunit
# 8733        65       glutamate--cysteine ligase catalytic subunit
# 8734        66       glutamate--cysteine ligase catalytic subunit
# 8735        27                         argininosuccinate synthase
# 8736        28                         argininosuccinate synthase
# 8737        29                         argininosuccinate synthase
# 8738       145                  Argininosuccinate synthaseCurated
# 8739       146                  Argininosuccinate synthaseCurated
# 8740        42                             Biotin--protein ligase
# 8741        15              Glutamine-dependent NAD(+) synthetase
# 8742        16              Glutamine-dependent NAD(+) synthetase
# 8743        17              Glutamine-dependent NAD(+) synthetase
# 8744        18              Glutamine-dependent NAD(+) synthetase
# 8745        64                           Acetyl-CoA carboxylase 2
# 8746        65                           Acetyl-CoA carboxylase 2
# 8747        66                           Acetyl-CoA carboxylase 2
# 8748        67                           Acetyl-CoA carboxylase 2
# 8749        68                           Acetyl-CoA carboxylase 2
# 8750        69                           Acetyl-CoA carboxylase 2
# 8751       117                         creatine kinase BB isoform
# 8752       118                         creatine kinase BB isoform
# 8753       119                         creatine kinase BB isoform
# 8754       120                         creatine kinase MM isoform
# 8755       121                         creatine kinase MM isoform
# 8756       122           ubiquitous mitochondrial creatine kinase
# 8757       123           ubiquitous mitochondrial creatine kinase
# 8758       124           sarcomeric mitochondrial creatine kinase
# 8759       125           sarcomeric mitochondrial creatine kinase
# 8760       121  KetohexokinaseImported\n\n<p>Manually validate...
# 8761       122  KetohexokinaseImported\n\n<p>Manually validate...
#
#                                   Reaction ID  Enzymatic Activity EC_Number  \
# 0                                         NaN                 NaN   1.1.1.1
# 1                                         NaN                 NaN   1.1.1.1
# 2                                         NaN                 NaN   1.1.1.1
# 3                                         NaN                 NaN   1.1.1.1
# 4                                         NaN                 NaN   1.1.1.1
# 5                                         NaN                 NaN   1.1.1.1
# 6                                         NaN                 NaN   1.1.1.1
# 7                                         NaN                 NaN   1.1.1.1
# 8                                         NaN                 NaN   1.1.1.1
# 9                                         NaN                 NaN   1.1.1.1
# 10                                        NaN                 NaN   1.1.1.1
# 11                                        NaN                 NaN   1.1.1.1
# 12                                        NaN                 NaN   1.1.1.1
# 13                                        NaN                 NaN   1.1.1.1
# 14                                        NaN                 NaN   1.1.1.1
# 15                                        NaN                 NaN   1.1.1.1
# 16                                        NaN                 NaN   1.1.1.1
# 17                                        NaN                 NaN   1.1.1.1
# 18                                        NaN                 NaN   1.1.1.1
# 19                                        NaN                 NaN   1.1.1.1
# 20                                        NaN                 NaN   1.1.1.1
# 21                                        NaN                 NaN   1.1.1.1
# 22                                        NaN                 NaN   1.1.1.1
# 23                                        NaN                 NaN   1.1.1.1
# 24                                        NaN                 NaN   1.1.1.1
# 25                                        NaN                 NaN   1.1.1.1
# 26                                        NaN                 NaN   1.1.1.1
# 27                                        NaN                 NaN   1.1.1.1
# 28                                        NaN                 NaN   1.1.1.1
# 29                                        NaN                 NaN   1.1.1.1
# ...                                       ...                 ...       ...
# 8732                                      NaN                 NaN   6.3.2.2
# 8733                                      NaN                 NaN   6.3.2.2
# 8734                                      NaN                 NaN   6.3.2.2
# 8735                                      NaN                 NaN   6.3.4.5
# 8736                                      NaN                 NaN   6.3.4.5
# 8737                                      NaN                 NaN   6.3.4.5
# 8738             Citrulline--aspartate ligase                 NaN       nan
# 8739             Citrulline--aspartate ligase                 NaN       nan
# 8740                Biotin apo-protein ligase                 NaN       nan
# 8741  NAD(+) synthase [glutamine-hydrolyzing]                 NaN       nan
# 8742  NAD(+) synthase [glutamine-hydrolyzing]                 NaN       nan
# 8743  NAD(+) synthase [glutamine-hydrolyzing]                 NaN       nan
# 8744  NAD(+) synthase [glutamine-hydrolyzing]                 NaN       nan
# 8745                                 ACC-beta                 NaN       nan
# 8746                                 ACC-beta                 NaN       nan
# 8747                                 ACC-beta                 NaN       nan
# 8748                                 ACC-beta                 NaN       nan
# 8749                                 ACC-beta                 NaN       nan
# 8750                                 ACC-beta                 NaN       nan
# 8751                                      NaN                 NaN   2.7.3.2
# 8752                                      NaN                 NaN   2.7.3.2
# 8753                                      NaN                 NaN   2.7.3.2
# 8754                                      NaN                 NaN   2.7.3.2
# 8755                                      NaN                 NaN   2.7.3.2
# 8756                                      NaN                 NaN   2.7.3.2
# 8757                                      NaN                 NaN   2.7.3.2
# 8758                                      NaN                 NaN   2.7.3.2
# 8759                                      NaN                 NaN   2.7.3.2
# 8760                     Hepatic fructokinase                 NaN       nan
# 8761                     Hepatic fructokinase                 NaN       nan
#
#          Gene      Organism Strain/Tissue  \
# 0         NaN  Homo sapiens           NaN
# 1         NaN  Homo sapiens           NaN
# 2         NaN  Homo sapiens           NaN
# 3         NaN  Homo sapiens           NaN
# 4         NaN  Homo sapiens           NaN
# 5         NaN  Homo sapiens           NaN
# 6         NaN  Homo sapiens           NaN
# 7         NaN  Homo sapiens           NaN
# 8         NaN  Homo sapiens           NaN
# 9         NaN  Homo sapiens           NaN
# 10        NaN  Homo sapiens           NaN
# 11        NaN  Homo sapiens           NaN
# 12        NaN  Homo sapiens           NaN
# 13        NaN  Homo sapiens           NaN
# 14        NaN  Homo sapiens           NaN
# 15        NaN  Homo sapiens           NaN
# 16        NaN  Homo sapiens           NaN
# 17        NaN  Homo sapiens           NaN
# 18        NaN  Homo sapiens           NaN
# 19        NaN  Homo sapiens           NaN
# 20        NaN  Homo sapiens           NaN
# 21        NaN  Homo sapiens           NaN
# 22        NaN  Homo sapiens           NaN
# 23        NaN  Homo sapiens           NaN
# 24        NaN  Homo sapiens           NaN
# 25        NaN  Homo sapiens           NaN
# 26        NaN  Homo sapiens           NaN
# 27        NaN  Homo sapiens           NaN
# 28        NaN  Homo sapiens           NaN
# 29        NaN  Homo sapiens           NaN
# ...       ...           ...           ...
# 8732     GCLC  Homo sapiens           NaN
# 8733     GCLC  Homo sapiens           NaN
# 8734     GCLC  Homo sapiens           NaN
# 8735     ASS1  Homo sapiens           NaN
# 8736     ASS1  Homo sapiens           NaN
# 8737     ASS1  Homo sapiens           NaN
# 8738     ASS1  Homo sapiens         Human
# 8739     ASS1  Homo sapiens         Human
# 8740     HLCS  Homo sapiens         Human
# 8741  NADSYN1  Homo sapiens         Human
# 8742  NADSYN1  Homo sapiens         Human
# 8743  NADSYN1  Homo sapiens         Human
# 8744  NADSYN1  Homo sapiens         Human
# 8745    ACACB  Homo sapiens         Human
# 8746    ACACB  Homo sapiens         Human
# 8747    ACACB  Homo sapiens         Human
# 8748    ACACB  Homo sapiens         Human
# 8749    ACACB  Homo sapiens         Human
# 8750    ACACB  Homo sapiens         Human
# 8751      CKB  Homo sapiens           NaN
# 8752      CKB  Homo sapiens           NaN
# 8753      CKB  Homo sapiens           NaN
# 8754      CKM  Homo sapiens           NaN
# 8755      CKM  Homo sapiens           NaN
# 8756   CKMT1B  Homo sapiens           NaN
# 8757   CKMT1B  Homo sapiens           NaN
# 8758    CKMT2  Homo sapiens           NaN
# 8759    CKMT2  Homo sapiens           NaN
# 8760      KHK  Homo sapiens         Human
# 8761      KHK  Homo sapiens         Human
#
#                                                Reaction      Cofactor   ...    \
# 0     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 1     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 2     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 3     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 4     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 5     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 6     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 7     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 8     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 9     a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 10    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 11    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 12    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 13    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 14    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 15    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 16    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 17    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 18    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 19    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 20    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 21    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 22    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 23    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 24    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 25    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 26    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 27    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 28    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# 29    a primary alcohol + NAD+ <=> an aldehyde + NAD...           NaN   ...
# ...                                                 ...           ...   ...
# 8732  L-glutamate + L-cysteine + ATP  →  γ-L-glutamy...           NaN   ...
# 8733  L-glutamate + L-cysteine + ATP  →  γ-L-glutamy...           NaN   ...
# 8734  L-glutamate + L-cysteine + ATP  →  γ-L-glutamy...           NaN   ...
# 8735  L-aspartate + L-citrulline + ATP  →  L-arginin...           NaN   ...
# 8736  L-aspartate + L-citrulline + ATP  →  L-arginin...           NaN   ...
# 8737  L-aspartate + L-citrulline + ATP  →  L-arginin...           NaN   ...
# 8738  ATP + L-citrulline + L-aspartate = AMP + dipho...           NaN   ...
# 8739  ATP + L-citrulline + L-aspartate = AMP + dipho...           NaN   ...
# 8740  ATP + biotin + apo-[methylmalonyl-CoA:pyruvate...           NaN   ...
# 8741  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8742  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8743  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8744  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8745  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8746  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8747  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8748  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8749  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8750  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8751  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8752  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8753  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8754  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8755  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8756  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8757  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8758  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8759  creatine + ATP  ↔  creatine-phosphate + ADP + ...        Mg2+,    ...
# 8760    ATP + D-fructose = ADP + D-fructose 1-phosphate           NaN   ...
# 8761    ATP + D-fructose = ADP + D-fructose 1-phosphate           NaN   ...
#
#                               pH Temp (°C) Buffer/Media         Uniprot  \
# 0                            7.5      25.0          NaN             NaN
# 1                            7.5      25.0          NaN             NaN
# 2                            NaN       NaN          NaN             NaN
# 3                            NaN      23.0          NaN  P00326, P08319
# 4                            NaN      23.0          NaN  P00326, P08319
# 5                            NaN      23.0          NaN  P00326, P08319
# 6                            NaN      23.0          NaN  P00326, P08319
# 7                            NaN      23.0          NaN  P00326, P08319
# 8                            NaN      23.0          NaN  P00326, P08319
# 9                            NaN      23.0          NaN  P00326, P08319
# 10                           NaN      23.0          NaN  P00326, P08319
# 11                           7.5      25.0          NaN             NaN
# 12                           7.5      25.0          NaN             NaN
# 13                           7.5      25.0          NaN             NaN
# 14                           7.5      25.0          NaN             NaN
# 15                           7.5      25.0          NaN             NaN
# 16                           NaN       NaN          NaN             NaN
# 17                           NaN       NaN          NaN             NaN
# 18                           NaN       NaN          NaN             NaN
# 19                           NaN       NaN          NaN             NaN
# 20                           NaN      23.0          NaN  P00326, P08319
# 21                           NaN       NaN          NaN             NaN
# 22                           NaN       NaN          NaN             NaN
# 23                           NaN      23.0          NaN  P00326, P08319
# 24                           NaN      23.0          NaN  P00326, P08319
# 25                           7.5      25.0          NaN             NaN
# 26                           7.5      25.0          NaN             NaN
# 27                           7.5      25.0          NaN             NaN
# 28                           NaN       NaN          NaN             NaN
# 29                           7.5      25.0          NaN             NaN
# ...                          ...       ...          ...             ...
# 8732  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8733  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8734  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8735           Act. Allosteric;        NaN          NaN             NaN
# 8736           Act. Allosteric;        NaN          NaN             NaN
# 8737           Act. Allosteric;        NaN          NaN             NaN
# 8738                         NaN       7.0          NaN             NaN
# 8739                         NaN       7.0          NaN             NaN
# 8740                         NaN       NaN          NaN             NaN
# 8741                         NaN       NaN          NaN             NaN
# 8742                         NaN       NaN          NaN             NaN
# 8743                         NaN       NaN          NaN             NaN
# 8744                         NaN       NaN          NaN             NaN
# 8745                         NaN       NaN          NaN             NaN
# 8746                         NaN       NaN          NaN             NaN
# 8747                         NaN       NaN          NaN             NaN
# 8748                         NaN       NaN          NaN             NaN
# 8749                         NaN       NaN          NaN             NaN
# 8750                         NaN       NaN          NaN             NaN
# 8751  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8752  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8753  Inhib. Unknown Mechanism;        NaN          NaN             NaN
# 8754                         NaN       NaN          NaN             NaN
# 8755                         NaN       NaN          NaN             NaN
# 8756                         NaN       NaN          NaN             NaN
# 8757                         NaN       NaN          NaN             NaN
# 8758                         NaN       NaN          NaN             NaN
# 8759                         NaN       NaN          NaN             NaN
# 8760                         NaN       NaN           25             NaN
# 8761                         NaN       NaN           25             NaN
#
#       References Data Point                                          Notes  \
# 0            RF4        NaN                                 isozyme ADH1B2
# 1            RF4        NaN                                 isozyme ADH1B1
# 2            RF7        NaN                                            NaN
# 3            RF2        NaN                           isozyme ADH1C at 21-
# 4            RF2        NaN                            isozyme ADH2 at 21-
# 5            RF2        NaN                            isozyme ADH4 at 21-
# 6            RF2        NaN                            isozyme ADH3 at 21-
# 7            RF2        NaN                            isozyme ADH3 at 21-
# 8            RF2        NaN                           isozyme ADH1C at 21-
# 9            RF2        NaN                            isozyme ADH4 at 21-
# 10           RF2        NaN                            isozyme ADH2 at 21-
# 11           RF8        NaN                                              4
# 12           RF8        NaN                                            1B1
# 13           RF8        NaN                                            1B2
# 14           RF4        NaN                                 isozyme ADH1B1
# 15           RF4        NaN                                 isozyme ADH1B2
# 16           RF1        NaN                           isoenzyme beta1beta1
# 17           RF1        NaN  isoenzyme gamma2gamma2; isoenzymes beta2beta2
# 18           RF1        NaN                          isoenzymes beta2beta2
# 19           RF1        NaN                         isoenzyme gamma1gamma1
# 20           RF2        NaN                           isozyme ADH1C at 21-
# 21           RF1        NaN                           isoenzyme beta3beta3
# 22           RF1        NaN                           isoenzyme alphaalpha
# 23           RF2        NaN                            isozyme ADH4 at 21-
# 24           RF2        NaN                            isozyme ADH2 at 21-
# 25           RF8        NaN                                            1B1
# 26           RF8        NaN                                            1B2
# 27           RF8        NaN                                              4
# 28           RF1        NaN                                            NaN
# 29           RF8        NaN                                              4
# ...          ...        ...                                            ...
# 8732      P48506        RF1                                            NaN
# 8733      P48506        RF1                                            NaN
# 8734      P48506        RF1                                            NaN
# 8735      P00966        RF6                                            NaN
# 8736      P00966        RF6                                            NaN
# 8737      P00966        RF6                                            NaN
# 8738      P00966       RF11                                            NaN
# 8739      P00966       RF11                                            NaN
# 8740      P50747        RF2                                            NaN
# 8741      Q6IA69        RF2                                            NaN
# 8742      Q6IA69        RF2                                            NaN
# 8743      Q6IA69        RF2                                            NaN
# 8744      Q6IA69        RF2                                            NaN
# 8745      O00763        RF5                                            NaN
# 8746      O00763        RF5                                            NaN
# 8747      O00763        RF5                                            NaN
# 8748      O00763        RF5                                            NaN
# 8749      O00763        RF5                                            NaN
# 8750      O00763        RF5                                            NaN
# 8751      P12277       RF14                                            NaN
# 8752      P12277       RF14                                            NaN
# 8753      P12277       RF14                                            NaN
# 8754      P06732       RF15                                            NaN
# 8755      P06732       RF15                                            NaN
# 8756      P12532        RF2                                            NaN
# 8757      P12532        RF2                                            NaN
# 8758      P17540        RF2                                            NaN
# 8759      P17540        RF2                                            NaN
# 8760      P50053        RF1                                            NaN
# 8761      P50053        RF1                                            NaN
#
#      BIGG ID     BIGG NAME KEEPing
# 0        nan           NaN       X
# 1        nan           NaN       X
# 2        nan           NaN       X
# 3        nan           NaN       X
# 4        nan           NaN       X
# 5        nan           NaN       X
# 6        nan           NaN       X
# 7        nan           NaN       X
# 8        nan           NaN       X
# 9        nan           NaN       X
# 10       nan           NaN       X
# 11       nan           NaN       X
# 12       nan           NaN       X
# 13       nan           NaN       X
# 14       nan           NaN       X
# 15       nan           NaN       X
# 16     acald  acetaldehyde     NaN
# 17     acald  acetaldehyde     NaN
# 18     acald  acetaldehyde     NaN
# 19     acald  acetaldehyde     NaN
# 20     acald  acetaldehyde     NaN
# 21     acald  acetaldehyde     NaN
# 22     acald  acetaldehyde     NaN
# 23     acald  acetaldehyde     NaN
# 24     acald  acetaldehyde     NaN
# 25       nan           NaN       X
# 26       nan           NaN       X
# 27       nan           NaN       X
# 28       nan           NaN       X
# 29       nan           NaN       X
# ...      ...           ...     ...
# 8732     nan           NaN     NaN
# 8733     nan           NaN     NaN
# 8734     nan           NaN     NaN
# 8735     nan           NaN     NaN
# 8736     nan           NaN     NaN
# 8737     nan           NaN     NaN
# 8738     nan           NaN     NaN
# 8739     nan           NaN     NaN
# 8740     nan           NaN     NaN
# 8741     nan           NaN     NaN
# 8742     nan           NaN     NaN
# 8743     nan           NaN     NaN
# 8744     nan           NaN     NaN
# 8745     nan           NaN     NaN
# 8746     nan           NaN     NaN
# 8747     nan           NaN     NaN
# 8748     nan           NaN     NaN
# 8749     nan           NaN     NaN
# 8750     nan           NaN     NaN
# 8751     nan           NaN     NaN
# 8752     nan           NaN     NaN
# 8753     nan           NaN     NaN
# 8754     nan           NaN     NaN
# 8755     nan           NaN     NaN
# 8756     nan           NaN     NaN
# 8757     nan           NaN     NaN
# 8758     nan           NaN     NaN
# 8759     nan           NaN     NaN
# 8760     nan           NaN     NaN
# 8761     nan           NaN     NaN
#
# [8762 rows x 29 columns]

# %%
Kinetic_No_Match=Kinetic_df[(Kinetic_df['BIGG ID'] =='nan') & (Kinetic_df['EC_Number'] =="nan")]

# %%
Kinetic_No_Match
# Out:
#       Entry ID                            Recommended Enzyme Name  \
# 1183         4                 D-3-phosphoglycerate dehydrogenase
# 1184         5                 D-3-phosphoglycerate dehydrogenase
# 4890       214  Adenylate kinase isoenzyme 6UniRule annotation...
# 4891       215  Adenylate kinase isoenzyme 6UniRule annotation...
# 5841       107  High affinity cGMP-specific 3',5'-cyclic phosp...
# 7660       699           Aflatoxin B1 aldehyde reductase member 2
# 7661       700           Aflatoxin B1 aldehyde reductase member 2
# 7662       701           Aflatoxin B1 aldehyde reductase member 2
# 7663       702           Aflatoxin B1 aldehyde reductase member 2
# 7668      1008            Aldo-keto reductase family 1 member B10
# 7669      1009            Aldo-keto reductase family 1 member B10
# 7670      1010            Aldo-keto reductase family 1 member B10
# 7671       115             3-hydroxyacyl-CoA dehydrogenase type-2
# 7672       116             3-hydroxyacyl-CoA dehydrogenase type-2
# 7673       117             3-hydroxyacyl-CoA dehydrogenase type-2
# 7674       118             3-hydroxyacyl-CoA dehydrogenase type-2
# 7675       119             3-hydroxyacyl-CoA dehydrogenase type-2
# 7676       120             3-hydroxyacyl-CoA dehydrogenase type-2
# 7677       121             3-hydroxyacyl-CoA dehydrogenase type-2
# 7678       122             3-hydroxyacyl-CoA dehydrogenase type-2
# 7679       123             3-hydroxyacyl-CoA dehydrogenase type-2
# 7680        28        Isocitrate dehydrogenase [NADP] cytoplasmic
# 7681        29        Isocitrate dehydrogenase [NADP] cytoplasmic
# 7682        30        Isocitrate dehydrogenase [NADP] cytoplasmic
# 7683        52                          Lambda-crystallin homolog
# 7684        53                          Lambda-crystallin homolog
# 7685       157                Glucose-6-phosphate 1-dehydrogenase
# 7686       158                Glucose-6-phosphate 1-dehydrogenase
# 7687       364             Aldo-keto reductase family 1 member C1
# 7688       365             Aldo-keto reductase family 1 member C1
# ...        ...                                                ...
# 8708        47             Hematopoietic prostaglandin D synthase
# 8709        48             Hematopoietic prostaglandin D synthase
# 8710        49             Hematopoietic prostaglandin D synthase
# 8712         6                              Prostacyclin synthase
# 8714       101                               Phosphoglucomutase-2
# 8715       102                               Phosphoglucomutase-2
# 8716       103                               Phosphoglucomutase-2
# 8717       116                               Phosphoglucomutase-1
# 8719        18                               Phosphomannomutase 2
# 8720        19                               Phosphomannomutase 2
# 8721        28                               Phosphomannomutase 1
# 8722        29                               Phosphomannomutase 1
# 8723       104            Methylmalonyl-CoA mutase, mitochondrial
# 8724        10                    Inositol-3-phosphate synthase 1
# 8725        11                    Inositol-3-phosphate synthase 1
# 8738       145                  Argininosuccinate synthaseCurated
# 8739       146                  Argininosuccinate synthaseCurated
# 8740        42                             Biotin--protein ligase
# 8741        15              Glutamine-dependent NAD(+) synthetase
# 8742        16              Glutamine-dependent NAD(+) synthetase
# 8743        17              Glutamine-dependent NAD(+) synthetase
# 8744        18              Glutamine-dependent NAD(+) synthetase
# 8745        64                           Acetyl-CoA carboxylase 2
# 8746        65                           Acetyl-CoA carboxylase 2
# 8747        66                           Acetyl-CoA carboxylase 2
# 8748        67                           Acetyl-CoA carboxylase 2
# 8749        68                           Acetyl-CoA carboxylase 2
# 8750        69                           Acetyl-CoA carboxylase 2
# 8760       121  KetohexokinaseImported\n\n<p>Manually validate...
# 8761       122  KetohexokinaseImported\n\n<p>Manually validate...
#
#                                             Reaction ID  Enzymatic Activity  \
# 1183                                             3-PGDH                 NaN
# 1184                                             3-PGDH                 NaN
# 4890                                                AK6                 NaN
# 4891                                                AK6                 NaN
# 5841                                                NaN                 NaN
# 7660                 AFB1 aldehyde reductase 1AFB1-AR 1                 NaN
# 7661                 AFB1 aldehyde reductase 1AFB1-AR 1                 NaN
# 7662                 AFB1 aldehyde reductase 1AFB1-AR 1                 NaN
# 7663                 AFB1 aldehyde reductase 1AFB1-AR 1                 NaN
# 7668                                              ARL-1                 NaN
# 7669                                              ARL-1                 NaN
# 7670                                              ARL-1                 NaN
# 7671  17-beta-hydroxysteroid dehydrogenase 10Short n...                 NaN
# 7672  17-beta-hydroxysteroid dehydrogenase 10Short n...                 NaN
# 7673  17-beta-hydroxysteroid dehydrogenase 10Short n...                 NaN
# 7674  17-beta-hydroxysteroid dehydrogenase 10Short n...                 NaN
# 7675  17-beta-hydroxysteroid dehydrogenase 10Short n...                 NaN
# 7676  17-beta-hydroxysteroid dehydrogenase 10Short n...                 NaN
# 7677  17-beta-hydroxysteroid dehydrogenase 10Short n...                 NaN
# 7678  17-beta-hydroxysteroid dehydrogenase 10Short n...                 NaN
# 7679  17-beta-hydroxysteroid dehydrogenase 10Short n...                 NaN
# 7680                                                IDH                 NaN
# 7681                                                IDH                 NaN
# 7682                                                IDH                 NaN
# 7683                   L-gulonate 3-dehydrogenaseGul3DH                 NaN
# 7684                   L-gulonate 3-dehydrogenaseGul3DH                 NaN
# 7685                                               G6PD                 NaN
# 7686                                               G6PD                 NaN
# 7687  20-alpha-hydroxysteroid dehydrogenaseShort nam...                 NaN
# 7688  20-alpha-hydroxysteroid dehydrogenaseShort nam...                 NaN
# ...                                                 ...                 ...
# 8708                                             H-PGDS                 NaN
# 8709                                             H-PGDS                 NaN
# 8710                                             H-PGDS                 NaN
# 8712                          Prostaglandin I2 synthase                 NaN
# 8714                                              PGM 2                 NaN
# 8715                                              PGM 2                 NaN
# 8716                                              PGM 2                 NaN
# 8717                                              PGM 1                 NaN
# 8719                                              PMM 2                 NaN
# 8720                                              PMM 2                 NaN
# 8721                                              PMM 1                 NaN
# 8722                                              PMM 1                 NaN
# 8723                                                MCM                 NaN
# 8724                                              IPS 1                 NaN
# 8725                                              IPS 1                 NaN
# 8738                       Citrulline--aspartate ligase                 NaN
# 8739                       Citrulline--aspartate ligase                 NaN
# 8740                          Biotin apo-protein ligase                 NaN
# 8741            NAD(+) synthase [glutamine-hydrolyzing]                 NaN
# 8742            NAD(+) synthase [glutamine-hydrolyzing]                 NaN
# 8743            NAD(+) synthase [glutamine-hydrolyzing]                 NaN
# 8744            NAD(+) synthase [glutamine-hydrolyzing]                 NaN
# 8745                                           ACC-beta                 NaN
# 8746                                           ACC-beta                 NaN
# 8747                                           ACC-beta                 NaN
# 8748                                           ACC-beta                 NaN
# 8749                                           ACC-beta                 NaN
# 8750                                           ACC-beta                 NaN
# 8760                               Hepatic fructokinase                 NaN
# 8761                               Hepatic fructokinase                 NaN
#
#      EC_Number      Gene      Organism Strain/Tissue  \
# 1183       nan     PHGDH  Homo sapiens         Human
# 1184       nan     PHGDH  Homo sapiens         Human
# 4890       nan       AK6  Homo sapiens         Human
# 4891       nan       AK6  Homo sapiens         Human
# 5841       nan     PDE9A  Homo sapiens         Human
# 7660       nan    AKR7A2  Homo sapiens         Human
# 7661       nan    AKR7A2  Homo sapiens         Human
# 7662       nan    AKR7A2  Homo sapiens         Human
# 7663       nan    AKR7A2  Homo sapiens         Human
# 7668       nan   AKR1B10  Homo sapiens         Human
# 7669       nan   AKR1B10  Homo sapiens         Human
# 7670       nan   AKR1B10  Homo sapiens         Human
# 7671       nan  HSD17B10  Homo sapiens         Human
# 7672       nan  HSD17B10  Homo sapiens         Human
# 7673       nan  HSD17B10  Homo sapiens         Human
# 7674       nan  HSD17B10  Homo sapiens         Human
# 7675       nan  HSD17B10  Homo sapiens         Human
# 7676       nan  HSD17B10  Homo sapiens         Human
# 7677       nan  HSD17B10  Homo sapiens         Human
# 7678       nan  HSD17B10  Homo sapiens         Human
# 7679       nan  HSD17B10  Homo sapiens         Human
# 7680       nan      IDH1  Homo sapiens         Human
# 7681       nan      IDH1  Homo sapiens         Human
# 7682       nan      IDH1  Homo sapiens         Human
# 7683       nan     CRYL1  Homo sapiens         Human
# 7684       nan     CRYL1  Homo sapiens         Human
# 7685       nan      G6PD  Homo sapiens         Human
# 7686       nan      G6PD  Homo sapiens         Human
# 7687       nan    AKR1C1  Homo sapiens         Human
# 7688       nan    AKR1C1  Homo sapiens         Human
# ...        ...       ...           ...           ...
# 8708       nan     HPGDS  Homo sapiens         Human
# 8709       nan     HPGDS  Homo sapiens         Human
# 8710       nan     HPGDS  Homo sapiens         Human
# 8712       nan     PTGIS  Homo sapiens         Human
# 8714       nan      PGM2  Homo sapiens         Human
# 8715       nan      PGM2  Homo sapiens         Human
# 8716       nan      PGM2  Homo sapiens         Human
# 8717       nan      PGM1  Homo sapiens         Human
# 8719       nan      PMM2  Homo sapiens         Human
# 8720       nan      PMM2  Homo sapiens         Human
# 8721       nan      PMM1  Homo sapiens         Human
# 8722       nan      PMM1  Homo sapiens         Human
# 8723       nan       MUT  Homo sapiens         Human
# 8724       nan    ISYNA1  Homo sapiens         Human
# 8725       nan    ISYNA1  Homo sapiens         Human
# 8738       nan      ASS1  Homo sapiens         Human
# 8739       nan      ASS1  Homo sapiens         Human
# 8740       nan      HLCS  Homo sapiens         Human
# 8741       nan   NADSYN1  Homo sapiens         Human
# 8742       nan   NADSYN1  Homo sapiens         Human
# 8743       nan   NADSYN1  Homo sapiens         Human
# 8744       nan   NADSYN1  Homo sapiens         Human
# 8745       nan     ACACB  Homo sapiens         Human
# 8746       nan     ACACB  Homo sapiens         Human
# 8747       nan     ACACB  Homo sapiens         Human
# 8748       nan     ACACB  Homo sapiens         Human
# 8749       nan     ACACB  Homo sapiens         Human
# 8750       nan     ACACB  Homo sapiens         Human
# 8760       nan       KHK  Homo sapiens         Human
# 8761       nan       KHK  Homo sapiens         Human
#
#                                                Reaction      Cofactor   ...    \
# 1183  3-phospho-D-glycerate + NAD+ = 3-phosphonooxyp...           NaN   ...
# 1184  3-phospho-D-glycerate + NAD+ = 3-phosphonooxyp...           NaN   ...
# 4890                                  ATP + AMP = 2 ADP           NaN   ...
# 4891                                  ATP + AMP = 2 ADP           NaN   ...
# 5841  Guanosine 3',5'-cyclic phosphate + H2O = guano...    Zn2+, Mg2+   ...
# 7660  4-hydroxybutanoate + NADP+ = succinate semiald...           NaN   ...
# 7661  4-hydroxybutanoate + NADP+ = succinate semiald...           NaN   ...
# 7662  4-hydroxybutanoate + NADP+ = succinate semiald...           NaN   ...
# 7663  4-hydroxybutanoate + NADP+ = succinate semiald...           NaN   ...
# 7668                                                NaN           NaN   ...
# 7669                                                NaN           NaN   ...
# 7670                                                NaN           NaN   ...
# 7671  (S)-3-hydroxyacyl-CoA + NAD+ = 3-oxoacyl-CoA +...           NaN   ...
# 7672  (S)-3-hydroxyacyl-CoA + NAD+ = 3-oxoacyl-CoA +...           NaN   ...
# 7673  (S)-3-hydroxyacyl-CoA + NAD+ = 3-oxoacyl-CoA +...           NaN   ...
# 7674  (S)-3-hydroxyacyl-CoA + NAD+ = 3-oxoacyl-CoA +...           NaN   ...
# 7675  (S)-3-hydroxyacyl-CoA + NAD+ = 3-oxoacyl-CoA +...           NaN   ...
# 7676  (S)-3-hydroxyacyl-CoA + NAD+ = 3-oxoacyl-CoA +...           NaN   ...
# 7677  (S)-3-hydroxyacyl-CoA + NAD+ = 3-oxoacyl-CoA +...           NaN   ...
# 7678  (S)-3-hydroxyacyl-CoA + NAD+ = 3-oxoacyl-CoA +...           NaN   ...
# 7679  (S)-3-hydroxyacyl-CoA + NAD+ = 3-oxoacyl-CoA +...           NaN   ...
# 7680  Isocitrate + NADP+ = 2-oxoglutarate + CO2 + NADPH          Mg2+   ...
# 7681  Isocitrate + NADP+ = 2-oxoglutarate + CO2 + NADPH          Mg2+   ...
# 7682  Isocitrate + NADP+ = 2-oxoglutarate + CO2 + NADPH          Mg2+   ...
# 7683    L-gulonate + NAD+ = 3-dehydro-L-gulonate + NADH           NaN   ...
# 7684    L-gulonate + NAD+ = 3-dehydro-L-gulonate + NADH           NaN   ...
# 7685  D-glucose 6-phosphate + NADP+ = 6-phospho-D-gl...           NaN   ...
# 7686  D-glucose 6-phosphate + NADP+ = 6-phospho-D-gl...           NaN   ...
# 7687  17-alpha,20-alpha-dihydroxypregn-4-en-3-one + ...           NaN   ...
# 7688  17-alpha,20-alpha-dihydroxypregn-4-en-3-one + ...           NaN   ...
# ...                                                 ...           ...   ...
# 8708  (5Z,13E,15S)-9-alpha,11-alpha-epidioxy-15-hydr...   glutathione   ...
# 8709  (5Z,13E,15S)-9-alpha,11-alpha-epidioxy-15-hydr...   glutathione   ...
# 8710  (5Z,13E,15S)-9-alpha,11-alpha-epidioxy-15-hydr...   glutathione   ...
# 8712  (5Z,13E)-(15S)-9-alpha,11-alpha-epidioxy-15-hy...          heme   ...
# 8714  Alpha-D-glucose 1-phosphate = alpha-D-glucose ...          Mg2+   ...
# 8715  Alpha-D-glucose 1-phosphate = alpha-D-glucose ...          Mg2+   ...
# 8716  Alpha-D-glucose 1-phosphate = alpha-D-glucose ...          Mg2+   ...
# 8717  Alpha-D-glucose 1-phosphate = alpha-D-glucose ...          Mg2+   ...
# 8719  Alpha-D-mannose 1-phosphate = D-mannose 6-phos...           NaN   ...
# 8720  Alpha-D-mannose 1-phosphate = D-mannose 6-phos...           NaN   ...
# 8721  Alpha-D-mannose 1-phosphate = D-mannose 6-phos...          Mg2+   ...
# 8722  Alpha-D-mannose 1-phosphate = D-mannose 6-phos...          Mg2+   ...
# 8723               (R)-methylmalonyl-CoA = succinyl-CoA           NaN   ...
# 8724  D-glucose 6-phosphate = 1D-myo-inositol 3-phos...          NAD+   ...
# 8725  D-glucose 6-phosphate = 1D-myo-inositol 3-phos...          NAD+   ...
# 8738  ATP + L-citrulline + L-aspartate = AMP + dipho...           NaN   ...
# 8739  ATP + L-citrulline + L-aspartate = AMP + dipho...           NaN   ...
# 8740  ATP + biotin + apo-[methylmalonyl-CoA:pyruvate...           NaN   ...
# 8741  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8742  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8743  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8744  ATP + deamido-NAD+ + L-glutamine + H2O = AMP +...           NaN   ...
# 8745  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8746  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8747  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8748  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8749  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8750  ATP + acetyl-CoA + HCO3- = ADP + phosphate + m...  biotin, Mn2+   ...
# 8760    ATP + D-fructose = ADP + D-fructose 1-phosphate           NaN   ...
# 8761    ATP + D-fructose = ADP + D-fructose 1-phosphate           NaN   ...
#
#        pH Temp (°C) Buffer/Media Uniprot  References Data Point Notes BIGG ID  \
# 1183  NaN       NaN          NaN  O43175         RF1        NaN   NaN     nan
# 1184  NaN       NaN          NaN  O43175         RF1        NaN   NaN     nan
# 4890  NaN       NaN          NaN  Q9Y3D8        RF11        NaN   NaN     nan
# 4891  NaN       NaN          NaN  Q9Y3D8        RF11        NaN   NaN     nan
# 5841  NaN       NaN          NaN  O76083        RF16        NaN   NaN     nan
# 7660  NaN       NaN          NaN     NaN      O43488        RF8   NaN     nan
# 7661  NaN       NaN          NaN     NaN      O43488        RF8   NaN     nan
# 7662  NaN       NaN          NaN     NaN      O43488        RF8   NaN     nan
# 7663  NaN       NaN          NaN     NaN      O43488        RF8   NaN     nan
# 7668  NaN       NaN          NaN     NaN      O60218       RF23   NaN     nan
# 7669  NaN       NaN          NaN     NaN      O60218       RF23   NaN     nan
# 7670  NaN       NaN          NaN     NaN      O60218       RF23   NaN     nan
# 7671  NaN       7.0          NaN     NaN      Q99714        RF8   NaN     nan
# 7672  NaN       9.3          NaN     NaN      Q99714        RF8   NaN     nan
# 7673  NaN       9.3          NaN     NaN      Q99714        RF8   NaN     nan
# 7674  NaN       9.3          NaN     NaN      Q99714        RF8   NaN     nan
# 7675  NaN       9.3          NaN     NaN      Q99714        RF8   NaN     nan
# 7676  NaN       9.3          NaN     NaN      Q99714        RF8   NaN     nan
# 7677  NaN       9.3          NaN     NaN      Q99714        RF8   NaN     nan
# 7678  NaN       7.0          NaN     NaN      Q99714        RF8   NaN     nan
# 7679  NaN       9.3          NaN     NaN      Q99714        RF8   NaN     nan
# 7680  NaN       NaN          NaN     NaN      O75874        RF4   NaN     nan
# 7681  NaN       NaN          NaN     NaN      O75874        RF4   NaN     nan
# 7682  NaN       NaN          NaN     NaN      O75874        RF4   NaN     nan
# 7683  NaN       NaN          NaN     NaN      Q9Y2S2        RF1   NaN     nan
# 7684  NaN       NaN          NaN     NaN      Q9Y2S2        RF1   NaN     nan
# 7685  NaN       NaN          NaN     NaN      P11413       RF13   NaN     nan
# 7686  NaN       NaN          NaN     NaN      P11413       RF13   NaN     nan
# 7687  NaN       NaN          NaN     NaN      Q04828       RF21   NaN     nan
# 7688  NaN       NaN          NaN     NaN      Q04828       RF21   NaN     nan
# ...   ...       ...          ...     ...         ...        ...   ...     ...
# 8708  NaN       NaN          NaN     NaN      O60760       RF12   NaN     nan
# 8709  NaN       NaN          NaN     NaN      O60760       RF12   NaN     nan
# 8710  NaN       NaN          NaN     NaN      O60760       RF12   NaN     nan
# 8712  NaN       NaN          NaN     NaN      Q16647        RF5   NaN     nan
# 8714  NaN       NaN          NaN     NaN      Q96G03        RF3   NaN     nan
# 8715  NaN       NaN          NaN     NaN      Q96G03        RF3   NaN     nan
# 8716  NaN       NaN          NaN     NaN      Q96G03        RF3   NaN     nan
# 8717  NaN       NaN          NaN     NaN      P36871        RF7   NaN     nan
# 8719  NaN       NaN          NaN     NaN      O15305        RF1   NaN     nan
# 8720  NaN       NaN          NaN     NaN      O15305        RF1   NaN     nan
# 8721  NaN       NaN          NaN     NaN      Q92871        RF1   NaN     nan
# 8722  NaN       NaN          NaN     NaN      Q92871        RF1   NaN     nan
# 8723  NaN       NaN          NaN     NaN      P22033       RF10   NaN     nan
# 8724  NaN       NaN          NaN     NaN      Q9NPH2        RF2   NaN     nan
# 8725  NaN       NaN          NaN     NaN      Q9NPH2        RF2   NaN     nan
# 8738  NaN       7.0          NaN     NaN      P00966       RF11   NaN     nan
# 8739  NaN       7.0          NaN     NaN      P00966       RF11   NaN     nan
# 8740  NaN       NaN          NaN     NaN      P50747        RF2   NaN     nan
# 8741  NaN       NaN          NaN     NaN      Q6IA69        RF2   NaN     nan
# 8742  NaN       NaN          NaN     NaN      Q6IA69        RF2   NaN     nan
# 8743  NaN       NaN          NaN     NaN      Q6IA69        RF2   NaN     nan
# 8744  NaN       NaN          NaN     NaN      Q6IA69        RF2   NaN     nan
# 8745  NaN       NaN          NaN     NaN      O00763        RF5   NaN     nan
# 8746  NaN       NaN          NaN     NaN      O00763        RF5   NaN     nan
# 8747  NaN       NaN          NaN     NaN      O00763        RF5   NaN     nan
# 8748  NaN       NaN          NaN     NaN      O00763        RF5   NaN     nan
# 8749  NaN       NaN          NaN     NaN      O00763        RF5   NaN     nan
# 8750  NaN       NaN          NaN     NaN      O00763        RF5   NaN     nan
# 8760  NaN       NaN           25     NaN      P50053        RF1   NaN     nan
# 8761  NaN       NaN           25     NaN      P50053        RF1   NaN     nan
#
#      BIGG NAME KEEPing
# 1183       NaN       X
# 1184       NaN       X
# 4890       NaN       X
# 4891       NaN       X
# 5841       NaN       X
# 7660       NaN     NaN
# 7661       NaN     NaN
# 7662       NaN     NaN
# 7663       NaN     NaN
# 7668       NaN     NaN
# 7669       NaN     NaN
# 7670       NaN     NaN
# 7671       NaN     NaN
# 7672       NaN     NaN
# 7673       NaN     NaN
# 7674       NaN     NaN
# 7675       NaN     NaN
# 7676       NaN     NaN
# 7677       NaN     NaN
# 7678       NaN     NaN
# 7679       NaN     NaN
# 7680       NaN     NaN
# 7681       NaN     NaN
# 7682       NaN     NaN
# 7683       NaN     NaN
# 7684       NaN     NaN
# 7685       NaN     NaN
# 7686       NaN     NaN
# 7687       NaN     NaN
# 7688       NaN     NaN
# ...        ...     ...
# 8708       NaN     NaN
# 8709       NaN     NaN
# 8710       NaN     NaN
# 8712       NaN     NaN
# 8714       NaN     NaN
# 8715       NaN     NaN
# 8716       NaN     NaN
# 8717       NaN     NaN
# 8719       NaN     NaN
# 8720       NaN     NaN
# 8721       NaN     NaN
# 8722       NaN     NaN
# 8723       NaN     NaN
# 8724       NaN     NaN
# 8725       NaN     NaN
# 8738       NaN     NaN
# 8739       NaN     NaN
# 8740       NaN     NaN
# 8741       NaN     NaN
# 8742       NaN     NaN
# 8743       NaN     NaN
# 8744       NaN     NaN
# 8745       NaN     NaN
# 8746       NaN     NaN
# 8747       NaN     NaN
# 8748       NaN     NaN
# 8749       NaN     NaN
# 8750       NaN     NaN
# 8760       NaN     NaN
# 8761       NaN     NaN
#
# [729 rows x 29 columns]

# %%
type(a)
# Out:
# float

# %%
Kinetic__Match=Kinetic_df[(Kinetic_df['BIGG ID'] !='nan') & (Kinetic_df['EC_Number'] !="nan")]

# %%
Kinetic__Match
# Out:
#       Entry ID     Recommended Enzyme Name Reaction ID  Enzymatic Activity  \
# 16          74       alcohol dehydrogenase         NaN                 NaN
# 17          75       alcohol dehydrogenase         NaN                 NaN
# 18          76       alcohol dehydrogenase         NaN                 NaN
# 19          77       alcohol dehydrogenase         NaN                 NaN
# 20          78       alcohol dehydrogenase         NaN                 NaN
# 21          79       alcohol dehydrogenase         NaN                 NaN
# 22          80       alcohol dehydrogenase         NaN                 NaN
# 23          81       alcohol dehydrogenase         NaN                 NaN
# 24          82       alcohol dehydrogenase         NaN                 NaN
# 34          99       alcohol dehydrogenase         NaN                 NaN
# 35         100       alcohol dehydrogenase         NaN                 NaN
# 36         101       alcohol dehydrogenase         NaN                 NaN
# 37         102       alcohol dehydrogenase         NaN                 NaN
# 38         103       alcohol dehydrogenase         NaN                 NaN
# 39         104       alcohol dehydrogenase         NaN                 NaN
# 40         105       alcohol dehydrogenase         NaN                 NaN
# 41         106       alcohol dehydrogenase         NaN                 NaN
# 42         107       alcohol dehydrogenase         NaN                 NaN
# 43         108       alcohol dehydrogenase         NaN                 NaN
# 44         109       alcohol dehydrogenase         NaN                 NaN
# 45         110       alcohol dehydrogenase         NaN                 NaN
# 46         111       alcohol dehydrogenase         NaN                 NaN
# 47         112       alcohol dehydrogenase         NaN                 NaN
# 48         113       alcohol dehydrogenase         NaN                 NaN
# 49         114       alcohol dehydrogenase         NaN                 NaN
# 50         115       alcohol dehydrogenase         NaN                 NaN
# 51         116       alcohol dehydrogenase         NaN                 NaN
# 52         117       alcohol dehydrogenase         NaN                 NaN
# 53         118       alcohol dehydrogenase         NaN                 NaN
# 54         119       alcohol dehydrogenase         NaN                 NaN
# ...        ...                         ...         ...                 ...
# 7627         4  Triose-phosphate isomerase         NaN                 NaN
# 7628         5  Triose-phosphate isomerase         NaN                 NaN
# 7629         6  Triose-phosphate isomerase         NaN                 NaN
# 7630         7  Triose-phosphate isomerase         NaN                 NaN
# 7631         8  Triose-phosphate isomerase         NaN                 NaN
# 7632         9  Triose-phosphate isomerase         NaN                 NaN
# 7633        10  Triose-phosphate isomerase         NaN                 NaN
# 7634        11  Triose-phosphate isomerase         NaN                 NaN
# 7635        12  Triose-phosphate isomerase         NaN                 NaN
# 7636        13  Triose-phosphate isomerase         NaN                 NaN
# 7637        14  Triose-phosphate isomerase         NaN                 NaN
# 7638        15  triose-phosphate isomerase         NaN                 NaN
# 7639        17  triose-phosphate isomerase         NaN                 NaN
# 7640        19  triose-phosphate isomerase         NaN                 NaN
# 7641        21  triose-phosphate isomerase         NaN                 NaN
# 7642        23  triose-phosphate isomerase         NaN                 NaN
# 7643        24  triose-phosphate isomerase         NaN                 NaN
# 7644        25  triose-phosphate isomerase         NaN                 NaN
# 7645        26  triose-phosphate isomerase         NaN                 NaN
# 7646        28  triose-phosphate isomerase         NaN                 NaN
# 7647        31  triose-phosphate isomerase         NaN                 NaN
# 7648        34  triose-phosphate isomerase         NaN                 NaN
# 7649        37  triose-phosphate isomerase         NaN                 NaN
# 7650        40  triose-phosphate isomerase         NaN                 NaN
# 7651        43  triose-phosphate isomerase         NaN                 NaN
# 7652        46  triose-phosphate isomerase         NaN                 NaN
# 7653        49  triose-phosphate isomerase         NaN                 NaN
# 7654        60  triose-phosphate isomerase         NaN                 NaN
# 7655        66  triose-phosphate isomerase         NaN                 NaN
# 7656        76  triose-phosphate isomerase         NaN                 NaN
#
#      EC_Number Gene      Organism                    Strain/Tissue  \
# 16     1.1.1.1  NaN  Homo sapiens                              NaN
# 17     1.1.1.1  NaN  Homo sapiens                              NaN
# 18     1.1.1.1  NaN  Homo sapiens                              NaN
# 19     1.1.1.1  NaN  Homo sapiens                              NaN
# 20     1.1.1.1  NaN  Homo sapiens                              NaN
# 21     1.1.1.1  NaN  Homo sapiens                              NaN
# 22     1.1.1.1  NaN  Homo sapiens                              NaN
# 23     1.1.1.1  NaN  Homo sapiens                              NaN
# 24     1.1.1.1  NaN  Homo sapiens                              NaN
# 34     1.1.1.1  NaN  Homo sapiens                              NaN
# 35     1.1.1.1  NaN  Homo sapiens                              NaN
# 36     1.1.1.1  NaN  Homo sapiens                              NaN
# 37     1.1.1.1  NaN  Homo sapiens                              NaN
# 38     1.1.1.1  NaN  Homo sapiens                              NaN
# 39     1.1.1.1  NaN  Homo sapiens                              NaN
# 40     1.1.1.1  NaN  Homo sapiens                              NaN
# 41     1.1.1.1  NaN  Homo sapiens                              NaN
# 42     1.1.1.1  NaN  Homo sapiens                              NaN
# 43     1.1.1.1  NaN  Homo sapiens                              NaN
# 44     1.1.1.1  NaN  Homo sapiens                              NaN
# 45     1.1.1.1  NaN  Homo sapiens                              NaN
# 46     1.1.1.1  NaN  Homo sapiens                              NaN
# 47     1.1.1.1  NaN  Homo sapiens                              NaN
# 48     1.1.1.1  NaN  Homo sapiens                              NaN
# 49     1.1.1.1  NaN  Homo sapiens                              NaN
# 50     1.1.1.1  NaN  Homo sapiens                              NaN
# 51     1.1.1.1  NaN  Homo sapiens                              NaN
# 52     1.1.1.1  NaN  Homo sapiens                              NaN
# 53     1.1.1.1  NaN  Homo sapiens                              NaN
# 54     1.1.1.1  NaN  Homo sapiens                              NaN
# ...        ...  ...           ...                              ...
# 7627   5.3.1.1  NaN  Homo sapiens                              NaN
# 7628   5.3.1.1  NaN  Homo sapiens                              NaN
# 7629   5.3.1.1  NaN  Homo sapiens                              NaN
# 7630   5.3.1.1  NaN  Homo sapiens                              NaN
# 7631   5.3.1.1  NaN  Homo sapiens                              NaN
# 7632   5.3.1.1  NaN  Homo sapiens                              NaN
# 7633   5.3.1.1  NaN  Homo sapiens                              NaN
# 7634   5.3.1.1  NaN  Homo sapiens                              NaN
# 7635   5.3.1.1  NaN  Homo sapiens                              NaN
# 7636   5.3.1.1  NaN  Homo sapiens                              NaN
# 7637   5.3.1.1  NaN  Homo sapiens                              NaN
# 7638   5.3.1.1  NaN  Homo sapiens           skeletalmusclewildtype
# 7639   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformA
# 7640   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformC
# 7641   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformB
# 7642   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformB
# 7643   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformC
# 7644   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformA
# 7645   5.3.1.1  NaN  Homo sapiens           skeletalmusclewildtype
# 7646   5.3.1.1  NaN  Homo sapiens                    liverwildtype
# 7647   5.3.1.1  NaN  Homo sapiens                    liverwildtype
# 7648   5.3.1.1  NaN  Homo sapiens    erythrocytewildtypecomponentI
# 7649   5.3.1.1  NaN  Homo sapiens   erythrocytewildtypecomponentII
# 7650   5.3.1.1  NaN  Homo sapiens  erythrocytewildtypecomponentIII
# 7651   5.3.1.1  NaN  Homo sapiens    erythrocytewildtypecomponentI
# 7652   5.3.1.1  NaN  Homo sapiens   erythrocytewildtypecomponentII
# 7653   5.3.1.1  NaN  Homo sapiens  erythrocytewildtypecomponentIII
# 7654   5.3.1.1  NaN  Homo sapiens     wildtypeNterminallyHistagged
# 7655   5.3.1.1  NaN  Homo sapiens              erythrocytewildtype
# 7656   5.3.1.1  NaN  Homo sapiens              erythrocytewildtype
#
#                                                Reaction Cofactor   ...     pH  \
# 16    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 17    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 18    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 19    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 20    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 21    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 22    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 23    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 24    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 34    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 35    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 36    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 37    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 38    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 39    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 40    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 41    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 42    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 43    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 44    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 45    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 46    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 47    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 48    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 49    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 50    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 51    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    7.5
# 52    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    7.5
# 53    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# 54    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN   ...    NaN
# ...                                                 ...      ...   ...    ...
# 7627                                                NaN      NaN   ...    NaN
# 7628                                                NaN      NaN   ...    NaN
# 7629                                                NaN      NaN   ...    NaN
# 7630                                                NaN      NaN   ...    NaN
# 7631                                                NaN      NaN   ...    NaN
# 7632                                                NaN      NaN   ...    NaN
# 7633                                                NaN      NaN   ...    NaN
# 7634                                                NaN      NaN   ...    NaN
# 7635                                                NaN      NaN   ...    NaN
# 7636                                                NaN      NaN   ...    NaN
# 7637                                                NaN      NaN   ...    NaN
# 7638  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.5
# 7639  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.5
# 7640  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.5
# 7641  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.5
# 7642  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.5
# 7643  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.5
# 7644  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.5
# 7645  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.5
# 7646  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.9
# 7647  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.9
# 7648  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.6
# 7649  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.6
# 7650  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.6
# 7651  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.6
# 7652  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.6
# 7653  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.6
# 7654  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    7.4
# 7655  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    NaN
# 7656  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN   ...    NaN
#
#      Temp (°C)                                       Buffer/Media  \
# 16         NaN                                                NaN
# 17         NaN                                                NaN
# 18         NaN                                                NaN
# 19         NaN                                                NaN
# 20        23.0                                                NaN
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23        23.0                                                NaN
# 24        23.0                                                NaN
# 34         NaN                                                NaN
# 35         NaN                                                NaN
# 36         NaN                                                NaN
# 37         NaN                                                NaN
# 38         NaN                                                NaN
# 39        23.0                                                NaN
# 40         NaN                                                NaN
# 41         NaN                                                NaN
# 42         NaN                                                NaN
# 43         NaN                                                NaN
# 44         NaN                                                NaN
# 45         NaN                                                NaN
# 46         NaN                                                NaN
# 47         NaN                                                NaN
# 48         NaN                                                NaN
# 49        23.0                                                NaN
# 50         NaN                                                NaN
# 51        25.0                                                NaN
# 52        25.0                                                NaN
# 53         NaN                                                NaN
# 54         NaN                                                NaN
# ...        ...                                                ...
# 7627       NaN                                                NaN
# 7628       NaN                                                NaN
# 7629       NaN                                                NaN
# 7630       NaN                                                NaN
# 7631       NaN                                                NaN
# 7632       NaN                                                NaN
# 7633       NaN                                                NaN
# 7634       NaN                                                NaN
# 7635       NaN                                                NaN
# 7636       NaN                                                NaN
# 7637       NaN                                                NaN
# 7638      25.0  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...
# 7639      25.0  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...
# 7640      25.0  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...
# 7641      25.0  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...
# 7642      25.0  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...
# 7643      25.0  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...
# 7644      25.0  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...
# 7645      25.0  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...
# 7646       NaN  2 mM Triethanolamine,  5.4 mM EDTA, 0.67 mg/ml...
# 7647       NaN  2 mM Triethanolamine, 5.4 mM EDTA, 0.67 mg/ml ...
# 7648      30.0  50 mM triethanolamine, 1 mM EDTA, 0.15 mM NADH...
# 7649      30.0  50 mM triethanolamine, 1 mM EDTA, 0.15 mM NADH...
# 7650      30.0  50 mM triethanolamine, 1 mM EDTA, 0.15 mM NADH...
# 7651      30.0  50 mM triethanolamine, 1 mM EDTA, 0.3 mM NAD, ...
# 7652      30.0  50 mM triethanolamine, 1 mM EDTA, 0.3 mM NAD, ...
# 7653      30.0  50 mM triethanolamine, 1 mM EDTA, 0.3 mM NAD, ...
# 7654      25.0  100 mM triethanolamine, 10 mM EDTA, 0.2 mM NAD...
# 7655       NaN                                                NaN
# 7656      37.0                                                NaN
#
#              Uniprot  References Data Point  \
# 16               NaN         RF1        NaN
# 17               NaN         RF1        NaN
# 18               NaN         RF1        NaN
# 19               NaN         RF1        NaN
# 20    P00326, P08319         RF2        NaN
# 21               NaN         RF1        NaN
# 22               NaN         RF1        NaN
# 23    P00326, P08319         RF2        NaN
# 24    P00326, P08319         RF2        NaN
# 34               NaN         RF1        NaN
# 35               NaN         RF1        NaN
# 36               NaN         RF1        NaN
# 37               NaN         RF1        NaN
# 38               NaN         RF1        NaN
# 39    P00326, P08319         RF2        NaN
# 40               NaN         RF1        NaN
# 41               NaN         RF1        NaN
# 42               NaN         RF1        NaN
# 43               NaN         RF1        NaN
# 44               NaN         RF1        NaN
# 45               NaN         RF1        NaN
# 46               NaN         RF1        NaN
# 47               NaN         RF1        NaN
# 48               NaN         RF1        NaN
# 49    P00326, P08319         RF2        NaN
# 50               NaN         RF1        NaN
# 51               NaN         RF1        NaN
# 52               NaN         RF1        NaN
# 53               NaN         RF5        NaN
# 54               NaN         RF1        NaN
# ...              ...         ...        ...
# 7627             NaN         RF2        NaN
# 7628             NaN         RF3        NaN
# 7629             NaN         RF4        NaN
# 7630             NaN         RF3        NaN
# 7631             NaN         RF3        NaN
# 7632             NaN         RF2        NaN
# 7633             NaN         RF2        NaN
# 7634             NaN         RF4        NaN
# 7635             NaN         RF3        NaN
# 7636             NaN         RF3        NaN
# 7637             NaN         RF3        NaN
# 7638          P60174         RF5         S1
# 7639          P60174         RF5         S2
# 7640          P60174         RF5         S3
# 7641          P60174         RF5         S4
# 7642          P60174         RF5         S5
# 7643          P60174         RF5         S6
# 7644          P60174         RF5         S7
# 7645          P60174         RF5         S8
# 7646          P60174         RF4         S9
# 7647          P60174         RF4        S10
# 7648          P60174         RF3        S11
# 7649          P60174         RF3        S12
# 7650          P60174         RF3        S13
# 7651          P60174         RF3        S14
# 7652          P60174         RF3        S15
# 7653          P60174         RF3        S16
# 7654          P60174         RF6        S21
# 7655          P60174         RF7        S23
# 7656          P60174         RF9        S27
#
#                                               Notes BIGG ID     BIGG NAME  \
# 16                             isoenzyme beta1beta1   acald  acetaldehyde
# 17    isoenzyme gamma2gamma2; isoenzymes beta2beta2   acald  acetaldehyde
# 18                            isoenzymes beta2beta2   acald  acetaldehyde
# 19                           isoenzyme gamma1gamma1   acald  acetaldehyde
# 20                             isozyme ADH1C at 21-   acald  acetaldehyde
# 21                             isoenzyme beta3beta3   acald  acetaldehyde
# 22                             isoenzyme alphaalpha   acald  acetaldehyde
# 23                              isozyme ADH4 at 21-   acald  acetaldehyde
# 24                              isozyme ADH2 at 21-   acald  acetaldehyde
# 34                             isoenzyme beta1beta1    etoh       ethanol
# 35                                              NaN    etoh       ethanol
# 36                             isoenzyme beta1beta1    etoh       ethanol
# 37                                              NaN    etoh       ethanol
# 38                           isoenzyme gamma2gamma2    etoh       ethanol
# 39                             isozyme ADH1C at 21-    etoh       ethanol
# 40                             isoenzyme beta2beta2    etoh       ethanol
# 41                             isoenzyme beta2beta2    etoh       ethanol
# 42                           isoenzyme gamma1gamma1    etoh       ethanol
# 43                             isoenzyme alphaalpha    etoh       ethanol
# 44                             isoenzyme beta1beta1    etoh       ethanol
# 45                            isoenzyme alphagamma1    etoh       ethanol
# 46                           isoenzyme gamma2gamma2    etoh       ethanol
# 47                                              NaN    etoh       ethanol
# 48                           isoenzyme gamma1gamma1    etoh       ethanol
# 49                              isozyme ADH4 at 21-    etoh       ethanol
# 50                             isoenzyme alphaalpha    etoh       ethanol
# 51                      recombinant allozyme Ile308    etoh       ethanol
# 52                      recombinant allozyme Val308    etoh       ethanol
# 53                                              NaN    etoh       ethanol
# 54                                              NaN    etoh       ethanol
# ...                                             ...     ...           ...
# 7627                                    isoenzyme B     g3p           NaN
# 7628                                  enzyme form I     g3p           NaN
# 7629                                            NaN     g3p           NaN
# 7630                                 enzyme form II     g3p           NaN
# 7631                                enzyme form III     g3p           NaN
# 7632                                    isoenzyme B    dhap           NaN
# 7633                                    isoenzyme A    dhap           NaN
# 7634                                            NaN    dhap           NaN
# 7635                                enzyme form III    dhap           NaN
# 7636                                 enzyme form II    dhap           NaN
# 7637                                  enzyme form I    dhap           NaN
# 7638                                            NaN     g3p           NaN
# 7639                                            NaN     g3p           NaN
# 7640                                            NaN     g3p           NaN
# 7641                                            NaN     g3p           NaN
# 7642                                            NaN    dhap           NaN
# 7643                                            NaN    dhap           NaN
# 7644                                            NaN    dhap           NaN
# 7645                                            NaN    dhap           NaN
# 7646                                            NaN     g3p           NaN
# 7647                                            NaN    dhap           NaN
# 7648                                            NaN     g3p           NaN
# 7649                                            NaN     g3p           NaN
# 7650                                            NaN     g3p           NaN
# 7651                                            NaN    dhap           NaN
# 7652                                            NaN    dhap           NaN
# 7653                                            NaN    dhap           NaN
# 7654                                  coupled assay     g3p           NaN
# 7655                                  not available    dhap           NaN
# 7656         mean from 5 indiviudals, not available     g3p           NaN
#
#      KEEPing
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 34       NaN
# 35       NaN
# 36       NaN
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41       NaN
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46       NaN
# 47       NaN
# 48       NaN
# 49       NaN
# 50       NaN
# 51       NaN
# 52       NaN
# 53       NaN
# 54       NaN
# ...      ...
# 7627     NaN
# 7628     NaN
# 7629     NaN
# 7630     NaN
# 7631     NaN
# 7632     NaN
# 7633     NaN
# 7634     NaN
# 7635     NaN
# 7636     NaN
# 7637     NaN
# 7638     NaN
# 7639     NaN
# 7640     NaN
# 7641     NaN
# 7642     NaN
# 7643     NaN
# 7644     NaN
# 7645     NaN
# 7646     NaN
# 7647     NaN
# 7648     NaN
# 7649     NaN
# 7650     NaN
# 7651     NaN
# 7652     NaN
# 7653     NaN
# 7654     NaN
# 7655     NaN
# 7656     NaN
#
# [5225 rows x 29 columns]

# %% [markdown]
# # Trial 1 --> See how much has mapped so far
#
# add location of reaction info from model
#
# Add bigg id rxn for each row

# %%
Kinetic__Match.index=range(len(Kinetic__Match.index))

# %%
dictionary.values()
# Out:
# dict_values([[[2, 'EC_Comp'], [64, 'EC_Comp']], [[2, 'EC_Comp'], [70, 'EC_Comp'], [79, 'EC_Comp'], [142, 'EC_Comp'], [180, 'EC_Comp'], [181, 'EC_Comp']], [[64, 'EC_Comp'], [120, 'EC_Comp']], [[2, 'EC_Comp']], [], [], [], [], [[180, 'EC_Comp']], [[66, 'EC_Comp']], [[189, 'EC_Comp']], [[63, 'EC_Comp'], [64, 'EC_Comp']], [[79, 'EC_Comp'], [181, 'EC_Comp']], [], [], [[80, 'EC_Comp'], [81, 'EC_Comp']], [[70, 'EC_Comp']], [[71, 'EC_Comp']], [], [], [[133, 'EC_Comp']], [], [], [], [], [], [], [[103, 'EC_Comp']], [], [[2, 'EC_Comp']], [], [], [], [], [], [], [], [], [[142, 'EC_Comp']], [], [], [], [], [], [], [[5, 'EC_Comp'], [116, 'EC_Comp']], [[0, 'EC_Comp'], [18, 'EC_Comp'], [102, 'EC_Comp'], [135, 'EC_Comp']], [[98, 'EC_Comp']], [[135, 'EC_Comp']], [], [], [[93, 'EC_Comp'], [94, 'EC_Comp'], [95, 'EC_Comp']], [[5, 'EC_Comp']], [], [], [[98, 'EC_Comp']], [], [[102, 'EC_Comp']], [[0, 'EC_Comp'], [18, 'EC_Comp']], [[34, 'EC_Comp']], [], [[34, 'EC_Comp']], [], [], [], [], [], [[11, 'EC_Comp']], [[57, 'EC_Comp']], [[11, 'EC_Comp']], [[54, 'EC_Comp'], [55, 'EC_Comp']], [], [], [], [], [], [], [[99, 'EC_Comp']], [[119, 'EC_Comp'], [127, 'EC_Comp'], [129, 'EC_Comp']], [[145, 'EC_Comp']], [[45, 'EC_Comp']], [[107, 'EC_Comp']], [[108, 'EC_Comp']], [[89, 'EC_Comp']], [], [[129, 'EC_Comp']], [], [], [[0, 'EC_Comp'], [18, 'EC_Comp'], [52, 'EC_Comp'], [102, 'EC_Comp']], [], [[114, 'EC_Comp']], [], [], [], [], [[65, 'EC_Comp'], [115, 'EC_Comp']], [[115, 'EC_Comp']], [], [], [], [[115, 'EC_Comp']], [], [], [], [], [], [[74, 'EC_Comp']], [], [], [], [[110, 'EC_Comp']], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [[186, 'EC_Comp']], [], [[51, 'EC_Comp'], [136, 'EC_Comp']], [[176, 'EC_Comp'], [179, 'EC_Comp']], [[92, 'EC_Comp']], [[59, 'EC_Comp']], [[170, 'EC_Comp'], [171, 'EC_Comp']], [[7, 'EC_Comp'], [102, 'EC_Comp']], [[73, 'EC_Comp']], [[0, 'EC_Comp'], [18, 'EC_Comp']], [[32, 'EC_Comp'], [33, 'EC_Comp']], [[7, 'EC_Comp'], [8, 'EC_Comp'], [121, 'EC_Comp']], [[7, 'EC_Comp']], [], [], [[60, 'EC_Comp']], [[73, 'EC_Comp']], [[109, 'EC_Comp']], [], [], [], [[73, 'EC_Comp']], [], [], [[9, 'EC_Comp']], [[68, 'EC_Comp']], [], [], [], [], [[97, 'EC_Comp'], [178, 'EC_Comp']], [], [], [], [], [[97, 'EC_Comp']], [], [[178, 'EC_Comp']], [], [], [], [], [[111, 'EC_Comp']], [], [], [], [], [[26, 'EC_Comp'], [96, 'EC_Comp'], [124, 'EC_Comp'], [187, 'EC_Comp']], [[19, 'EC_Comp']], [[161, 'EC_Comp'], [187, 'EC_Comp']], [], [[96, 'EC_Comp']], [], [], [[6, 'EC_Comp']], [[141, 'EC_Comp'], [143, 'EC_Comp'], [174, 'EC_Comp']], [], [[140, 'EC_Comp'], [183, 'EC_Comp']], [[140, 'EC_Comp']], [], [[183, 'EC_Comp']], [], [], [], [], [], [], [], [[30, 'EC_Comp']], [], [], [[82, 'EC_Comp']], [[185, 'EC_Comp']], [], [], [], [], [], [], [], [], [], [], [], [[104, 'EC_Comp'], [173, 'EC_Comp']], [[122, 'EC_Comp']], [[14, 'EC_Comp'], [173, 'EC_Comp']], [[27, 'EC_Comp'], [91, 'EC_Comp'], [146, 'EC_Comp'], [147, 'EC_Comp'], [148, 'EC_Comp'], [149, 'EC_Comp'], [150, 'EC_Comp'], [151, 'EC_Comp'], [152, 'EC_Comp']], [[137, 'EC_Comp']], [[130, 'EC_Comp']], [[173, 'EC_Comp']], [[160, 'EC_Comp']], [], [[29, 'EC_Comp']], [], [], [], [[134, 'EC_Comp']], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [[118, 'EC_Comp']], [[4, 'EC_Comp']], [], [], [[182, 'EC_Comp']], [[162, 'EC_Comp']], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [[23, 'EC_Comp']], [[56, 'EC_Comp']], [], [[21, 'EC_Comp']], [], [], [], [], [], [[88, 'EC_Comp'], [144, 'EC_Comp']], [[179, 'EC_Comp']], [], [], [], [[159, 'EC_Comp']], [], [], [], [], [], [], [], [], [], [[90, 'EC_Comp']], [], [], [], [], [[58, 'EC_Comp']], [], [], [], [[46, 'EC_Comp']], [[67, 'EC_Comp']], [], [], [], [[153, 'EC_Comp']], [], [], [[36, 'EC_Comp']], [], [], [[132, 'EC_Comp']], [], [[69, 'EC_Comp']], [[38, 'EC_Comp'], [39, 'EC_Comp'], [40, 'EC_Comp'], [62, 'EC_Comp'], [83, 'EC_Comp'], [131, 'EC_Comp'], [139, 'EC_Comp']], [[38, 'EC_Comp'], [39, 'EC_Com ...

# %%
found=0
not_found=0
for i in range(len(Kinetic__Match["EC_Number"])):
    kinetic_ec=Kinetic__Match["EC_Number"][i]
    for key, value in dictionary.items():
        if kinetic_ec == key and str(value) !="[]":
        #print (kinetic_ec)
            found+=1
    else: 
        not_found+=1
        
        
print (found, not_found)
if not_found==0:
    print ("AWESOME, all mapped kinetic data")
# Out:
# 2643 5225

# %%
#Lets append the data to Kinetic DF 
#Trial 1: get dictonary to map to Kinetic DF 
#Trial 2: get loc from kinetic df to map reaction info 
DF_EC_LOC_LIST=[]
for i in range(len(Kinetic__Match["EC_Number"])):
    kinetic_ec=Kinetic__Match["EC_Number"][i]
    for key, value in dictionary.items():
        if kinetic_ec == key:
            DF_EC_LOC_LIST.append(value)

# %%
#Sanity check
len(DF_EC_LOC_LIST)==len(Kinetic__Match["EC_Number"])
# Out:
# True

# %%
#appending row to df
Kinetic__Match["df_EC_Loc"]=DF_EC_LOC_LIST
# Out:
# C:\Users\zafri\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:2 SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Kinetic__Match.columns
# Out:
# Index(['Entry ID', 'Recommended Enzyme Name', 'Reaction ID',
#        'Enzymatic Activity', 'EC_Number', 'Gene', 'Organism', 'Strain/Tissue',
#        'Reaction', 'Cofactor', 'Cofactor Concentration', 'Substrate',
#        'Value Type', 'Value', 'Deviation', 'Units', 'Structure', 'Regulation',
#        'Regulation Mechanism', 'pH', 'Temp (°C)', 'Buffer/Media', 'Uniprot',
#        'References', 'Data Point', 'Notes', 'BIGG ID', 'BIGG NAME', 'KEEPing',
#        'df_EC_Loc'],
#       dtype='object')

# %%
Kinetic__Match[["EC_Number",'BIGG ID', 'BIGG NAME', 'KEEPing',
       'df_EC_Loc', "Reaction" ]]
# Out:
#      EC_Number BIGG ID     BIGG NAME KEEPing                      df_EC_Loc  \
# 0      1.1.1.1   acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 1      1.1.1.1   acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 2      1.1.1.1   acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 3      1.1.1.1   acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 4      1.1.1.1   acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 5      1.1.1.1   acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 6      1.1.1.1   acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 7      1.1.1.1   acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 8      1.1.1.1   acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 9      1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 10     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 11     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 12     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 13     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 14     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 15     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 16     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 17     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 18     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 19     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 20     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 21     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 22     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 23     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 24     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 25     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 26     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 27     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 28     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 29     1.1.1.1    etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# ...        ...     ...           ...     ...                            ...
# 5195   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5196   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5197   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5198   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5199   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5200   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5201   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5202   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5203   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5204   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5205   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5206   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5207   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5208   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5209   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5210   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5211   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5212   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5213   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5214   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5215   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5216   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5217   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5218   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5219   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5220   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5221   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5222   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
# 5223   5.3.1.1    dhap           NaN     NaN               [[172, EC_Comp]]
# 5224   5.3.1.1     g3p           NaN     NaN               [[172, EC_Comp]]
#
#                                                Reaction
# 0     a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 1     a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 2     a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 3     a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 4     a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 5     a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 6     a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 7     a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 8     a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 9     a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 10    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 11    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 12    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 13    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 14    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 15    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 16    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 17    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 18    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 19    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 20    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 21    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 22    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 23    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 24    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 25    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 26    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 27    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 28    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# 29    a primary alcohol + NAD+ <=> an aldehyde + NAD...
# ...                                                 ...
# 5195                                                NaN
# 5196                                                NaN
# 5197                                                NaN
# 5198                                                NaN
# 5199                                                NaN
# 5200                                                NaN
# 5201                                                NaN
# 5202                                                NaN
# 5203                                                NaN
# 5204                                                NaN
# 5205                                                NaN
# 5206  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5207  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5208  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5209  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5210  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5211  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5212  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5213  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5214  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5215  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5216  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5217  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5218  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5219  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5220  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5221  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5222  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5223  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
# 5224  D-Glyceraldehyde 3-phosphate = Glycerone phosp...
#
# [5225 rows x 6 columns]

# %%
#Trial 1 successful 
#trial 2 add df_EC info to kinetic rows 

# rename reaction in Kinetic to be specific

# %%
Kinetic__Match=Kinetic__Match.rename(columns={"Reaction": "Reaction_Kinetic_Scrape"})

# %%
Kinetic__Match
# Out:
#       Entry ID     Recommended Enzyme Name Reaction ID  Enzymatic Activity  \
# 0           74       alcohol dehydrogenase         NaN                 NaN
# 1           75       alcohol dehydrogenase         NaN                 NaN
# 2           76       alcohol dehydrogenase         NaN                 NaN
# 3           77       alcohol dehydrogenase         NaN                 NaN
# 4           78       alcohol dehydrogenase         NaN                 NaN
# 5           79       alcohol dehydrogenase         NaN                 NaN
# 6           80       alcohol dehydrogenase         NaN                 NaN
# 7           81       alcohol dehydrogenase         NaN                 NaN
# 8           82       alcohol dehydrogenase         NaN                 NaN
# 9           99       alcohol dehydrogenase         NaN                 NaN
# 10         100       alcohol dehydrogenase         NaN                 NaN
# 11         101       alcohol dehydrogenase         NaN                 NaN
# 12         102       alcohol dehydrogenase         NaN                 NaN
# 13         103       alcohol dehydrogenase         NaN                 NaN
# 14         104       alcohol dehydrogenase         NaN                 NaN
# 15         105       alcohol dehydrogenase         NaN                 NaN
# 16         106       alcohol dehydrogenase         NaN                 NaN
# 17         107       alcohol dehydrogenase         NaN                 NaN
# 18         108       alcohol dehydrogenase         NaN                 NaN
# 19         109       alcohol dehydrogenase         NaN                 NaN
# 20         110       alcohol dehydrogenase         NaN                 NaN
# 21         111       alcohol dehydrogenase         NaN                 NaN
# 22         112       alcohol dehydrogenase         NaN                 NaN
# 23         113       alcohol dehydrogenase         NaN                 NaN
# 24         114       alcohol dehydrogenase         NaN                 NaN
# 25         115       alcohol dehydrogenase         NaN                 NaN
# 26         116       alcohol dehydrogenase         NaN                 NaN
# 27         117       alcohol dehydrogenase         NaN                 NaN
# 28         118       alcohol dehydrogenase         NaN                 NaN
# 29         119       alcohol dehydrogenase         NaN                 NaN
# ...        ...                         ...         ...                 ...
# 5195         4  Triose-phosphate isomerase         NaN                 NaN
# 5196         5  Triose-phosphate isomerase         NaN                 NaN
# 5197         6  Triose-phosphate isomerase         NaN                 NaN
# 5198         7  Triose-phosphate isomerase         NaN                 NaN
# 5199         8  Triose-phosphate isomerase         NaN                 NaN
# 5200         9  Triose-phosphate isomerase         NaN                 NaN
# 5201        10  Triose-phosphate isomerase         NaN                 NaN
# 5202        11  Triose-phosphate isomerase         NaN                 NaN
# 5203        12  Triose-phosphate isomerase         NaN                 NaN
# 5204        13  Triose-phosphate isomerase         NaN                 NaN
# 5205        14  Triose-phosphate isomerase         NaN                 NaN
# 5206        15  triose-phosphate isomerase         NaN                 NaN
# 5207        17  triose-phosphate isomerase         NaN                 NaN
# 5208        19  triose-phosphate isomerase         NaN                 NaN
# 5209        21  triose-phosphate isomerase         NaN                 NaN
# 5210        23  triose-phosphate isomerase         NaN                 NaN
# 5211        24  triose-phosphate isomerase         NaN                 NaN
# 5212        25  triose-phosphate isomerase         NaN                 NaN
# 5213        26  triose-phosphate isomerase         NaN                 NaN
# 5214        28  triose-phosphate isomerase         NaN                 NaN
# 5215        31  triose-phosphate isomerase         NaN                 NaN
# 5216        34  triose-phosphate isomerase         NaN                 NaN
# 5217        37  triose-phosphate isomerase         NaN                 NaN
# 5218        40  triose-phosphate isomerase         NaN                 NaN
# 5219        43  triose-phosphate isomerase         NaN                 NaN
# 5220        46  triose-phosphate isomerase         NaN                 NaN
# 5221        49  triose-phosphate isomerase         NaN                 NaN
# 5222        60  triose-phosphate isomerase         NaN                 NaN
# 5223        66  triose-phosphate isomerase         NaN                 NaN
# 5224        76  triose-phosphate isomerase         NaN                 NaN
#
#      EC_Number Gene      Organism                    Strain/Tissue  \
# 0      1.1.1.1  NaN  Homo sapiens                              NaN
# 1      1.1.1.1  NaN  Homo sapiens                              NaN
# 2      1.1.1.1  NaN  Homo sapiens                              NaN
# 3      1.1.1.1  NaN  Homo sapiens                              NaN
# 4      1.1.1.1  NaN  Homo sapiens                              NaN
# 5      1.1.1.1  NaN  Homo sapiens                              NaN
# 6      1.1.1.1  NaN  Homo sapiens                              NaN
# 7      1.1.1.1  NaN  Homo sapiens                              NaN
# 8      1.1.1.1  NaN  Homo sapiens                              NaN
# 9      1.1.1.1  NaN  Homo sapiens                              NaN
# 10     1.1.1.1  NaN  Homo sapiens                              NaN
# 11     1.1.1.1  NaN  Homo sapiens                              NaN
# 12     1.1.1.1  NaN  Homo sapiens                              NaN
# 13     1.1.1.1  NaN  Homo sapiens                              NaN
# 14     1.1.1.1  NaN  Homo sapiens                              NaN
# 15     1.1.1.1  NaN  Homo sapiens                              NaN
# 16     1.1.1.1  NaN  Homo sapiens                              NaN
# 17     1.1.1.1  NaN  Homo sapiens                              NaN
# 18     1.1.1.1  NaN  Homo sapiens                              NaN
# 19     1.1.1.1  NaN  Homo sapiens                              NaN
# 20     1.1.1.1  NaN  Homo sapiens                              NaN
# 21     1.1.1.1  NaN  Homo sapiens                              NaN
# 22     1.1.1.1  NaN  Homo sapiens                              NaN
# 23     1.1.1.1  NaN  Homo sapiens                              NaN
# 24     1.1.1.1  NaN  Homo sapiens                              NaN
# 25     1.1.1.1  NaN  Homo sapiens                              NaN
# 26     1.1.1.1  NaN  Homo sapiens                              NaN
# 27     1.1.1.1  NaN  Homo sapiens                              NaN
# 28     1.1.1.1  NaN  Homo sapiens                              NaN
# 29     1.1.1.1  NaN  Homo sapiens                              NaN
# ...        ...  ...           ...                              ...
# 5195   5.3.1.1  NaN  Homo sapiens                              NaN
# 5196   5.3.1.1  NaN  Homo sapiens                              NaN
# 5197   5.3.1.1  NaN  Homo sapiens                              NaN
# 5198   5.3.1.1  NaN  Homo sapiens                              NaN
# 5199   5.3.1.1  NaN  Homo sapiens                              NaN
# 5200   5.3.1.1  NaN  Homo sapiens                              NaN
# 5201   5.3.1.1  NaN  Homo sapiens                              NaN
# 5202   5.3.1.1  NaN  Homo sapiens                              NaN
# 5203   5.3.1.1  NaN  Homo sapiens                              NaN
# 5204   5.3.1.1  NaN  Homo sapiens                              NaN
# 5205   5.3.1.1  NaN  Homo sapiens                              NaN
# 5206   5.3.1.1  NaN  Homo sapiens           skeletalmusclewildtype
# 5207   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformA
# 5208   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformC
# 5209   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformB
# 5210   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformB
# 5211   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformC
# 5212   5.3.1.1  NaN  Homo sapiens   skeletalmusclewildtypeisoformA
# 5213   5.3.1.1  NaN  Homo sapiens           skeletalmusclewildtype
# 5214   5.3.1.1  NaN  Homo sapiens                    liverwildtype
# 5215   5.3.1.1  NaN  Homo sapiens                    liverwildtype
# 5216   5.3.1.1  NaN  Homo sapiens    erythrocytewildtypecomponentI
# 5217   5.3.1.1  NaN  Homo sapiens   erythrocytewildtypecomponentII
# 5218   5.3.1.1  NaN  Homo sapiens  erythrocytewildtypecomponentIII
# 5219   5.3.1.1  NaN  Homo sapiens    erythrocytewildtypecomponentI
# 5220   5.3.1.1  NaN  Homo sapiens   erythrocytewildtypecomponentII
# 5221   5.3.1.1  NaN  Homo sapiens  erythrocytewildtypecomponentIII
# 5222   5.3.1.1  NaN  Homo sapiens     wildtypeNterminallyHistagged
# 5223   5.3.1.1  NaN  Homo sapiens              erythrocytewildtype
# 5224   5.3.1.1  NaN  Homo sapiens              erythrocytewildtype
#
#                                 Reaction_Kinetic_Scrape Cofactor  \
# 0     a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 1     a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 2     a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 3     a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 4     a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 5     a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 6     a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 7     a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 8     a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 9     a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 10    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 11    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 12    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 13    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 14    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 15    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 16    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 17    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 18    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 19    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 20    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 21    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 22    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 23    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 24    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 25    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 26    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 27    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 28    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# 29    a primary alcohol + NAD+ <=> an aldehyde + NAD...      NaN
# ...                                                 ...      ...
# 5195                                                NaN      NaN
# 5196                                                NaN      NaN
# 5197                                                NaN      NaN
# 5198                                                NaN      NaN
# 5199                                                NaN      NaN
# 5200                                                NaN      NaN
# 5201                                                NaN      NaN
# 5202                                                NaN      NaN
# 5203                                                NaN      NaN
# 5204                                                NaN      NaN
# 5205                                                NaN      NaN
# 5206  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5207  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5208  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5209  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5210  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5211  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5212  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5213  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5214  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5215  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5216  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5217  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5218  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5219  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5220  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5221  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5222  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5223  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
# 5224  D-Glyceraldehyde 3-phosphate = Glycerone phosp...      NaN
#
#                   ...               Temp (°C)  \
# 0                 ...                     NaN
# 1                 ...                     NaN
# 2                 ...                     NaN
# 3                 ...                     NaN
# 4                 ...                    23.0
# 5                 ...                     NaN
# 6                 ...                     NaN
# 7                 ...                    23.0
# 8                 ...                    23.0
# 9                 ...                     NaN
# 10                ...                     NaN
# 11                ...                     NaN
# 12                ...                     NaN
# 13                ...                     NaN
# 14                ...                    23.0
# 15                ...                     NaN
# 16                ...                     NaN
# 17                ...                     NaN
# 18                ...                     NaN
# 19                ...                     NaN
# 20                ...                     NaN
# 21                ...                     NaN
# 22                ...                     NaN
# 23                ...                     NaN
# 24                ...                    23.0
# 25                ...                     NaN
# 26                ...                    25.0
# 27                ...                    25.0
# 28                ...                     NaN
# 29                ...                     NaN
# ...               ...                     ...
# 5195              ...                     NaN
# 5196              ...                     NaN
# 5197              ...                     NaN
# 5198              ...                     NaN
# 5199              ...                     NaN
# 5200              ...                     NaN
# 5201              ...                     NaN
# 5202              ...                     NaN
# 5203              ...                     NaN
# 5204              ...                     NaN
# 5205              ...                     NaN
# 5206              ...                    25.0
# 5207              ...                    25.0
# 5208              ...                    25.0
# 5209              ...                    25.0
# 5210              ...                    25.0
# 5211              ...                    25.0
# 5212              ...                    25.0
# 5213              ...                    25.0
# 5214              ...                     NaN
# 5215              ...                     NaN
# 5216              ...                    30.0
# 5217              ...                    30.0
# 5218              ...                    30.0
# 5219              ...                    30.0
# 5220              ...                    30.0
# 5221              ...                    30.0
# 5222              ...                    25.0
# 5223              ...                     NaN
# 5224              ...                    37.0
#
#                                            Buffer/Media         Uniprot  \
# 0                                                   NaN             NaN
# 1                                                   NaN             NaN
# 2                                                   NaN             NaN
# 3                                                   NaN             NaN
# 4                                                   NaN  P00326, P08319
# 5                                                   NaN             NaN
# 6                                                   NaN             NaN
# 7                                                   NaN  P00326, P08319
# 8                                                   NaN  P00326, P08319
# 9                                                   NaN             NaN
# 10                                                  NaN             NaN
# 11                                                  NaN             NaN
# 12                                                  NaN             NaN
# 13                                                  NaN             NaN
# 14                                                  NaN  P00326, P08319
# 15                                                  NaN             NaN
# 16                                                  NaN             NaN
# 17                                                  NaN             NaN
# 18                                                  NaN             NaN
# 19                                                  NaN             NaN
# 20                                                  NaN             NaN
# 21                                                  NaN             NaN
# 22                                                  NaN             NaN
# 23                                                  NaN             NaN
# 24                                                  NaN  P00326, P08319
# 25                                                  NaN             NaN
# 26                                                  NaN             NaN
# 27                                                  NaN             NaN
# 28                                                  NaN             NaN
# 29                                                  NaN             NaN
# ...                                                 ...             ...
# 5195                                                NaN             NaN
# 5196                                                NaN             NaN
# 5197                                                NaN             NaN
# 5198                                                NaN             NaN
# 5199                                                NaN             NaN
# 5200                                                NaN             NaN
# 5201                                                NaN             NaN
# 5202                                                NaN             NaN
# 5203                                                NaN             NaN
# 5204                                                NaN             NaN
# 5205                                                NaN             NaN
# 5206  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...          P60174
# 5207  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...          P60174
# 5208  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...          P60174
# 5209  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...          P60174
# 5210  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...          P60174
# 5211  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...          P60174
# 5212  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...          P60174
# 5213  100 mM Triethanolamine-HCl, 0.1 % BSA, 2 mM Di...          P60174
# 5214  2 mM Triethanolamine,  5.4 mM EDTA, 0.67 mg/ml...          P60174
# 5215  2 mM Triethanolamine, 5.4 mM EDTA, 0.67 mg/ml ...          P60174
# 5216  50 mM triethanolamine, 1 mM EDTA, 0.15 mM NADH...          P60174
# 5217  50 mM triethanolamine, 1 mM EDTA, 0.15 mM NADH...          P60174
# 5218  50 mM triethanolamine, 1 mM EDTA, 0.15 mM NADH...          P60174
# 5219  50 mM triethanolamine, 1 mM EDTA, 0.3 mM NAD, ...          P60174
# 5220  50 mM triethanolamine, 1 mM EDTA, 0.3 mM NAD, ...          P60174
# 5221  50 mM triethanolamine, 1 mM EDTA, 0.3 mM NAD, ...          P60174
# 5222  100 mM triethanolamine, 10 mM EDTA, 0.2 mM NAD...          P60174
# 5223                                                NaN          P60174
# 5224                                                NaN          P60174
#
#      References  Data Point                                          Notes  \
# 0           RF1         NaN                           isoenzyme beta1beta1
# 1           RF1         NaN  isoenzyme gamma2gamma2; isoenzymes beta2beta2
# 2           RF1         NaN                          isoenzymes beta2beta2
# 3           RF1         NaN                         isoenzyme gamma1gamma1
# 4           RF2         NaN                           isozyme ADH1C at 21-
# 5           RF1         NaN                           isoenzyme beta3beta3
# 6           RF1         NaN                           isoenzyme alphaalpha
# 7           RF2         NaN                            isozyme ADH4 at 21-
# 8           RF2         NaN                            isozyme ADH2 at 21-
# 9           RF1         NaN                           isoenzyme beta1beta1
# 10          RF1         NaN                                            NaN
# 11          RF1         NaN                           isoenzyme beta1beta1
# 12          RF1         NaN                                            NaN
# 13          RF1         NaN                         isoenzyme gamma2gamma2
# 14          RF2         NaN                           isozyme ADH1C at 21-
# 15          RF1         NaN                           isoenzyme beta2beta2
# 16          RF1         NaN                           isoenzyme beta2beta2
# 17          RF1         NaN                         isoenzyme gamma1gamma1
# 18          RF1         NaN                           isoenzyme alphaalpha
# 19          RF1         NaN                           isoenzyme beta1beta1
# 20          RF1         NaN                          isoenzyme alphagamma1
# 21          RF1         NaN                         isoenzyme gamma2gamma2
# 22          RF1         NaN                                            NaN
# 23          RF1         NaN                         isoenzyme gamma1gamma1
# 24          RF2         NaN                            isozyme ADH4 at 21-
# 25          RF1         NaN                           isoenzyme alphaalpha
# 26          RF1         NaN                    recombinant allozyme Ile308
# 27          RF1         NaN                    recombinant allozyme Val308
# 28          RF5         NaN                                            NaN
# 29          RF1         NaN                                            NaN
# ...         ...         ...                                            ...
# 5195        RF2         NaN                                    isoenzyme B
# 5196        RF3         NaN                                  enzyme form I
# 5197        RF4         NaN                                            NaN
# 5198        RF3         NaN                                 enzyme form II
# 5199        RF3         NaN                                enzyme form III
# 5200        RF2         NaN                                    isoenzyme B
# 5201        RF2         NaN                                    isoenzyme A
# 5202        RF4         NaN                                            NaN
# 5203        RF3         NaN                                enzyme form III
# 5204        RF3         NaN                                 enzyme form II
# 5205        RF3         NaN                                  enzyme form I
# 5206        RF5          S1                                            NaN
# 5207        RF5          S2                                            NaN
# 5208        RF5          S3                                            NaN
# 5209        RF5          S4                                            NaN
# 5210        RF5          S5                                            NaN
# 5211        RF5          S6                                            NaN
# 5212        RF5          S7                                            NaN
# 5213        RF5          S8                                            NaN
# 5214        RF4          S9                                            NaN
# 5215        RF4         S10                                            NaN
# 5216        RF3         S11                                            NaN
# 5217        RF3         S12                                            NaN
# 5218        RF3         S13                                            NaN
# 5219        RF3         S14                                            NaN
# 5220        RF3         S15                                            NaN
# 5221        RF3         S16                                            NaN
# 5222        RF6         S21                                  coupled assay
# 5223        RF7         S23                                  not available
# 5224        RF9         S27         mean from 5 indiviudals, not available
#
#      BIGG ID     BIGG NAME KEEPing                      df_EC_Loc
# 0      acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 1      acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 2      acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 3      acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 4      acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 5      acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 6      acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 7      acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 8      acald  acetaldehyde     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 9       etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 10      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 11      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 12      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 13      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 14      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 15      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 16      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 17      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 18      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 19      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 20      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 21      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 22      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 23      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 24      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 25      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 26      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 27      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 28      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# 29      etoh       ethanol     NaN  [[2, EC_Comp], [64, EC_Comp]]
# ...      ...           ...     ...                            ...
# 5195     g3p           NaN     NaN               [[172, EC_Comp]]
# 5196     g3p           NaN     NaN               [[172, EC_Comp]]
# 5197     g3p           NaN     NaN               [[172, EC_Comp]]
# 5198     g3p           NaN     NaN               [[172, EC_Comp]]
# 5199     g3p           NaN     NaN               [[172, EC_Comp]]
# 5200    dhap           NaN     NaN               [[172, EC_Comp]]
# 5201    dhap           NaN     NaN               [[172, EC_Comp]]
# 5202    dhap           NaN     NaN               [[172, EC_Comp]]
# 5203    dhap           NaN     NaN               [[172, EC_Comp]]
# 5204    dhap           NaN     NaN               [[172, EC_Comp]]
# 5205    dhap           NaN     NaN               [[172, EC_Comp]]
# 5206     g3p           NaN     NaN               [[172, EC_Comp]]
# 5207     g3p           NaN     NaN               [[172, EC_Comp]]
# 5208     g3p           NaN     NaN               [[172, EC_Comp]]
# 5209     g3p           NaN     NaN               [[172, EC_Comp]]
# 5210    dhap           NaN     NaN               [[172, EC_Comp]]
# 5211    dhap           NaN     NaN               [[172, EC_Comp]]
# 5212    dhap           NaN     NaN               [[172, EC_Comp]]
# 5213    dhap           NaN     NaN               [[172, EC_Comp]]
# 5214     g3p           NaN     NaN               [[172, EC_Comp]]
# 5215    dhap           NaN     NaN               [[172, EC_Comp]]
# 5216     g3p           NaN     NaN               [[172, EC_Comp]]
# 5217     g3p           NaN     NaN               [[172, EC_Comp]]
# 5218     g3p           NaN     NaN               [[172, EC_Comp]]
# 5219    dhap           NaN     NaN               [[172, EC_Comp]]
# 5220    dhap           NaN     NaN               [[172, EC_Comp]]
# 5221    dhap           NaN     NaN               [[172, EC_Comp]]
# 5222     g3p           NaN     NaN               [[172, EC_Comp]]
# 5223    dhap           NaN     NaN               [[172, EC_Comp]]
# 5224     g3p           NaN     NaN               [[172, EC_Comp]]
#
# [5225 rows x 30 columns]

# %%
#Lets look at df_EC
df_EC
# Out:
#     ANNOT_BIGG                                        ANNOT_EC ANNOT_METANET  \
# 0    2OXOADOXm  ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']     MNXR94818
# 1      34HPPOR                                      1.13.11.27     MNXR94843
# 2       3DSPHR                                       1.1.1.102     MNXR94866
# 3         3HAO                                       1.13.11.6     MNXR94889
# 4    3HBCOAHLm                                         3.1.2.4     MNXR94891
# 5      AASAD3m                                        1.2.1.31     MNXR95158
# 6         AATA                                        2.6.1.39     MNXR95160
# 7     ACACT10m                         ['2.3.1.16', '2.3.1.9']     MNXR95195
# 8      ACACT1m                                         2.3.1.9     MNXR95194
# 9        ACITL                          ['2.3.3.8', '4.1.3.6']     MNXR95268
# 10    ACOAD10m                                        1.3.99.3     MNXR95306
# 11     ACOAD8m             ['1.3.8.4', '1.3.8.7', '1.3.99.10']     MNXR95318
# 12     ACOAD9m                         ['1.3.8.-', '1.3.99.3']     MNXR95319
# 13      ACONTm                                         4.2.1.3     MNXR95384
# 14        ADK3                         ['2.7.4.10', '2.7.4.4']     MNXR95452
# 15      ADSL1r                                         4.3.2.2     MNXR95493
# 16      ADSL2r                                         4.3.2.2     MNXR95494
# 17       AIRCr                                        4.1.1.21     MNXR95646
# 18       AKGDm  ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']     MNXR95655
# 19     ALATA_L                                         2.6.1.2     MNXR95698
# 20      AMCOXO                                         1.5.1.-     MNXR95807
# 21       ARGNm                                         3.5.3.1     MNXR95945
# 22       ARGSS                                         6.3.4.5     MNXR95949
# 23       ASNNm              ['3.5.1.1', '3.5.1.38', '3.5.5.4']     MNXR96056
# 24       ASNS1                                         6.3.5.4     MNXR96059
# 25       ASPCT                                         2.1.3.2     MNXR96080
# 26      ASPTAm                                         2.6.1.1     MNXR96079
# 27       ATPtm                                         2.7.4.6     MNXR96123
# 28      CBPSam                         ['6.3.4.16', '6.3.5.5']     MNXR96486
# 29     CHLPCTD                                        2.7.7.15     MNXR96686
# ..         ...                                             ...           ...
# 160      PRPPS                                         2.7.6.1    MNXR103215
# 161      PSERT                                        2.6.1.52    MNXR103225
# 162      PSP_L                                         3.1.3.3    MNXR103260
# 163      RNDR1                                        1.17.4.1    MNXR104060
# 164      RNDR2                                        1.17.4.1    MNXR104062
# 165      RNDR3                                        1.17.4.1    MNXR104064
# 166      RNDR4                                        1.17.4.1    MNXR104066
# 167        RPE                                         5.1.3.1    MNXR104083
# 168        RPI                                         5.3.1.6    MNXR104084
# 169       TALA                                         2.2.1.2    MNXR104715
# 170       TKT1                                         2.2.1.1    MNXR104868
# 171       TKT2                                         2.2.1.1    MNXR104869
# 172        TPI                                         5.3.1.1    MNXR104918
# 173       UMPK             ['2.7.4.14', '2.7.4.22', '2.7.4.4']    MNXR105118
# 174      VALTA                         ['2.6.1.42', '2.6.1.6']     MNXR96230
# 175     ACCOAC                                         6.4.1.2     MNXR95219
# 176     AICART                                         2.1.2.3     MNXR95639
# 177      ARGSL                                         4.3.2.1     MNXR95948
# 178     GLUPRT                                        2.4.2.14    MNXR100287
# 179       IMPC                         ['2.1.2.3', '3.5.4.10']    MNXR100783
# 180      LDH_L                                        1.1.1.27    MNXR101040
# 181        MDH                       ['1.1.1.299', '1.1.1.37']    MNXR101439
# 182      MI1PP                                        3.1.3.25    MNXR101570
# 183        PFK                                        2.7.1.11    MNXR102507
# 184      PRFGS                                         6.3.5.3    MNXR103165
# 185        PYK                                        2.7.1.40    MNXR103371
# 186       TMDS                                        2.1.1.45    MNXR104889
# 187      TYRTA   ['2.6.1.1', '2.6.1.5', '2.6.1.57', '2.6.1.9']    MNXR105000
# 188     AACOAT                                        6.2.1.16     MNXR95136
# 189   HMGCOARx                                        1.1.1.34    MNXR100659
#
#                                             Annot Keys  \
# 0    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 1    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 2    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 3    dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 4    dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 5    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 6    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 7    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 8    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 9    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 10   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 11   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 12   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 13   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 14   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 15   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 16   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 17   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 18   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 19   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 20   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 21   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 22   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 23   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 24   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 25   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 26   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 27   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 28   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 29   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# ..                                                 ...
# 160  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 161  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 162  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 163  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 164  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 165  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 166  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 167  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 168  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 169  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 170  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 171  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 172  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 173  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 174  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 175  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 176  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 177  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 178  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 179  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 180  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 181  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 182  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 183  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 184  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 185  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 186  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 187  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 188  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 189  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
#
#                                           Annot Values  \
# 0    dict_values(['SBO:0000375', '2OXOADOXm', 'META...
# 1    dict_values(['SBO:0000375', '34HPPOR', 'META:4...
# 2    dict_values(['SBO:0000375', '3DSPHR', 'META:3-...
# 3    dict_values(['SBO:0000375', '3HAO', '1.13.11.6...
# 4    dict_values(['SBO:0000375', '3HBCOAHLm', '3.1....
# 5    dict_values(['SBO:0000375', 'AASAD3m', 'META:A...
# 6    dict_values(['SBO:0000375', 'AATA', 'META:2-AM...
# 7    dict_values(['SBO:0000375', 'ACACT10m', 'META:...
# 8    dict_values(['SBO:0000375', 'ACACT1m', 'META:A...
# 9    dict_values(['SBO:0000375', 'ACITL', 'META:ATP...
# 10   dict_values(['SBO:0000375', 'ACOAD10m', '1.3.9...
# 11   dict_values(['SBO:0000375', 'ACOAD8m', 'META:R...
# 12   dict_values(['SBO:0000375', 'ACOAD9m', 'META:M...
# 13   dict_values(['SBO:0000375', 'ACONTm', '4.2.1.3...
# 14   dict_values(['SBO:0000375', 'ADK3', 'META:RXN-...
# 15   dict_values(['SBO:0000375', 'ADSL1r', 'META:AM...
# 16   dict_values(['SBO:0000375', 'ADSL2r', 'META:AI...
# 17   dict_values(['SBO:0000375', 'AIRCr', '4.1.1.21...
# 18   dict_values(['SBO:0000375', 'AKGDm', 'META:2OX...
# 19   dict_values(['SBO:0000375', 'ALATA_L', ['META:...
# 20   dict_values(['SBO:0000375', 'AMCOXO', '1.5.1.-...
# 21   dict_values(['SBO:0000375', 'ARGNm', 'META:ARG...
# 22   dict_values(['SBO:0000375', 'ARGSS', 'META:ARG...
# 23   dict_values(['SBO:0000375', 'ASNNm', 'META:ASP...
# 24   dict_values(['SBO:0000375', 'ASNS1', 'META:ASN...
# 25   dict_values(['SBO:0000375', 'ASPCT', 'META:ASP...
# 26   dict_values(['SBO:0000375', 'ASPTAm', ['META:A...
# 27   dict_values(['SBO:0000375', 'ATPtm', '2.7.4.6'...
# 28   dict_values(['SBO:0000375', 'CBPSam', 'META:RX...
# 29   dict_values(['SBO:0000375', 'CHLPCTD', 'META:2...
# ..                                                 ...
# 160  dict_values(['SBO:0000375', 'PRPPS', '2.7.6.1'...
# 161  dict_values(['SBO:0000375', 'PSERT', 'META:PSE...
# 162  dict_values(['SBO:0000375', 'PSP_L', 'META:RXN...
# 163  dict_values(['SBO:0000375', 'RNDR1', 'META:ADP...
# 164  dict_values(['SBO:0000375', 'RNDR2', 'META:GDP...
# 165  dict_values(['SBO:0000375', 'RNDR3', 'META:CDP...
# 166  dict_values(['SBO:0000375', 'RNDR4', 'META:UDP...
# 167  dict_values(['SBO:0000375', 'RPE', 'META:RIBUL...
# 168  dict_values(['SBO:0000375', 'RPI', '5.3.1.6', ...
# 169  dict_values(['SBO:0000375', 'TALA', 'META:TRAN...
# 170  dict_values(['SBO:0000375', 'TKT1', '2.2.1.1',...
# 171  dict_values(['SBO:0000375', 'TKT2', 'META:2TRA...
# 172  dict_values(['SBO:0000375', 'TPI', 'META:TRIOS...
# 173  dict_values(['SBO:0000375', 'UMPK', 'META:RXN-...
# 174  dict_values(['SBO:0000375', 'VALTA', 'META:BRA...
# 175  dict_values(['SBO:0000375', 'ACCOAC', 'META:AC...
# 176  dict_values(['SBO:0000375', 'AICART', '2.1.2.3...
# 177  dict_values(['SBO:0000375', 'ARGSL', 'META:ARG...
# 178  dict_values(['SBO:0000375', 'GLUPRT', 'META:PR...
# 179  dict_values(['SBO:0000375', 'IMPC', 'META:IMPC...
# 180  dict_values(['SBO:0000375', 'LDH_L', 'META:L-L...
# 181  dict_values(['SBO:0000375', 'MDH', 'META:MALAT...
# 182  dict_values(['SBO:0000375', 'MI1PP', 'META:RXN...
# 183  dict_values(['SBO:0000375', 'PFK', '2.7.1.11',...
# 184  dict_values(['SBO:0000375', 'PRFGS', '6.3.5.3'...
# 185  dict_values(['SBO:0000375', 'PYK', 'META:PEPDE...
# 186  dict_values(['SBO:0000375', 'TMDS', '2.1.1.45'...
# 187  dict_values(['SBO:0000375', 'TYRTA', 'META:TYR...
# 188  dict_values(['SBO:0000375', 'AACOAT', 'META:AC...
# 189  dict_values(['SBO:0000375', 'HMGCOARx', '1.1.1...
#
#                                        Full Annotation     rxn_id  \
# 0    {'SBO': 'SBO:0000375', 'bigg.reaction': '2OXOA...  2OXOADOXm
# 1    {'SBO': 'SBO:0000375', 'bigg.reaction': '34HPP...    34HPPOR
# 2    {'SBO': 'SBO:0000375', 'bigg.reaction': '3DSPH...     3DSPHR
# 3    {'SBO': 'SBO:0000375', 'bigg.reaction': '3HAO'...       3HAO
# 4    {'SBO': 'SBO:0000375', 'bigg.reaction': '3HBCO...  3HBCOAHLm
# 5    {'SBO': 'SBO:0000375', 'bigg.reaction': 'AASAD...    AASAD3m
# 6    {'SBO': 'SBO:0000375', 'bigg.reaction': 'AATA'...       AATA
# 7    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACACT...   ACACT10m
# 8    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACACT...    ACACT1m
# 9    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACITL...      ACITL
# 10   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...   ACOAD10m
# 11   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...    ACOAD8m
# 12   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...    ACOAD9m
# 13   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACONT...     ACONTm
# 14   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADK3'...       ADK3
# 15   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADSL1...     ADSL1r
# 16   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADSL2...     ADSL2r
# 17   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AIRCr...      AIRCr
# 18   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AKGDm...      AKGDm
# 19   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ALATA...    ALATA_L
# 20   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AMCOX...     AMCOXO
# 21   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGNm...      ARGNm
# 22   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGSS...      ARGSS
# 23   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASNNm...      ASNNm
# 24   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASNS1...      ASNS1
# 25   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASPCT...      ASPCT
# 26   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASPTA...     ASPTAm
# 27   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ATPtm...      ATPtm
# 28   {'SBO': 'SBO:0000375', 'bigg.reaction': 'CBPSa...     CBPSam
# 29   {'SBO': 'SBO:0000375', 'bigg.reaction': 'CHLPC...    CHLPCTD
# ..                                                 ...        ...
# 160  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PRPPS...      PRPPS
# 161  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PSERT...      PSERT
# 162  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PSP_L...      PSP_L
# 163  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR1...      RNDR1
# 164  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR2...      RNDR2
# 165  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR3...      RNDR3
# 166  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR4...      RNDR4
# 167  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RPE',...        RPE
# 168  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RPI',...        RPI
# 169  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TALA'...       TALA
# 170  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TKT1'...       TKT1
# 171  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TKT2'...       TKT2
# 172  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TPI',...        TPI
# 173  {'SBO': 'SBO:0000375', 'bigg.reaction': 'UMPK'...       UMPK
# 174  {'SBO': 'SBO:0000375', 'bigg.reaction': 'VALTA...      VALTA
# 175  {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACCOA...     ACCOAC
# 176  {'SBO': 'SBO:0000375', 'bigg.reaction': 'AICAR...     AICART
# 177  {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGSL...      ARGSL
# 178  {'SBO': 'SBO:0000375', 'bigg.reaction': 'GLUPR...     GLUPRT
# 179  {'SBO': 'SBO:0000375', 'bigg.reaction': 'IMPC'...       IMPC
# 180  {'SBO': 'SBO:0000375', 'bigg.reaction': 'LDH_L...      LDH_L
# 181  {'SBO': 'SBO:0000375', 'bigg.reaction': 'MDH',...        MDH
# 182  {'SBO': 'SBO:0000375', 'bigg.reaction': 'MI1PP...      MI1PP
# 183  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PFK',...        PFK
# 184  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PRFGS...      PRFGS
# 185  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PYK',...        PYK
# 186  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TMDS'...       TMDS
# 187  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TYRTA...      TYRTA
# 188  {'SBO': 'SBO:0000375', 'bigg.reaction': 'AACOA...     AACOAT
# 189  {'SBO': 'SBO:0000375', 'bigg.reaction': 'HMGCO...   HMGCOARx
#
#                                             rxn_string  \
# 0    2oxoadp_m + coa_m + nad_m --> co2_m + glutcoa_...
# 1                 34hpp_c + o2_c --> co2_c + hgentis_c
# 2       3dsphgn_c + h_c + nadph_c --> nadp_c + sphgn_c
# 3                  3hanthrn_c + o2_c --> cmusa_c + h_c
# 4         3hibutcoa_m + h2o_m --> 3hmp_m + coa_m + h_m
# 5    L2aadp6sa_m + h2o_m + nad_m --> L2aadp_m + 2.0...
# 6            2oxoadp_c + glu__L_c <=> L2aadp_c + akg_c
# 7              2maacoa_m + coa_m <=> accoa_m + ppcoa_m
# 8                      2.0 accoa_m --> aacoa_m + coa_m
# 9    atp_c + cit_c + coa_c --> accoa_c + adp_c + oa...
# 10            2mbcoa_m + fad_m --> 2mb2coa_m + fadh2_m
# 11             fad_m + ivcoa_m --> 3mb2coa_m + fadh2_m
# 12             fad_m + ibcoa_m --> 2mp2coa_m + fadh2_m
# 13                                    cit_m <=> icit_m
# 14                     amp_c + gtp_c <=> adp_c + gdp_c
# 15                           dcamp_c --> amp_c + fum_c
# 16                        25aics_c --> aicar_c + fum_c
# 17                     air_c + co2_c <=> 5aizc_c + h_c
# 18   akg_m + coa_m + nad_m --> co2_m + nadh_m + suc...
# 19               akg_c + ala__L_c <=> glu__L_c + pyr_c
# 20   amuco_c + h2o_c + h_c + nadph_c --> 2oxoadp_c ...
# 21                 arg__L_m + h2o_m --> orn_m + urea_m
# 22   asp__L_c + atp_c + citr__L_c --> amp_c + argsu...
# 23               asn__L_m + h2o_m --> asp__L_m + nh4_m
# 24   asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c ...
# 25           asp__L_c + cbp_c <=> cbasp_c + h_c + pi_c
# 26               akg_m + asp__L_m <=> glu__L_m + oaa_m
# 27                     adp_c + atp_m --> adp_m + atp_c
# 28   2.0 atp_m + hco3_m + nh4_m --> 2.0 adp_m + cbp...
# 29         cholp_c + ctp_c + h_c --> cdpchol_c + ppi_c
# ..                                                 ...
# 160             atp_c + r5p_c --> amp_c + h_c + prpp_c
# 161            3php_c + glu__L_c --> akg_c + pser__L_c
# 162              h2o_c + pser__L_c --> pi_c + ser__L_c
# 163       adp_c + trdrd_c --> dadp_c + h2o_c + trdox_c
# 164       gdp_c + trdrd_c --> dgdp_c + h2o_c + trdox_c
# 165       cdp_c + trdrd_c --> dcdp_c + h2o_c + trdox_c
# 166       trdrd_c + udp_c --> dudp_c + h2o_c + trdox_c
# 167                            ru5p__D_c <=> xu5p__D_c
# 168                                r5p_c <=> ru5p__D_c
# 169                    g3p_c + s7p_c <=> e4p_c + f6p_c
# 170                r5p_c + xu5p__D_c <=> g3p_c + s7p_c
# 171                e4p_c + xu5p__D_c <=> f6p_c + g3p_c
# 172                                   dhap_c <=> g3p_c
# 173                    atp_c + ump_c <=> adp_c + udp_c
# 174             akg_c + val__L_c <=> 3mob_c + glu__L_c
# 175  accoa_c + atp_c + hco3_c --> adp_c + h_c + mal...
# 176            10fthf_c + aicar_c <=> fprica_c + thf_c
# 177                      argsuc_c <=> arg__L_c + fum_c
# 178  gln__L_c + h2o_c + prpp_c --> glu__L_c + ppi_c...
# 179                         h2o_c + imp_c <=> fprica_c
# 180          lac__L_c + nad_c <=> h_c + nadh_c + pyr_c
# 181          mal__L_c + nad_c <=> h_c + nadh_c + oaa_c
# 182               h2o_c + mi1p__D_c --> inost_c + pi_c
# 183              atp_c + f6p_c --> adp_c + fdp_c + h_c
# 184  atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + ...
# 185              adp_c + h_c + pep_c --> atp_c + pyr_c
# 186                dump_c + mlthf_c --> dhf_c + dtmp_c
# 187            akg_c + tyr__L_c <=> 34hpp_c + glu__L_c
# 188  acac_c + atp_c + coa_c --> aacoa_c + amp_c + p...
# 189  2.0 h_x + hmgcoa_x + 2.0 nadph_x --> coa_x + m...
#
#                                            METANETX_EC  \
# 0    <td>1.2.1.52<br>1.2.4.2<br>1.8.1.4<br>2.3.1.61...
# 1                                  <td>1.13.11.27</td>
# 2                                   <td>1.1.1.102</td>
# 3                                   <td>1.13.11.6</td>
# 4                                     <td>3.1.2.4</td>
# 5                                    <td>1.2.1.31</td>
# 6                                    <td>2.6.1.39</td>
# 7                    <td>2.3.1.16<br>2.3.1.9</br></td>
# 8                                     <td>2.3.1.9</td>
# 9                     <td>2.3.3.8<br>4.1.3.6</br></td>
# 10                                   <td>1.3.99.3</td>
# 11   <td>1.3.8.4<br>1.3.8.7<br>1.3.99.10</br></br><...
# 12                     <td>1.3.8<br>1.3.99.3</br></td>
# 13                                    <td>4.2.1.3</td>
# 14                   <td>2.7.4.10<br>2.7.4.4</br></td>
# 15                                    <td>4.3.2.2</td>
# 16                                    <td>4.3.2.2</td>
# 17                                   <td>4.1.1.21</td>
# 18   <td>1.2.1.52<br>1.2.4.2<br>1.8.1.4<br>2.3.1.61...
# 19                                    <td>2.6.1.2</td>
# 20                                    <td>1.5.1.-</td>
# 21                                    <td>3.5.3.1</td>
# 22                                    <td>6.3.4.5</td>
# 23   <td>3.5.1.1<br>3.5.1.38<br>3.5.5.4</br></br></td>
# 24                                    <td>6.3.5.4</td>
# 25                                    <td>2.1.3.2</td>
# 26                                    <td>2.6.1.1</td>
# 27                                    <td>2.7.4.6</td>
# 28                   <td>6.3.4.16<br>6.3.5.5</br></td>
# 29                                   <td>2.7.7.15</td>
# ..                                                 ...
# 160                                   <td>2.7.6.1</td>
# 161                                  <td>2.6.1.52</td>
# 162                                   <td>3.1.3.3</td>
# 163                                  <td>1.17.4.1</td>
# 164                                  <td>1.17.4.1</td>
# 165                 <td>1.17.4.1<br>1.17.4.2</br></td>
# 166                                  <td>1.17.4.1</td>
# 167                                   <td>5.1.3.1</td>
# 168                                   <td>5.3.1.6</td>
# 169                                   <td>2.2.1.2</td>
# 170                                   <td>2.2.1.1</td>
# 171                                   <td>2.2.1.1</td>
# 172                                   <td>5.3.1.1</td>
# 173  <td>2.7.4.14<br>2.7.4.22<br>2.7.4.4</br></br><...
# 174                  <td>2.6.1.42<br>2.6.1.6</br></td>
# 175                                   <td>6.4.1.2</td>
# 176                                   <td>2.1.2.3</td>
# 177                                   <td>4.3.2.1</td>
# 178                                  <td>2.4.2.14</td>
# 179                  <td>2.1.2.3<br>3.5.4.10</br></td>
# 180                                  <td>1.1.1.27</td>
# 181                <td>1.1.1.299<br>1.1.1.37</br></td>
# 182                                  <td>3.1.3.25</td>
# 183                                  <td>2.7.1.11</td>
# 184                                   <td>6.3.5.3</td>
# 185                                  <td>2.7.1.40</td>
# 186                                  <td>2.1.1.45</td>
# 187  <td>2.6.1.1<br>2.6.1.5<br>2.6.1.57<br>2.6.1.9<...
# 188                                  <td>6.2.1.16</td>
# 189                                  <td>1.1.1.34</td>
#
#                                             EC_Comp
# 0    ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 1                                        1.13.11.27
# 2                                         1.1.1.102
# 3                                         1.13.11.6
# 4                                           3.1.2.4
# 5                                          1.2.1.31
# 6                                          2.6.1.39
# 7                           ['2.3.1.16', '2.3.1.9']
# 8                                           2.3.1.9
# 9                            ['2.3.3.8', '4.1.3.6']
# 10                                         1.3.99.3
# 11              ['1.3.8.4', '1.3.8.7', '1.3.99.10']
# 12                          ['1.3.8.-', '1.3.99.3']
# 13                                          4.2.1.3
# 14                          ['2.7.4.10', '2.7.4.4']
# 15                                          4.3.2.2
# 16                                          4.3.2.2
# 17                                         4.1.1.21
# 18   ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 19                                          2.6.1.2
# 20                                          1.5.1.-
# 21                                          3.5.3.1
# 22                                          6.3.4.5
# 23               ['3.5.1.1', '3.5.1.38', '3.5.5.4']
# 24                                          6.3.5.4
# 25                                          2.1.3.2
# 26                                          2.6.1.1
# 27                                          2.7.4.6
# 28                          ['6.3.4.16', '6.3.5.5']
# 29                                         2.7.7.15
# ..                                              ...
# 160                                         2.7.6.1
# 161                                        2.6.1.52
# 162                                         3.1.3.3
# 163                                        1.17.4.1
# 164                                        1.17.4.1
# 165                                        1.17.4.1
# 166                                        1.17.4.1
# 167                                         5.1.3.1
# 168                                         5.3.1.6
# 169                                         2.2.1.2
# 170                                         2.2.1.1
# 171                                         2.2.1.1
# 172                                         5.3.1.1
# 173             ['2.7.4.14', '2.7.4.22', '2.7.4.4']
# 174                         ['2.6.1.42', '2.6.1.6']
# 175                                         6.4.1.2
# 176                                         2.1.2.3
# 177                                         4.3.2.1
# 178                                        2.4.2.14
# 179                         ['2.1.2.3', '3.5.4.10']
# 180                                        1.1.1.27
# 181                       ['1.1.1.299', '1.1.1.37']
# 182                                        3.1.3.25
# 183                                        2.7.1.11
# 184                                         6.3.5.3
# 185                                        2.7.1.40
# 186                                        2.1.1.45
# 187   ['2.6.1.1', '2.6.1.5', '2.6.1.57', '2.6.1.9']
# 188                                        6.2.1.16
# 189                                        1.1.1.34
#
# [190 rows x 10 columns]

# %%
#check some stuff
df_EC["rxn_id"].tolist()==df_EC["ANNOT_BIGG"].tolist()
# Out:
# True

# %%
writer = pd.ExcelWriter('Kinetic__matched(beforemanualcuration.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
Kinetic__Match.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# ## Curation Instructions
# At this point each kinetic data point needs to be correctly identified to a BIGGID
#
# Curation process:
# for every row in kinetic_df
# look at Kinetic_df['df_EC_loc']
#     * Go to that [row#, colname]
#     identify the right bigg id based upon metabolite in kinetic data and reaction string
# priority:
# 1. reaction string
# 1. enzyme name
# 1. metabolites
#
# ADD BIGG ID of reaction that matches in df_EC
#
# ### lets look at how much curation

# %%
empty=0
curate=0
for i in Kinetic__Match["df_EC_Loc"]:
    if str(i) =="[]":
        empty+=1
    else:
        curate+=1

# %%
print (curate, empty)
# Out:
# 2643 2582

# %%
# ADD ALL DF_EC INFO TO KINETIC DATA
# CAN BE USED TO ADD MORE DATA FROM MODEL TO DATA 
df_EC
# Out:
#     ANNOT_BIGG                                        ANNOT_EC ANNOT_METANET  \
# 0    2OXOADOXm  ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']     MNXR94818
# 1      34HPPOR                                      1.13.11.27     MNXR94843
# 2       3DSPHR                                       1.1.1.102     MNXR94866
# 3         3HAO                                       1.13.11.6     MNXR94889
# 4    3HBCOAHLm                                         3.1.2.4     MNXR94891
# 5      AASAD3m                                        1.2.1.31     MNXR95158
# 6         AATA                                        2.6.1.39     MNXR95160
# 7     ACACT10m                         ['2.3.1.16', '2.3.1.9']     MNXR95195
# 8      ACACT1m                                         2.3.1.9     MNXR95194
# 9        ACITL                          ['2.3.3.8', '4.1.3.6']     MNXR95268
# 10    ACOAD10m                                        1.3.99.3     MNXR95306
# 11     ACOAD8m             ['1.3.8.4', '1.3.8.7', '1.3.99.10']     MNXR95318
# 12     ACOAD9m                         ['1.3.8.-', '1.3.99.3']     MNXR95319
# 13      ACONTm                                         4.2.1.3     MNXR95384
# 14        ADK3                         ['2.7.4.10', '2.7.4.4']     MNXR95452
# 15      ADSL1r                                         4.3.2.2     MNXR95493
# 16      ADSL2r                                         4.3.2.2     MNXR95494
# 17       AIRCr                                        4.1.1.21     MNXR95646
# 18       AKGDm  ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']     MNXR95655
# 19     ALATA_L                                         2.6.1.2     MNXR95698
# 20      AMCOXO                                         1.5.1.-     MNXR95807
# 21       ARGNm                                         3.5.3.1     MNXR95945
# 22       ARGSS                                         6.3.4.5     MNXR95949
# 23       ASNNm              ['3.5.1.1', '3.5.1.38', '3.5.5.4']     MNXR96056
# 24       ASNS1                                         6.3.5.4     MNXR96059
# 25       ASPCT                                         2.1.3.2     MNXR96080
# 26      ASPTAm                                         2.6.1.1     MNXR96079
# 27       ATPtm                                         2.7.4.6     MNXR96123
# 28      CBPSam                         ['6.3.4.16', '6.3.5.5']     MNXR96486
# 29     CHLPCTD                                        2.7.7.15     MNXR96686
# ..         ...                                             ...           ...
# 160      PRPPS                                         2.7.6.1    MNXR103215
# 161      PSERT                                        2.6.1.52    MNXR103225
# 162      PSP_L                                         3.1.3.3    MNXR103260
# 163      RNDR1                                        1.17.4.1    MNXR104060
# 164      RNDR2                                        1.17.4.1    MNXR104062
# 165      RNDR3                                        1.17.4.1    MNXR104064
# 166      RNDR4                                        1.17.4.1    MNXR104066
# 167        RPE                                         5.1.3.1    MNXR104083
# 168        RPI                                         5.3.1.6    MNXR104084
# 169       TALA                                         2.2.1.2    MNXR104715
# 170       TKT1                                         2.2.1.1    MNXR104868
# 171       TKT2                                         2.2.1.1    MNXR104869
# 172        TPI                                         5.3.1.1    MNXR104918
# 173       UMPK             ['2.7.4.14', '2.7.4.22', '2.7.4.4']    MNXR105118
# 174      VALTA                         ['2.6.1.42', '2.6.1.6']     MNXR96230
# 175     ACCOAC                                         6.4.1.2     MNXR95219
# 176     AICART                                         2.1.2.3     MNXR95639
# 177      ARGSL                                         4.3.2.1     MNXR95948
# 178     GLUPRT                                        2.4.2.14    MNXR100287
# 179       IMPC                         ['2.1.2.3', '3.5.4.10']    MNXR100783
# 180      LDH_L                                        1.1.1.27    MNXR101040
# 181        MDH                       ['1.1.1.299', '1.1.1.37']    MNXR101439
# 182      MI1PP                                        3.1.3.25    MNXR101570
# 183        PFK                                        2.7.1.11    MNXR102507
# 184      PRFGS                                         6.3.5.3    MNXR103165
# 185        PYK                                        2.7.1.40    MNXR103371
# 186       TMDS                                        2.1.1.45    MNXR104889
# 187      TYRTA   ['2.6.1.1', '2.6.1.5', '2.6.1.57', '2.6.1.9']    MNXR105000
# 188     AACOAT                                        6.2.1.16     MNXR95136
# 189   HMGCOARx                                        1.1.1.34    MNXR100659
#
#                                             Annot Keys  \
# 0    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 1    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 2    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 3    dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 4    dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 5    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 6    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 7    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 8    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 9    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 10   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 11   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 12   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 13   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 14   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 15   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 16   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 17   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 18   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 19   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 20   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 21   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 22   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 23   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 24   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 25   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 26   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 27   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 28   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 29   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# ..                                                 ...
# 160  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 161  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 162  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 163  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 164  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 165  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 166  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 167  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 168  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 169  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 170  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 171  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 172  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 173  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 174  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 175  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 176  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 177  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 178  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 179  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 180  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 181  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 182  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 183  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 184  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 185  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 186  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 187  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 188  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 189  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
#
#                                           Annot Values  \
# 0    dict_values(['SBO:0000375', '2OXOADOXm', 'META...
# 1    dict_values(['SBO:0000375', '34HPPOR', 'META:4...
# 2    dict_values(['SBO:0000375', '3DSPHR', 'META:3-...
# 3    dict_values(['SBO:0000375', '3HAO', '1.13.11.6...
# 4    dict_values(['SBO:0000375', '3HBCOAHLm', '3.1....
# 5    dict_values(['SBO:0000375', 'AASAD3m', 'META:A...
# 6    dict_values(['SBO:0000375', 'AATA', 'META:2-AM...
# 7    dict_values(['SBO:0000375', 'ACACT10m', 'META:...
# 8    dict_values(['SBO:0000375', 'ACACT1m', 'META:A...
# 9    dict_values(['SBO:0000375', 'ACITL', 'META:ATP...
# 10   dict_values(['SBO:0000375', 'ACOAD10m', '1.3.9...
# 11   dict_values(['SBO:0000375', 'ACOAD8m', 'META:R...
# 12   dict_values(['SBO:0000375', 'ACOAD9m', 'META:M...
# 13   dict_values(['SBO:0000375', 'ACONTm', '4.2.1.3...
# 14   dict_values(['SBO:0000375', 'ADK3', 'META:RXN-...
# 15   dict_values(['SBO:0000375', 'ADSL1r', 'META:AM...
# 16   dict_values(['SBO:0000375', 'ADSL2r', 'META:AI...
# 17   dict_values(['SBO:0000375', 'AIRCr', '4.1.1.21...
# 18   dict_values(['SBO:0000375', 'AKGDm', 'META:2OX...
# 19   dict_values(['SBO:0000375', 'ALATA_L', ['META:...
# 20   dict_values(['SBO:0000375', 'AMCOXO', '1.5.1.-...
# 21   dict_values(['SBO:0000375', 'ARGNm', 'META:ARG...
# 22   dict_values(['SBO:0000375', 'ARGSS', 'META:ARG...
# 23   dict_values(['SBO:0000375', 'ASNNm', 'META:ASP...
# 24   dict_values(['SBO:0000375', 'ASNS1', 'META:ASN...
# 25   dict_values(['SBO:0000375', 'ASPCT', 'META:ASP...
# 26   dict_values(['SBO:0000375', 'ASPTAm', ['META:A...
# 27   dict_values(['SBO:0000375', 'ATPtm', '2.7.4.6'...
# 28   dict_values(['SBO:0000375', 'CBPSam', 'META:RX...
# 29   dict_values(['SBO:0000375', 'CHLPCTD', 'META:2...
# ..                                                 ...
# 160  dict_values(['SBO:0000375', 'PRPPS', '2.7.6.1'...
# 161  dict_values(['SBO:0000375', 'PSERT', 'META:PSE...
# 162  dict_values(['SBO:0000375', 'PSP_L', 'META:RXN...
# 163  dict_values(['SBO:0000375', 'RNDR1', 'META:ADP...
# 164  dict_values(['SBO:0000375', 'RNDR2', 'META:GDP...
# 165  dict_values(['SBO:0000375', 'RNDR3', 'META:CDP...
# 166  dict_values(['SBO:0000375', 'RNDR4', 'META:UDP...
# 167  dict_values(['SBO:0000375', 'RPE', 'META:RIBUL...
# 168  dict_values(['SBO:0000375', 'RPI', '5.3.1.6', ...
# 169  dict_values(['SBO:0000375', 'TALA', 'META:TRAN...
# 170  dict_values(['SBO:0000375', 'TKT1', '2.2.1.1',...
# 171  dict_values(['SBO:0000375', 'TKT2', 'META:2TRA...
# 172  dict_values(['SBO:0000375', 'TPI', 'META:TRIOS...
# 173  dict_values(['SBO:0000375', 'UMPK', 'META:RXN-...
# 174  dict_values(['SBO:0000375', 'VALTA', 'META:BRA...
# 175  dict_values(['SBO:0000375', 'ACCOAC', 'META:AC...
# 176  dict_values(['SBO:0000375', 'AICART', '2.1.2.3...
# 177  dict_values(['SBO:0000375', 'ARGSL', 'META:ARG...
# 178  dict_values(['SBO:0000375', 'GLUPRT', 'META:PR...
# 179  dict_values(['SBO:0000375', 'IMPC', 'META:IMPC...
# 180  dict_values(['SBO:0000375', 'LDH_L', 'META:L-L...
# 181  dict_values(['SBO:0000375', 'MDH', 'META:MALAT...
# 182  dict_values(['SBO:0000375', 'MI1PP', 'META:RXN...
# 183  dict_values(['SBO:0000375', 'PFK', '2.7.1.11',...
# 184  dict_values(['SBO:0000375', 'PRFGS', '6.3.5.3'...
# 185  dict_values(['SBO:0000375', 'PYK', 'META:PEPDE...
# 186  dict_values(['SBO:0000375', 'TMDS', '2.1.1.45'...
# 187  dict_values(['SBO:0000375', 'TYRTA', 'META:TYR...
# 188  dict_values(['SBO:0000375', 'AACOAT', 'META:AC...
# 189  dict_values(['SBO:0000375', 'HMGCOARx', '1.1.1...
#
#                                        Full Annotation     rxn_id  \
# 0    {'SBO': 'SBO:0000375', 'bigg.reaction': '2OXOA...  2OXOADOXm
# 1    {'SBO': 'SBO:0000375', 'bigg.reaction': '34HPP...    34HPPOR
# 2    {'SBO': 'SBO:0000375', 'bigg.reaction': '3DSPH...     3DSPHR
# 3    {'SBO': 'SBO:0000375', 'bigg.reaction': '3HAO'...       3HAO
# 4    {'SBO': 'SBO:0000375', 'bigg.reaction': '3HBCO...  3HBCOAHLm
# 5    {'SBO': 'SBO:0000375', 'bigg.reaction': 'AASAD...    AASAD3m
# 6    {'SBO': 'SBO:0000375', 'bigg.reaction': 'AATA'...       AATA
# 7    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACACT...   ACACT10m
# 8    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACACT...    ACACT1m
# 9    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACITL...      ACITL
# 10   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...   ACOAD10m
# 11   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...    ACOAD8m
# 12   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...    ACOAD9m
# 13   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACONT...     ACONTm
# 14   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADK3'...       ADK3
# 15   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADSL1...     ADSL1r
# 16   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADSL2...     ADSL2r
# 17   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AIRCr...      AIRCr
# 18   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AKGDm...      AKGDm
# 19   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ALATA...    ALATA_L
# 20   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AMCOX...     AMCOXO
# 21   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGNm...      ARGNm
# 22   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGSS...      ARGSS
# 23   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASNNm...      ASNNm
# 24   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASNS1...      ASNS1
# 25   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASPCT...      ASPCT
# 26   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASPTA...     ASPTAm
# 27   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ATPtm...      ATPtm
# 28   {'SBO': 'SBO:0000375', 'bigg.reaction': 'CBPSa...     CBPSam
# 29   {'SBO': 'SBO:0000375', 'bigg.reaction': 'CHLPC...    CHLPCTD
# ..                                                 ...        ...
# 160  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PRPPS...      PRPPS
# 161  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PSERT...      PSERT
# 162  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PSP_L...      PSP_L
# 163  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR1...      RNDR1
# 164  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR2...      RNDR2
# 165  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR3...      RNDR3
# 166  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR4...      RNDR4
# 167  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RPE',...        RPE
# 168  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RPI',...        RPI
# 169  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TALA'...       TALA
# 170  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TKT1'...       TKT1
# 171  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TKT2'...       TKT2
# 172  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TPI',...        TPI
# 173  {'SBO': 'SBO:0000375', 'bigg.reaction': 'UMPK'...       UMPK
# 174  {'SBO': 'SBO:0000375', 'bigg.reaction': 'VALTA...      VALTA
# 175  {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACCOA...     ACCOAC
# 176  {'SBO': 'SBO:0000375', 'bigg.reaction': 'AICAR...     AICART
# 177  {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGSL...      ARGSL
# 178  {'SBO': 'SBO:0000375', 'bigg.reaction': 'GLUPR...     GLUPRT
# 179  {'SBO': 'SBO:0000375', 'bigg.reaction': 'IMPC'...       IMPC
# 180  {'SBO': 'SBO:0000375', 'bigg.reaction': 'LDH_L...      LDH_L
# 181  {'SBO': 'SBO:0000375', 'bigg.reaction': 'MDH',...        MDH
# 182  {'SBO': 'SBO:0000375', 'bigg.reaction': 'MI1PP...      MI1PP
# 183  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PFK',...        PFK
# 184  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PRFGS...      PRFGS
# 185  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PYK',...        PYK
# 186  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TMDS'...       TMDS
# 187  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TYRTA...      TYRTA
# 188  {'SBO': 'SBO:0000375', 'bigg.reaction': 'AACOA...     AACOAT
# 189  {'SBO': 'SBO:0000375', 'bigg.reaction': 'HMGCO...   HMGCOARx
#
#                                             rxn_string  \
# 0    2oxoadp_m + coa_m + nad_m --> co2_m + glutcoa_...
# 1                 34hpp_c + o2_c --> co2_c + hgentis_c
# 2       3dsphgn_c + h_c + nadph_c --> nadp_c + sphgn_c
# 3                  3hanthrn_c + o2_c --> cmusa_c + h_c
# 4         3hibutcoa_m + h2o_m --> 3hmp_m + coa_m + h_m
# 5    L2aadp6sa_m + h2o_m + nad_m --> L2aadp_m + 2.0...
# 6            2oxoadp_c + glu__L_c <=> L2aadp_c + akg_c
# 7              2maacoa_m + coa_m <=> accoa_m + ppcoa_m
# 8                      2.0 accoa_m --> aacoa_m + coa_m
# 9    atp_c + cit_c + coa_c --> accoa_c + adp_c + oa...
# 10            2mbcoa_m + fad_m --> 2mb2coa_m + fadh2_m
# 11             fad_m + ivcoa_m --> 3mb2coa_m + fadh2_m
# 12             fad_m + ibcoa_m --> 2mp2coa_m + fadh2_m
# 13                                    cit_m <=> icit_m
# 14                     amp_c + gtp_c <=> adp_c + gdp_c
# 15                           dcamp_c --> amp_c + fum_c
# 16                        25aics_c --> aicar_c + fum_c
# 17                     air_c + co2_c <=> 5aizc_c + h_c
# 18   akg_m + coa_m + nad_m --> co2_m + nadh_m + suc...
# 19               akg_c + ala__L_c <=> glu__L_c + pyr_c
# 20   amuco_c + h2o_c + h_c + nadph_c --> 2oxoadp_c ...
# 21                 arg__L_m + h2o_m --> orn_m + urea_m
# 22   asp__L_c + atp_c + citr__L_c --> amp_c + argsu...
# 23               asn__L_m + h2o_m --> asp__L_m + nh4_m
# 24   asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c ...
# 25           asp__L_c + cbp_c <=> cbasp_c + h_c + pi_c
# 26               akg_m + asp__L_m <=> glu__L_m + oaa_m
# 27                     adp_c + atp_m --> adp_m + atp_c
# 28   2.0 atp_m + hco3_m + nh4_m --> 2.0 adp_m + cbp...
# 29         cholp_c + ctp_c + h_c --> cdpchol_c + ppi_c
# ..                                                 ...
# 160             atp_c + r5p_c --> amp_c + h_c + prpp_c
# 161            3php_c + glu__L_c --> akg_c + pser__L_c
# 162              h2o_c + pser__L_c --> pi_c + ser__L_c
# 163       adp_c + trdrd_c --> dadp_c + h2o_c + trdox_c
# 164       gdp_c + trdrd_c --> dgdp_c + h2o_c + trdox_c
# 165       cdp_c + trdrd_c --> dcdp_c + h2o_c + trdox_c
# 166       trdrd_c + udp_c --> dudp_c + h2o_c + trdox_c
# 167                            ru5p__D_c <=> xu5p__D_c
# 168                                r5p_c <=> ru5p__D_c
# 169                    g3p_c + s7p_c <=> e4p_c + f6p_c
# 170                r5p_c + xu5p__D_c <=> g3p_c + s7p_c
# 171                e4p_c + xu5p__D_c <=> f6p_c + g3p_c
# 172                                   dhap_c <=> g3p_c
# 173                    atp_c + ump_c <=> adp_c + udp_c
# 174             akg_c + val__L_c <=> 3mob_c + glu__L_c
# 175  accoa_c + atp_c + hco3_c --> adp_c + h_c + mal...
# 176            10fthf_c + aicar_c <=> fprica_c + thf_c
# 177                      argsuc_c <=> arg__L_c + fum_c
# 178  gln__L_c + h2o_c + prpp_c --> glu__L_c + ppi_c...
# 179                         h2o_c + imp_c <=> fprica_c
# 180          lac__L_c + nad_c <=> h_c + nadh_c + pyr_c
# 181          mal__L_c + nad_c <=> h_c + nadh_c + oaa_c
# 182               h2o_c + mi1p__D_c --> inost_c + pi_c
# 183              atp_c + f6p_c --> adp_c + fdp_c + h_c
# 184  atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + ...
# 185              adp_c + h_c + pep_c --> atp_c + pyr_c
# 186                dump_c + mlthf_c --> dhf_c + dtmp_c
# 187            akg_c + tyr__L_c <=> 34hpp_c + glu__L_c
# 188  acac_c + atp_c + coa_c --> aacoa_c + amp_c + p...
# 189  2.0 h_x + hmgcoa_x + 2.0 nadph_x --> coa_x + m...
#
#                                            METANETX_EC  \
# 0    <td>1.2.1.52<br>1.2.4.2<br>1.8.1.4<br>2.3.1.61...
# 1                                  <td>1.13.11.27</td>
# 2                                   <td>1.1.1.102</td>
# 3                                   <td>1.13.11.6</td>
# 4                                     <td>3.1.2.4</td>
# 5                                    <td>1.2.1.31</td>
# 6                                    <td>2.6.1.39</td>
# 7                    <td>2.3.1.16<br>2.3.1.9</br></td>
# 8                                     <td>2.3.1.9</td>
# 9                     <td>2.3.3.8<br>4.1.3.6</br></td>
# 10                                   <td>1.3.99.3</td>
# 11   <td>1.3.8.4<br>1.3.8.7<br>1.3.99.10</br></br><...
# 12                     <td>1.3.8<br>1.3.99.3</br></td>
# 13                                    <td>4.2.1.3</td>
# 14                   <td>2.7.4.10<br>2.7.4.4</br></td>
# 15                                    <td>4.3.2.2</td>
# 16                                    <td>4.3.2.2</td>
# 17                                   <td>4.1.1.21</td>
# 18   <td>1.2.1.52<br>1.2.4.2<br>1.8.1.4<br>2.3.1.61...
# 19                                    <td>2.6.1.2</td>
# 20                                    <td>1.5.1.-</td>
# 21                                    <td>3.5.3.1</td>
# 22                                    <td>6.3.4.5</td>
# 23   <td>3.5.1.1<br>3.5.1.38<br>3.5.5.4</br></br></td>
# 24                                    <td>6.3.5.4</td>
# 25                                    <td>2.1.3.2</td>
# 26                                    <td>2.6.1.1</td>
# 27                                    <td>2.7.4.6</td>
# 28                   <td>6.3.4.16<br>6.3.5.5</br></td>
# 29                                   <td>2.7.7.15</td>
# ..                                                 ...
# 160                                   <td>2.7.6.1</td>
# 161                                  <td>2.6.1.52</td>
# 162                                   <td>3.1.3.3</td>
# 163                                  <td>1.17.4.1</td>
# 164                                  <td>1.17.4.1</td>
# 165                 <td>1.17.4.1<br>1.17.4.2</br></td>
# 166                                  <td>1.17.4.1</td>
# 167                                   <td>5.1.3.1</td>
# 168                                   <td>5.3.1.6</td>
# 169                                   <td>2.2.1.2</td>
# 170                                   <td>2.2.1.1</td>
# 171                                   <td>2.2.1.1</td>
# 172                                   <td>5.3.1.1</td>
# 173  <td>2.7.4.14<br>2.7.4.22<br>2.7.4.4</br></br><...
# 174                  <td>2.6.1.42<br>2.6.1.6</br></td>
# 175                                   <td>6.4.1.2</td>
# 176                                   <td>2.1.2.3</td>
# 177                                   <td>4.3.2.1</td>
# 178                                  <td>2.4.2.14</td>
# 179                  <td>2.1.2.3<br>3.5.4.10</br></td>
# 180                                  <td>1.1.1.27</td>
# 181                <td>1.1.1.299<br>1.1.1.37</br></td>
# 182                                  <td>3.1.3.25</td>
# 183                                  <td>2.7.1.11</td>
# 184                                   <td>6.3.5.3</td>
# 185                                  <td>2.7.1.40</td>
# 186                                  <td>2.1.1.45</td>
# 187  <td>2.6.1.1<br>2.6.1.5<br>2.6.1.57<br>2.6.1.9<...
# 188                                  <td>6.2.1.16</td>
# 189                                  <td>1.1.1.34</td>
#
#                                             EC_Comp
# 0    ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 1                                        1.13.11.27
# 2                                         1.1.1.102
# 3                                         1.13.11.6
# 4                                           3.1.2.4
# 5                                          1.2.1.31
# 6                                          2.6.1.39
# 7                           ['2.3.1.16', '2.3.1.9']
# 8                                           2.3.1.9
# 9                            ['2.3.3.8', '4.1.3.6']
# 10                                         1.3.99.3
# 11              ['1.3.8.4', '1.3.8.7', '1.3.99.10']
# 12                          ['1.3.8.-', '1.3.99.3']
# 13                                          4.2.1.3
# 14                          ['2.7.4.10', '2.7.4.4']
# 15                                          4.3.2.2
# 16                                          4.3.2.2
# 17                                         4.1.1.21
# 18   ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 19                                          2.6.1.2
# 20                                          1.5.1.-
# 21                                          3.5.3.1
# 22                                          6.3.4.5
# 23               ['3.5.1.1', '3.5.1.38', '3.5.5.4']
# 24                                          6.3.5.4
# 25                                          2.1.3.2
# 26                                          2.6.1.1
# 27                                          2.7.4.6
# 28                          ['6.3.4.16', '6.3.5.5']
# 29                                         2.7.7.15
# ..                                              ...
# 160                                         2.7.6.1
# 161                                        2.6.1.52
# 162                                         3.1.3.3
# 163                                        1.17.4.1
# 164                                        1.17.4.1
# 165                                        1.17.4.1
# 166                                        1.17.4.1
# 167                                         5.1.3.1
# 168                                         5.3.1.6
# 169                                         2.2.1.2
# 170                                         2.2.1.1
# 171                                         2.2.1.1
# 172                                         5.3.1.1
# 173             ['2.7.4.14', '2.7.4.22', '2.7.4.4']
# 174                         ['2.6.1.42', '2.6.1.6']
# 175                                         6.4.1.2
# 176                                         2.1.2.3
# 177                                         4.3.2.1
# 178                                        2.4.2.14
# 179                         ['2.1.2.3', '3.5.4.10']
# 180                                        1.1.1.27
# 181                       ['1.1.1.299', '1.1.1.37']
# 182                                        3.1.3.25
# 183                                        2.7.1.11
# 184                                         6.3.5.3
# 185                                        2.7.1.40
# 186                                        2.1.1.45
# 187   ['2.6.1.1', '2.6.1.5', '2.6.1.57', '2.6.1.9']
# 188                                        6.2.1.16
# 189                                        1.1.1.34
#
# [190 rows x 10 columns]

# %%
# add reaction name to df_EC
reaction_name_list=[]
metabolite_dicts=[]
reactants_list=[]
products_list=[]
for i in RECON3d.reactions:
    if i.id in df_EC["ANNOT_BIGG"].tolist():
        reaction_name_list.append(i.name)
        metabolite_dicts.append(i.metabolites)
        reactants_list.append(i.reactants)
        products_list.append(i.products)

# %%
df_EC["model_rxn_name"]=reaction_name_list
df_EC["metabolite_dict"]=metabolite_dicts
df_EC["reactants"]=reactants_list
df_EC["products"]=products_list

# %%
df_EC
# Out:
#     ANNOT_BIGG                                        ANNOT_EC ANNOT_METANET  \
# 0    2OXOADOXm  ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']     MNXR94818
# 1      34HPPOR                                      1.13.11.27     MNXR94843
# 2       3DSPHR                                       1.1.1.102     MNXR94866
# 3         3HAO                                       1.13.11.6     MNXR94889
# 4    3HBCOAHLm                                         3.1.2.4     MNXR94891
# 5      AASAD3m                                        1.2.1.31     MNXR95158
# 6         AATA                                        2.6.1.39     MNXR95160
# 7     ACACT10m                         ['2.3.1.16', '2.3.1.9']     MNXR95195
# 8      ACACT1m                                         2.3.1.9     MNXR95194
# 9        ACITL                          ['2.3.3.8', '4.1.3.6']     MNXR95268
# 10    ACOAD10m                                        1.3.99.3     MNXR95306
# 11     ACOAD8m             ['1.3.8.4', '1.3.8.7', '1.3.99.10']     MNXR95318
# 12     ACOAD9m                         ['1.3.8.-', '1.3.99.3']     MNXR95319
# 13      ACONTm                                         4.2.1.3     MNXR95384
# 14        ADK3                         ['2.7.4.10', '2.7.4.4']     MNXR95452
# 15      ADSL1r                                         4.3.2.2     MNXR95493
# 16      ADSL2r                                         4.3.2.2     MNXR95494
# 17       AIRCr                                        4.1.1.21     MNXR95646
# 18       AKGDm  ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']     MNXR95655
# 19     ALATA_L                                         2.6.1.2     MNXR95698
# 20      AMCOXO                                         1.5.1.-     MNXR95807
# 21       ARGNm                                         3.5.3.1     MNXR95945
# 22       ARGSS                                         6.3.4.5     MNXR95949
# 23       ASNNm              ['3.5.1.1', '3.5.1.38', '3.5.5.4']     MNXR96056
# 24       ASNS1                                         6.3.5.4     MNXR96059
# 25       ASPCT                                         2.1.3.2     MNXR96080
# 26      ASPTAm                                         2.6.1.1     MNXR96079
# 27       ATPtm                                         2.7.4.6     MNXR96123
# 28      CBPSam                         ['6.3.4.16', '6.3.5.5']     MNXR96486
# 29     CHLPCTD                                        2.7.7.15     MNXR96686
# ..         ...                                             ...           ...
# 160      PRPPS                                         2.7.6.1    MNXR103215
# 161      PSERT                                        2.6.1.52    MNXR103225
# 162      PSP_L                                         3.1.3.3    MNXR103260
# 163      RNDR1                                        1.17.4.1    MNXR104060
# 164      RNDR2                                        1.17.4.1    MNXR104062
# 165      RNDR3                                        1.17.4.1    MNXR104064
# 166      RNDR4                                        1.17.4.1    MNXR104066
# 167        RPE                                         5.1.3.1    MNXR104083
# 168        RPI                                         5.3.1.6    MNXR104084
# 169       TALA                                         2.2.1.2    MNXR104715
# 170       TKT1                                         2.2.1.1    MNXR104868
# 171       TKT2                                         2.2.1.1    MNXR104869
# 172        TPI                                         5.3.1.1    MNXR104918
# 173       UMPK             ['2.7.4.14', '2.7.4.22', '2.7.4.4']    MNXR105118
# 174      VALTA                         ['2.6.1.42', '2.6.1.6']     MNXR96230
# 175     ACCOAC                                         6.4.1.2     MNXR95219
# 176     AICART                                         2.1.2.3     MNXR95639
# 177      ARGSL                                         4.3.2.1     MNXR95948
# 178     GLUPRT                                        2.4.2.14    MNXR100287
# 179       IMPC                         ['2.1.2.3', '3.5.4.10']    MNXR100783
# 180      LDH_L                                        1.1.1.27    MNXR101040
# 181        MDH                       ['1.1.1.299', '1.1.1.37']    MNXR101439
# 182      MI1PP                                        3.1.3.25    MNXR101570
# 183        PFK                                        2.7.1.11    MNXR102507
# 184      PRFGS                                         6.3.5.3    MNXR103165
# 185        PYK                                        2.7.1.40    MNXR103371
# 186       TMDS                                        2.1.1.45    MNXR104889
# 187      TYRTA   ['2.6.1.1', '2.6.1.5', '2.6.1.57', '2.6.1.9']    MNXR105000
# 188     AACOAT                                        6.2.1.16     MNXR95136
# 189   HMGCOARx                                        1.1.1.34    MNXR100659
#
#                                             Annot Keys  \
# 0    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 1    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 2    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 3    dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 4    dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 5    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 6    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 7    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 8    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 9    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 10   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 11   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 12   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 13   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 14   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 15   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 16   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 17   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 18   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 19   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 20   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 21   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 22   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 23   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 24   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 25   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 26   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 27   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 28   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 29   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# ..                                                 ...
# 160  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 161  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 162  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 163  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 164  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 165  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 166  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 167  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 168  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 169  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 170  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 171  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 172  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 173  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 174  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 175  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 176  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 177  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 178  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 179  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 180  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 181  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 182  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 183  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 184  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 185  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 186  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 187  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 188  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 189  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
#
#                                           Annot Values  \
# 0    dict_values(['SBO:0000375', '2OXOADOXm', 'META...
# 1    dict_values(['SBO:0000375', '34HPPOR', 'META:4...
# 2    dict_values(['SBO:0000375', '3DSPHR', 'META:3-...
# 3    dict_values(['SBO:0000375', '3HAO', '1.13.11.6...
# 4    dict_values(['SBO:0000375', '3HBCOAHLm', '3.1....
# 5    dict_values(['SBO:0000375', 'AASAD3m', 'META:A...
# 6    dict_values(['SBO:0000375', 'AATA', 'META:2-AM...
# 7    dict_values(['SBO:0000375', 'ACACT10m', 'META:...
# 8    dict_values(['SBO:0000375', 'ACACT1m', 'META:A...
# 9    dict_values(['SBO:0000375', 'ACITL', 'META:ATP...
# 10   dict_values(['SBO:0000375', 'ACOAD10m', '1.3.9...
# 11   dict_values(['SBO:0000375', 'ACOAD8m', 'META:R...
# 12   dict_values(['SBO:0000375', 'ACOAD9m', 'META:M...
# 13   dict_values(['SBO:0000375', 'ACONTm', '4.2.1.3...
# 14   dict_values(['SBO:0000375', 'ADK3', 'META:RXN-...
# 15   dict_values(['SBO:0000375', 'ADSL1r', 'META:AM...
# 16   dict_values(['SBO:0000375', 'ADSL2r', 'META:AI...
# 17   dict_values(['SBO:0000375', 'AIRCr', '4.1.1.21...
# 18   dict_values(['SBO:0000375', 'AKGDm', 'META:2OX...
# 19   dict_values(['SBO:0000375', 'ALATA_L', ['META:...
# 20   dict_values(['SBO:0000375', 'AMCOXO', '1.5.1.-...
# 21   dict_values(['SBO:0000375', 'ARGNm', 'META:ARG...
# 22   dict_values(['SBO:0000375', 'ARGSS', 'META:ARG...
# 23   dict_values(['SBO:0000375', 'ASNNm', 'META:ASP...
# 24   dict_values(['SBO:0000375', 'ASNS1', 'META:ASN...
# 25   dict_values(['SBO:0000375', 'ASPCT', 'META:ASP...
# 26   dict_values(['SBO:0000375', 'ASPTAm', ['META:A...
# 27   dict_values(['SBO:0000375', 'ATPtm', '2.7.4.6'...
# 28   dict_values(['SBO:0000375', 'CBPSam', 'META:RX...
# 29   dict_values(['SBO:0000375', 'CHLPCTD', 'META:2...
# ..                                                 ...
# 160  dict_values(['SBO:0000375', 'PRPPS', '2.7.6.1'...
# 161  dict_values(['SBO:0000375', 'PSERT', 'META:PSE...
# 162  dict_values(['SBO:0000375', 'PSP_L', 'META:RXN...
# 163  dict_values(['SBO:0000375', 'RNDR1', 'META:ADP...
# 164  dict_values(['SBO:0000375', 'RNDR2', 'META:GDP...
# 165  dict_values(['SBO:0000375', 'RNDR3', 'META:CDP...
# 166  dict_values(['SBO:0000375', 'RNDR4', 'META:UDP...
# 167  dict_values(['SBO:0000375', 'RPE', 'META:RIBUL...
# 168  dict_values(['SBO:0000375', 'RPI', '5.3.1.6', ...
# 169  dict_values(['SBO:0000375', 'TALA', 'META:TRAN...
# 170  dict_values(['SBO:0000375', 'TKT1', '2.2.1.1',...
# 171  dict_values(['SBO:0000375', 'TKT2', 'META:2TRA...
# 172  dict_values(['SBO:0000375', 'TPI', 'META:TRIOS...
# 173  dict_values(['SBO:0000375', 'UMPK', 'META:RXN-...
# 174  dict_values(['SBO:0000375', 'VALTA', 'META:BRA...
# 175  dict_values(['SBO:0000375', 'ACCOAC', 'META:AC...
# 176  dict_values(['SBO:0000375', 'AICART', '2.1.2.3...
# 177  dict_values(['SBO:0000375', 'ARGSL', 'META:ARG...
# 178  dict_values(['SBO:0000375', 'GLUPRT', 'META:PR...
# 179  dict_values(['SBO:0000375', 'IMPC', 'META:IMPC...
# 180  dict_values(['SBO:0000375', 'LDH_L', 'META:L-L...
# 181  dict_values(['SBO:0000375', 'MDH', 'META:MALAT...
# 182  dict_values(['SBO:0000375', 'MI1PP', 'META:RXN...
# 183  dict_values(['SBO:0000375', 'PFK', '2.7.1.11',...
# 184  dict_values(['SBO:0000375', 'PRFGS', '6.3.5.3'...
# 185  dict_values(['SBO:0000375', 'PYK', 'META:PEPDE...
# 186  dict_values(['SBO:0000375', 'TMDS', '2.1.1.45'...
# 187  dict_values(['SBO:0000375', 'TYRTA', 'META:TYR...
# 188  dict_values(['SBO:0000375', 'AACOAT', 'META:AC...
# 189  dict_values(['SBO:0000375', 'HMGCOARx', '1.1.1...
#
#                                        Full Annotation     rxn_id  \
# 0    {'SBO': 'SBO:0000375', 'bigg.reaction': '2OXOA...  2OXOADOXm
# 1    {'SBO': 'SBO:0000375', 'bigg.reaction': '34HPP...    34HPPOR
# 2    {'SBO': 'SBO:0000375', 'bigg.reaction': '3DSPH...     3DSPHR
# 3    {'SBO': 'SBO:0000375', 'bigg.reaction': '3HAO'...       3HAO
# 4    {'SBO': 'SBO:0000375', 'bigg.reaction': '3HBCO...  3HBCOAHLm
# 5    {'SBO': 'SBO:0000375', 'bigg.reaction': 'AASAD...    AASAD3m
# 6    {'SBO': 'SBO:0000375', 'bigg.reaction': 'AATA'...       AATA
# 7    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACACT...   ACACT10m
# 8    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACACT...    ACACT1m
# 9    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACITL...      ACITL
# 10   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...   ACOAD10m
# 11   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...    ACOAD8m
# 12   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...    ACOAD9m
# 13   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACONT...     ACONTm
# 14   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADK3'...       ADK3
# 15   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADSL1...     ADSL1r
# 16   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADSL2...     ADSL2r
# 17   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AIRCr...      AIRCr
# 18   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AKGDm...      AKGDm
# 19   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ALATA...    ALATA_L
# 20   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AMCOX...     AMCOXO
# 21   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGNm...      ARGNm
# 22   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGSS...      ARGSS
# 23   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASNNm...      ASNNm
# 24   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASNS1...      ASNS1
# 25   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASPCT...      ASPCT
# 26   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASPTA...     ASPTAm
# 27   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ATPtm...      ATPtm
# 28   {'SBO': 'SBO:0000375', 'bigg.reaction': 'CBPSa...     CBPSam
# 29   {'SBO': 'SBO:0000375', 'bigg.reaction': 'CHLPC...    CHLPCTD
# ..                                                 ...        ...
# 160  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PRPPS...      PRPPS
# 161  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PSERT...      PSERT
# 162  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PSP_L...      PSP_L
# 163  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR1...      RNDR1
# 164  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR2...      RNDR2
# 165  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR3...      RNDR3
# 166  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR4...      RNDR4
# 167  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RPE',...        RPE
# 168  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RPI',...        RPI
# 169  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TALA'...       TALA
# 170  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TKT1'...       TKT1
# 171  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TKT2'...       TKT2
# 172  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TPI',...        TPI
# 173  {'SBO': 'SBO:0000375', 'bigg.reaction': 'UMPK'...       UMPK
# 174  {'SBO': 'SBO:0000375', 'bigg.reaction': 'VALTA...      VALTA
# 175  {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACCOA...     ACCOAC
# 176  {'SBO': 'SBO:0000375', 'bigg.reaction': 'AICAR...     AICART
# 177  {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGSL...      ARGSL
# 178  {'SBO': 'SBO:0000375', 'bigg.reaction': 'GLUPR...     GLUPRT
# 179  {'SBO': 'SBO:0000375', 'bigg.reaction': 'IMPC'...       IMPC
# 180  {'SBO': 'SBO:0000375', 'bigg.reaction': 'LDH_L...      LDH_L
# 181  {'SBO': 'SBO:0000375', 'bigg.reaction': 'MDH',...        MDH
# 182  {'SBO': 'SBO:0000375', 'bigg.reaction': 'MI1PP...      MI1PP
# 183  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PFK',...        PFK
# 184  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PRFGS...      PRFGS
# 185  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PYK',...        PYK
# 186  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TMDS'...       TMDS
# 187  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TYRTA...      TYRTA
# 188  {'SBO': 'SBO:0000375', 'bigg.reaction': 'AACOA...     AACOAT
# 189  {'SBO': 'SBO:0000375', 'bigg.reaction': 'HMGCO...   HMGCOARx
#
#                                             rxn_string  \
# 0    2oxoadp_m + coa_m + nad_m --> co2_m + glutcoa_...
# 1                 34hpp_c + o2_c --> co2_c + hgentis_c
# 2       3dsphgn_c + h_c + nadph_c --> nadp_c + sphgn_c
# 3                  3hanthrn_c + o2_c --> cmusa_c + h_c
# 4         3hibutcoa_m + h2o_m --> 3hmp_m + coa_m + h_m
# 5    L2aadp6sa_m + h2o_m + nad_m --> L2aadp_m + 2.0...
# 6            2oxoadp_c + glu__L_c <=> L2aadp_c + akg_c
# 7              2maacoa_m + coa_m <=> accoa_m + ppcoa_m
# 8                      2.0 accoa_m --> aacoa_m + coa_m
# 9    atp_c + cit_c + coa_c --> accoa_c + adp_c + oa...
# 10            2mbcoa_m + fad_m --> 2mb2coa_m + fadh2_m
# 11             fad_m + ivcoa_m --> 3mb2coa_m + fadh2_m
# 12             fad_m + ibcoa_m --> 2mp2coa_m + fadh2_m
# 13                                    cit_m <=> icit_m
# 14                     amp_c + gtp_c <=> adp_c + gdp_c
# 15                           dcamp_c --> amp_c + fum_c
# 16                        25aics_c --> aicar_c + fum_c
# 17                     air_c + co2_c <=> 5aizc_c + h_c
# 18   akg_m + coa_m + nad_m --> co2_m + nadh_m + suc...
# 19               akg_c + ala__L_c <=> glu__L_c + pyr_c
# 20   amuco_c + h2o_c + h_c + nadph_c --> 2oxoadp_c ...
# 21                 arg__L_m + h2o_m --> orn_m + urea_m
# 22   asp__L_c + atp_c + citr__L_c --> amp_c + argsu...
# 23               asn__L_m + h2o_m --> asp__L_m + nh4_m
# 24   asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c ...
# 25           asp__L_c + cbp_c <=> cbasp_c + h_c + pi_c
# 26               akg_m + asp__L_m <=> glu__L_m + oaa_m
# 27                     adp_c + atp_m --> adp_m + atp_c
# 28   2.0 atp_m + hco3_m + nh4_m --> 2.0 adp_m + cbp...
# 29         cholp_c + ctp_c + h_c --> cdpchol_c + ppi_c
# ..                                                 ...
# 160             atp_c + r5p_c --> amp_c + h_c + prpp_c
# 161            3php_c + glu__L_c --> akg_c + pser__L_c
# 162              h2o_c + pser__L_c --> pi_c + ser__L_c
# 163       adp_c + trdrd_c --> dadp_c + h2o_c + trdox_c
# 164       gdp_c + trdrd_c --> dgdp_c + h2o_c + trdox_c
# 165       cdp_c + trdrd_c --> dcdp_c + h2o_c + trdox_c
# 166       trdrd_c + udp_c --> dudp_c + h2o_c + trdox_c
# 167                            ru5p__D_c <=> xu5p__D_c
# 168                                r5p_c <=> ru5p__D_c
# 169                    g3p_c + s7p_c <=> e4p_c + f6p_c
# 170                r5p_c + xu5p__D_c <=> g3p_c + s7p_c
# 171                e4p_c + xu5p__D_c <=> f6p_c + g3p_c
# 172                                   dhap_c <=> g3p_c
# 173                    atp_c + ump_c <=> adp_c + udp_c
# 174             akg_c + val__L_c <=> 3mob_c + glu__L_c
# 175  accoa_c + atp_c + hco3_c --> adp_c + h_c + mal...
# 176            10fthf_c + aicar_c <=> fprica_c + thf_c
# 177                      argsuc_c <=> arg__L_c + fum_c
# 178  gln__L_c + h2o_c + prpp_c --> glu__L_c + ppi_c...
# 179                         h2o_c + imp_c <=> fprica_c
# 180          lac__L_c + nad_c <=> h_c + nadh_c + pyr_c
# 181          mal__L_c + nad_c <=> h_c + nadh_c + oaa_c
# 182               h2o_c + mi1p__D_c --> inost_c + pi_c
# 183              atp_c + f6p_c --> adp_c + fdp_c + h_c
# 184  atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + ...
# 185              adp_c + h_c + pep_c --> atp_c + pyr_c
# 186                dump_c + mlthf_c --> dhf_c + dtmp_c
# 187            akg_c + tyr__L_c <=> 34hpp_c + glu__L_c
# 188  acac_c + atp_c + coa_c --> aacoa_c + amp_c + p...
# 189  2.0 h_x + hmgcoa_x + 2.0 nadph_x --> coa_x + m...
#
#                                            METANETX_EC  \
# 0    <td>1.2.1.52<br>1.2.4.2<br>1.8.1.4<br>2.3.1.61...
# 1                                  <td>1.13.11.27</td>
# 2                                   <td>1.1.1.102</td>
# 3                                   <td>1.13.11.6</td>
# 4                                     <td>3.1.2.4</td>
# 5                                    <td>1.2.1.31</td>
# 6                                    <td>2.6.1.39</td>
# 7                    <td>2.3.1.16<br>2.3.1.9</br></td>
# 8                                     <td>2.3.1.9</td>
# 9                     <td>2.3.3.8<br>4.1.3.6</br></td>
# 10                                   <td>1.3.99.3</td>
# 11   <td>1.3.8.4<br>1.3.8.7<br>1.3.99.10</br></br><...
# 12                     <td>1.3.8<br>1.3.99.3</br></td>
# 13                                    <td>4.2.1.3</td>
# 14                   <td>2.7.4.10<br>2.7.4.4</br></td>
# 15                                    <td>4.3.2.2</td>
# 16                                    <td>4.3.2.2</td>
# 17                                   <td>4.1.1.21</td>
# 18   <td>1.2.1.52<br>1.2.4.2<br>1.8.1.4<br>2.3.1.61...
# 19                                    <td>2.6.1.2</td>
# 20                                    <td>1.5.1.-</td>
# 21                                    <td>3.5.3.1</td>
# 22                                    <td>6.3.4.5</td>
# 23   <td>3.5.1.1<br>3.5.1.38<br>3.5.5.4</br></br></td>
# 24                                    <td>6.3.5.4</td>
# 25                                    <td>2.1.3.2</td>
# 26                                    <td>2.6.1.1</td>
# 27                                    <td>2.7.4.6</td>
# 28                   <td>6.3.4.16<br>6.3.5.5</br></td>
# 29                                   <td>2.7.7.15</td>
# ..                                                 ...
# 160                                   <td>2.7.6.1</td>
# 161                                  <td>2.6.1.52</td>
# 162                                   <td>3.1.3.3</td>
# 163                                  <td>1.17.4.1</td>
# 164                                  <td>1.17.4.1</td>
# 165                 <td>1.17.4.1<br>1.17.4.2</br></td>
# 166                                  <td>1.17.4.1</td>
# 167                                   <td>5.1.3.1</td>
# 168                                   <td>5.3.1.6</td>
# 169                                   <td>2.2.1.2</td>
# 170                                   <td>2.2.1.1</td>
# 171                                   <td>2.2.1.1</td>
# 172                                   <td>5.3.1.1</td>
# 173  <td>2.7.4.14<br>2.7.4.22<br>2.7.4.4</br></br><...
# 174                  <td>2.6.1.42<br>2.6.1.6</br></td>
# 175                                   <td>6.4.1.2</td>
# 176                                   <td>2.1.2.3</td>
# 177                                   <td>4.3.2.1</td>
# 178                                  <td>2.4.2.14</td>
# 179                  <td>2.1.2.3<br>3.5.4.10</br></td>
# 180                                  <td>1.1.1.27</td>
# 181                <td>1.1.1.299<br>1.1.1.37</br></td>
# 182                                  <td>3.1.3.25</td>
# 183                                  <td>2.7.1.11</td>
# 184                                   <td>6.3.5.3</td>
# 185                                  <td>2.7.1.40</td>
# 186                                  <td>2.1.1.45</td>
# 187  <td>2.6.1.1<br>2.6.1.5<br>2.6.1.57<br>2.6.1.9<...
# 188                                  <td>6.2.1.16</td>
# 189                                  <td>1.1.1.34</td>
#
#                                             EC_Comp  \
# 0    ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 1                                        1.13.11.27
# 2                                         1.1.1.102
# 3                                         1.13.11.6
# 4                                           3.1.2.4
# 5                                          1.2.1.31
# 6                                          2.6.1.39
# 7                           ['2.3.1.16', '2.3.1.9']
# 8                                           2.3.1.9
# 9                            ['2.3.3.8', '4.1.3.6']
# 10                                         1.3.99.3
# 11              ['1.3.8.4', '1.3.8.7', '1.3.99.10']
# 12                          ['1.3.8.-', '1.3.99.3']
# 13                                          4.2.1.3
# 14                          ['2.7.4.10', '2.7.4.4']
# 15                                          4.3.2.2
# 16                                          4.3.2.2
# 17                                         4.1.1.21
# 18   ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 19                                          2.6.1.2
# 20                                          1.5.1.-
# 21                                          3.5.3.1
# 22                                          6.3.4.5
# 23               ['3.5.1.1', '3.5.1.38', '3.5.5.4']
# 24                                          6.3.5.4
# 25                                          2.1.3.2
# 26                                          2.6.1.1
# 27                                          2.7.4.6
# 28                          ['6.3.4.16', '6.3.5.5']
# 29                                         2.7.7.15
# ..                                              ...
# 160                                         2.7.6.1
# 161                                        2.6.1.52
# 162                                         3.1.3.3
# 163                                        1.17.4.1
# 164                                        1.17.4.1
# 165                                        1.17.4.1
# 166                                        1.17.4.1
# 167                                         5.1.3.1
# 168                                         5.3.1.6
# 169                                         2.2.1.2
# 170                                         2.2.1.1
# 171                                         2.2.1.1
# 172                                         5.3.1.1
# 173             ['2.7.4.14', '2.7.4.22', '2.7.4.4']
# 174                         ['2.6.1.42', '2.6.1.6']
# 175                                         6.4.1.2
# 176                                         2.1.2.3
# 177                                         4.3.2.1
# 178                                        2.4.2.14
# 179                         ['2.1.2.3', '3.5.4.10']
# 180                                        1.1.1.27
# 181                       ['1.1.1.299', '1.1.1.37']
# 182                                        3.1.3.25
# 183                                        2.7.1.11
# 184                                         6.3.5.3
# 185                                        2.7.1.40
# 186                                        2.1.1.45
# 187   ['2.6.1.1', '2.6.1.5', '2.6.1.57', '2.6.1.9']
# 188                                        6.2.1.16
# 189                                        1.1.1.34
#
#                                         model_rxn_name  \
# 0    2-Oxoadipate:lipoamde 2-oxidoreductase(decarbo...
# 1         4 Hydroxyphenylpyruvateoxygen oxidoreductase
# 2                       3 Dehydrosphinganine reductase
# 3                3 hydroxyanthranilate 3 4 dioxygenase
# 4     3-hydroxyisobutyryl-CoA hydrolase, mitochondrial
# 5    L-aminoadipate-semialdehyde dehydrogenase (NAD...
# 6                          2 aminoadipate transaminase
# 7                         Acetyl-CoA C-acyltransferase
# 8        Acetyl CoA C acetyltransferase  mitochondrial
# 9                                    ATP-Citrate lyase
# 10   2-methylacyl-coa dehydrogenase, trans-2-Methyl...
# 11                        Isovaleryl-coa dehydrogenase
# 12   2-methylacyl-coa dehydrogenase, 2-Methylprop-2...
# 13                                 Aconitate hydratase
# 14                             Adentylate kinase (GTP)
# 15                               Adenylsuccinate lyase
# 16                              Adenylosuccinate lyase
# 17            Phosphoribosylaminoimidazole carboxylase
# 18                        2-oxoglutarate dehydrogenase
# 19                              L-alanine transaminase
# 20                           2-aminomuconate reductase
# 21                                        Arginase (m)
# 22                          Argininosuccinate synthase
# 23                      L-asparaginase (mitochondrial)
# 24         Asparagine synthase (glutamine-hydrolysing)
# 25                      Aspartate carbamoyltransferase
# 26                              Aspartate transaminase
# 27                  ADP/ATP transporter, mitochondrial
# 28   Carbamoyl-phosphate synthase (ammonia) (mitoch...
# 29              Choline phosphate cytididyltransferase
# ..                                                 ...
# 160             Phosphoribosylpyrophosphate synthetase
# 161                         Phosphoserine transaminase
# 162               Phosphoserine phosphatase (L-serine)
# 163         Ribonucleoside-diphosphate reductase (ADP)
# 164         Ribonucleoside-diphosphate reductase (GDP)
# 165         Ribonucleoside-diphosphate reductase (CDP)
# 166         Ribonucleoside-diphosphate reductase (UDP)
# 167                   Ribulose 5-phosphate 3-epimerase
# 168                       Ribose-5-phosphate isomerase
# 169                                      Transaldolase
# 170                                      Transketolase
# 171                                      Transketolase
# 172                         Triose-phosphate isomerase
# 173                                         UMP kinase
# 174                                Valine transaminase
# 175                             Acetyl-CoA carboxylase
# 176  Phosphoribosylaminoimidazolecarboxamide formyl...
# 177                            Argininosuccinate lyase
# 178  Glutamine phosphoribosyldiphosphate amidotrans...
# 179                                 IMP cyclohydrolase
# 180                            L-lactate dehydrogenase
# 181                               Malate dehydrogenase
# 182                         Myo-inositol 1-phosphatase
# 183                                Phosphofructokinase
# 184         Phosphoribosylformylglycinamidine synthase
# 185                                    Pyruvate kinase
# 186                               Thymidylate synthase
# 187                              Tyrosine transaminase
# 188            Acetoacetyl-CoA:acetate CoA-transferase
# 189           Hydroxymethylglutaryl CoA reductase (ir)
#
#                                        metabolite_dict  \
# 0    {2oxoadp_m: -1.0, coa_m: -1.0, nad_m: -1.0, co...
# 1    {34hpp_c: -1.0, o2_c: -1.0, co2_c: 1.0, hgenti...
# 2    {3dsphgn_c: -1.0, h_c: -1.0, nadph_c: -1.0, na...
# 3    {3hanthrn_c: -1.0, o2_c: -1.0, cmusa_c: 1.0, h...
# 4    {3hibutcoa_m: -1.0, h2o_m: -1.0, 3hmp_m: 1.0, ...
# 5    {L2aadp6sa_m: -1.0, h2o_m: -1.0, nad_m: -1.0, ...
# 6    {2oxoadp_c: -1.0, glu__L_c: -1.0, L2aadp_c: 1....
# 7    {2maacoa_m: -1.0, coa_m: -1.0, accoa_m: 1.0, p...
# 8            {accoa_m: -2.0, aacoa_m: 1.0, coa_m: 1.0}
# 9    {atp_c: -1.0, cit_c: -1.0, coa_c: -1.0, accoa_...
# 10   {2mbcoa_m: -1.0, fad_m: -1.0, 2mb2coa_m: 1.0, ...
# 11   {fad_m: -1.0, ivcoa_m: -1.0, 3mb2coa_m: 1.0, f...
# 12   {fad_m: -1.0, ibcoa_m: -1.0, 2mp2coa_m: 1.0, f...
# 13                          {cit_m: -1.0, icit_m: 1.0}
# 14   {amp_c: -1.0, gtp_c: -1.0, adp_c: 1.0, gdp_c: ...
# 15             {dcamp_c: -1.0, amp_c: 1.0, fum_c: 1.0}
# 16          {25aics_c: -1.0, aicar_c: 1.0, fum_c: 1.0}
# 17   {air_c: -1.0, co2_c: -1.0, 5aizc_c: 1.0, h_c: ...
# 18   {akg_m: -1.0, coa_m: -1.0, nad_m: -1.0, co2_m:...
# 19   {akg_c: -1.0, ala__L_c: -1.0, glu__L_c: 1.0, p...
# 20   {amuco_c: -1.0, h2o_c: -1.0, h_c: -1.0, nadph_...
# 21   {arg__L_m: -1.0, h2o_m: -1.0, orn_m: 1.0, urea...
# 22   {asp__L_c: -1.0, atp_c: -1.0, citr__L_c: -1.0,...
# 23   {asn__L_m: -1.0, h2o_m: -1.0, asp__L_m: 1.0, n...
# 24   {asp__L_c: -1.0, atp_c: -1.0, gln__L_c: -1.0, ...
# 25   {asp__L_c: -1.0, cbp_c: -1.0, cbasp_c: 1.0, h_...
# 26   {akg_m: -1.0, asp__L_m: -1.0, glu__L_m: 1.0, o...
# 27   {adp_c: -1.0, atp_m: -1.0, adp_m: 1.0, atp_c: ...
# 28   {atp_m: -2.0, hco3_m: -1.0, nh4_m: -1.0, adp_m...
# 29   {cholp_c: -1.0, ctp_c: -1.0, h_c: -1.0, cdpcho...
# ..                                                 ...
# 160  {atp_c: -1.0, r5p_c: -1.0, amp_c: 1.0, h_c: 1....
# 161  {3php_c: -1.0, glu__L_c: -1.0, akg_c: 1.0, pse...
# 162  {h2o_c: -1.0, pser__L_c: -1.0, pi_c: 1.0, ser_...
# 163  {adp_c: -1.0, trdrd_c: -1.0, dadp_c: 1.0, h2o_...
# 164  {gdp_c: -1.0, trdrd_c: -1.0, dgdp_c: 1.0, h2o_...
# 165  {cdp_c: -1.0, trdrd_c: -1.0, dcdp_c: 1.0, h2o_...
# 166  {trdrd_c: -1.0, udp_c: -1.0, dudp_c: 1.0, h2o_...
# 167                  {ru5p__D_c: -1.0, xu5p__D_c: 1.0}
# 168                      {r5p_c: -1.0, ru5p__D_c: 1.0}
# 169  {g3p_c: -1.0, s7p_c: -1.0, e4p_c: 1.0, f6p_c: ...
# 170  {r5p_c: -1.0, xu5p__D_c: -1.0, g3p_c: 1.0, s7p...
# 171  {e4p_c: -1.0, xu5p__D_c: -1.0, f6p_c: 1.0, g3p...
# 172                         {dhap_c: -1.0, g3p_c: 1.0}
# 173  {atp_c: -1.0, ump_c: -1.0, adp_c: 1.0, udp_c: ...
# 174  {akg_c: -1.0, val__L_c: -1.0, 3mob_c: 1.0, glu...
# 175  {accoa_c: -1.0, atp_c: -1.0, hco3_c: -1.0, adp...
# 176  {10fthf_c: -1.0, aicar_c: -1.0, fprica_c: 1.0,...
# 177        {argsuc_c: -1.0, arg__L_c: 1.0, fum_c: 1.0}
# 178  {gln__L_c: -1.0, h2o_c: -1.0, prpp_c: -1.0, gl...
# 179          {h2o_c: -1.0, imp_c: -1.0, fprica_c: 1.0}
# 180  {lac__L_c: -1.0, nad_c: -1.0, h_c: 1.0, nadh_c...
# 181  {mal__L_c: -1.0, nad_c: -1.0, h_c: 1.0, nadh_c...
# 182  {h2o_c: -1.0, mi1p__D_c: -1.0, inost_c: 1.0, p...
# 183  {atp_c: -1.0, f6p_c: -1.0, adp_c: 1.0, fdp_c: ...
# 184  {atp_c: -1.0, fgam_c: -1.0, gln__L_c: -1.0, h2...
# 185  {adp_c: -1.0, h_c: -1.0, pep_c: -1.0, atp_c: 1...
# 186  {dump_c: -1.0, mlthf_c: -1.0, dhf_c: 1.0, dtmp...
# 187  {akg_c: -1.0, tyr__L_c: -1.0, 34hpp_c: 1.0, gl...
# 188  {acac_c: -1.0, atp_c: -1.0, coa_c: -1.0, aacoa...
# 189  {h_x: -2.0, hmgcoa_x: -1.0, nadph_x: -2.0, coa...
#
#                               reactants  \
# 0             [2oxoadp_m, coa_m, nad_m]
# 1                       [34hpp_c, o2_c]
# 2             [3dsphgn_c, h_c, nadph_c]
# 3                    [3hanthrn_c, o2_c]
# 4                  [3hibutcoa_m, h2o_m]
# 5           [L2aadp6sa_m, h2o_m, nad_m]
# 6                 [2oxoadp_c, glu__L_c]
# 7                    aacoa_m, coa_m]
# 8                             [accoa_m]
# 9                 [atp_c, cit_c, coa_c]
# 10                    bcoa_m, fad_m]
# 11                     [fad_m, ivcoa_m]
# 12                     [fad_m, ibcoa_m]
# 13                              [cit_m]
# 14                       [amp_c, gtp_c]
# 15                            [dcamp_c]
# 16                           [25aics_c]
# 17                       [air_c, co2_c]
# 18                [akg_m, coa_m, nad_m]
# 19                    [akg_c, ala__L_c]
# 20       [amuco_c, h2o_c, h_c, nadph_c]
# 21                    [arg__L_m, h2o_m]
# 22         [asp__L_c, atp_c, citr__L_c]
# 23                    [asn__L_m, h2o_m]
# 24   [asp__L_c, atp_c, gln__L_c, h2o_c]
# 25                    [asp__L_c, cbp_c]
# 26                    [akg_m, asp__L_m]
# 27                       [adp_c, atp_m]
# 28               [atp_m, hco3_m, nh4_m]
# 29                [cholp_c, ctp_c, h_c]
# ..                                  ...
# 160                      [atp_c, r5p_c]
# 161                  [3php_c, glu__L_c]
# 162                  [h2o_c, pser__L_c]
# 163                    [adp_c, trdrd_c]
# 164                    [gdp_c, trdrd_c]
# 165                    [cdp_c, trdrd_c]
# 166                    [trdrd_c, udp_c]
# 167                         [ru5p__D_c]
# 168                             [r5p_c]
# 169                      [g3p_c, s7p_c]
# 170                  [r5p_c, xu5p__D_c]
# 171                  [e4p_c, xu5p__D_c]
# 172                            [dhap_c]
# 173                      [atp_c, ump_c]
# 174                   [akg_c, val__L_c]
# 175            [accoa_c, atp_c, hco3_c]
# 176                 [10fthf_c, aicar_c]
# 177                          [argsuc_c]
# 178           [gln__L_c, h2o_c, prpp_c]
# 179                      [h2o_c, imp_c]
# 180                   [lac__L_c, nad_c]
# 181                   [mal__L_c, nad_c]
# 182                  [h2o_c, mi1p__D_c]
# 183                      [atp_c, f6p_c]
# 184    [atp_c, fgam_c, gln__L_c, h2o_c]
# 185                 [adp_c, h_c, pep_c]
# 186                   [dump_c, mlthf_c]
# 187                   [akg_c, tyr__L_c]
# 188              [acac_c, atp_c, coa_c]
# 189            [h_x, hmgcoa_x, nadph_x]
#
#                                     products
# 0                 [co2_m, glutcoa_m, nadh_m]
# 1                         [co2_c, hgentis_c]
# 2                          [nadp_c, sphgn_c]
# 3                             [cmusa_c, h_c]
# 4                       [3hmp_m, coa_m, h_m]
# 5                    [L2aadp_m, h_m, nadh_m]
# 6                          [L2aadp_c, akg_c]
# 7                         [accoa_m, ppcoa_m]
# 8                           [aacoa_m, coa_m]
# 9              [accoa_c, adp_c, oaa_c, pi_c]
# 10                      b2coa_m, fadh2_m]
# 11                      b2coa_m, fadh2_m]
# 12                      p2coa_m, fadh2_m]
# 13                                  [icit_m]
# 14                            [adp_c, gdp_c]
# 15                            [amp_c, fum_c]
# 16                          [aicar_c, fum_c]
# 17                            [5aizc_c, h_c]
# 18                 [co2_m, nadh_m, succoa_m]
# 19                         [glu__L_c, pyr_c]
# 20                [2oxoadp_c, nadp_c, nh4_c]
# 21                           [orn_m, urea_m]
# 22             [amp_c, argsuc_c, h_c, ppi_c]
# 23                         [asp__L_m, nh4_m]
# 24   [amp_c, asn__L_c, glu__L_c, h_c, ppi_c]
# 25                      [cbasp_c, h_c, pi_c]
# 26                         [glu__L_m, oaa_m]
# 27                            [adp_m, atp_c]
# 28                 [adp_m, cbp_m, h_m, pi_m]
# 29                        [cdpchol_c, ppi_c]
# ..                                       ...
# 160                     [amp_c, h_c, prpp_c]
# 161                       [akg_c, pser__L_c]
# 162                         [pi_c, ser__L_c]
# 163                 [dadp_c, h2o_c, trdox_c]
# 164                 [dgdp_c, h2o_c, trdox_c]
# 165                 [dcdp_c, h2o_c, trdox_c]
# 166                 [dudp_c, h2o_c, trdox_c]
# 167                              [xu5p__D_c]
# 168                              [ru5p__D_c]
# 169                           [e4p_c, f6p_c]
# 170                           [g3p_c, s7p_c]
# 171                           [f6p_c, g3p_c]
# 172                                  [g3p_c]
# 173                           [adp_c, udp_c]
# 174                       ob_c, glu__L_c]
# 175             [adp_c, h_c, malcoa_c, pi_c]
# 176                        [fprica_c, thf_c]
# 177                        [arg__L_c, fum_c]
# 178                [glu__L_c, ppi_c, pram_c]
# 179                               [fprica_c]
# 180                     [h_c, nadh_c, pyr_c]
# 181                     [h_c, nadh_c, oaa_c]
# 182                          [inost_c, pi_c]
# 183                      [adp_c, fdp_c, h_c]
# 184    [adp_c, fpram_c, glu__L_c, h_c, pi_c]
# 185                           [atp_c, pyr_c]
# 186                          [dhf_c, dtmp_c]
# 187                      [34hpp_c, glu__L_c]
# 188                  [aacoa_c, amp_c, ppi_c]
# 189                [coa_x, mev__R_x, nadp_x]
#
# [190 rows x 14 columns]

# %%
#reorder columns for optimal curation
print (df_EC.columns)
column_order=['ANNOT_BIGG', 'ANNOT_EC','EC_Comp' ,'model_rxn_name', 'rxn_id', 'rxn_string','metabolite_dict',
              'reactants', 'products','ANNOT_METANET', 'Annot Keys', 'Annot Values',
              'Full Annotation']
df_EC=df_EC[column_order]
# Out:
# Index(['ANNOT_BIGG', 'ANNOT_EC', 'ANNOT_METANET', 'Annot Keys', 'Annot Values',
#        'Full Annotation', 'rxn_id', 'rxn_string', 'METANETX_EC', 'EC_Comp',
#        'model_rxn_name', 'metabolite_dict', 'reactants', 'products'],
#       dtype='object')

# %%
df_EC
# Out:
#     ANNOT_BIGG                                        ANNOT_EC  \
# 0    2OXOADOXm  ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 1      34HPPOR                                      1.13.11.27
# 2       3DSPHR                                       1.1.1.102
# 3         3HAO                                       1.13.11.6
# 4    3HBCOAHLm                                         3.1.2.4
# 5      AASAD3m                                        1.2.1.31
# 6         AATA                                        2.6.1.39
# 7     ACACT10m                         ['2.3.1.16', '2.3.1.9']
# 8      ACACT1m                                         2.3.1.9
# 9        ACITL                          ['2.3.3.8', '4.1.3.6']
# 10    ACOAD10m                                        1.3.99.3
# 11     ACOAD8m             ['1.3.8.4', '1.3.8.7', '1.3.99.10']
# 12     ACOAD9m                         ['1.3.8.-', '1.3.99.3']
# 13      ACONTm                                         4.2.1.3
# 14        ADK3                         ['2.7.4.10', '2.7.4.4']
# 15      ADSL1r                                         4.3.2.2
# 16      ADSL2r                                         4.3.2.2
# 17       AIRCr                                        4.1.1.21
# 18       AKGDm  ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 19     ALATA_L                                         2.6.1.2
# 20      AMCOXO                                         1.5.1.-
# 21       ARGNm                                         3.5.3.1
# 22       ARGSS                                         6.3.4.5
# 23       ASNNm              ['3.5.1.1', '3.5.1.38', '3.5.5.4']
# 24       ASNS1                                         6.3.5.4
# 25       ASPCT                                         2.1.3.2
# 26      ASPTAm                                         2.6.1.1
# 27       ATPtm                                         2.7.4.6
# 28      CBPSam                         ['6.3.4.16', '6.3.5.5']
# 29     CHLPCTD                                        2.7.7.15
# ..         ...                                             ...
# 160      PRPPS                                         2.7.6.1
# 161      PSERT                                        2.6.1.52
# 162      PSP_L                                         3.1.3.3
# 163      RNDR1                                        1.17.4.1
# 164      RNDR2                                        1.17.4.1
# 165      RNDR3                                        1.17.4.1
# 166      RNDR4                                        1.17.4.1
# 167        RPE                                         5.1.3.1
# 168        RPI                                         5.3.1.6
# 169       TALA                                         2.2.1.2
# 170       TKT1                                         2.2.1.1
# 171       TKT2                                         2.2.1.1
# 172        TPI                                         5.3.1.1
# 173       UMPK             ['2.7.4.14', '2.7.4.22', '2.7.4.4']
# 174      VALTA                         ['2.6.1.42', '2.6.1.6']
# 175     ACCOAC                                         6.4.1.2
# 176     AICART                                         2.1.2.3
# 177      ARGSL                                         4.3.2.1
# 178     GLUPRT                                        2.4.2.14
# 179       IMPC                         ['2.1.2.3', '3.5.4.10']
# 180      LDH_L                                        1.1.1.27
# 181        MDH                       ['1.1.1.299', '1.1.1.37']
# 182      MI1PP                                        3.1.3.25
# 183        PFK                                        2.7.1.11
# 184      PRFGS                                         6.3.5.3
# 185        PYK                                        2.7.1.40
# 186       TMDS                                        2.1.1.45
# 187      TYRTA   ['2.6.1.1', '2.6.1.5', '2.6.1.57', '2.6.1.9']
# 188     AACOAT                                        6.2.1.16
# 189   HMGCOARx                                        1.1.1.34
#
#                                             EC_Comp  \
# 0    ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 1                                        1.13.11.27
# 2                                         1.1.1.102
# 3                                         1.13.11.6
# 4                                           3.1.2.4
# 5                                          1.2.1.31
# 6                                          2.6.1.39
# 7                           ['2.3.1.16', '2.3.1.9']
# 8                                           2.3.1.9
# 9                            ['2.3.3.8', '4.1.3.6']
# 10                                         1.3.99.3
# 11              ['1.3.8.4', '1.3.8.7', '1.3.99.10']
# 12                          ['1.3.8.-', '1.3.99.3']
# 13                                          4.2.1.3
# 14                          ['2.7.4.10', '2.7.4.4']
# 15                                          4.3.2.2
# 16                                          4.3.2.2
# 17                                         4.1.1.21
# 18   ['1.2.1.52', '1.2.4.2', '1.8.1.4', '2.3.1.61']
# 19                                          2.6.1.2
# 20                                          1.5.1.-
# 21                                          3.5.3.1
# 22                                          6.3.4.5
# 23               ['3.5.1.1', '3.5.1.38', '3.5.5.4']
# 24                                          6.3.5.4
# 25                                          2.1.3.2
# 26                                          2.6.1.1
# 27                                          2.7.4.6
# 28                          ['6.3.4.16', '6.3.5.5']
# 29                                         2.7.7.15
# ..                                              ...
# 160                                         2.7.6.1
# 161                                        2.6.1.52
# 162                                         3.1.3.3
# 163                                        1.17.4.1
# 164                                        1.17.4.1
# 165                                        1.17.4.1
# 166                                        1.17.4.1
# 167                                         5.1.3.1
# 168                                         5.3.1.6
# 169                                         2.2.1.2
# 170                                         2.2.1.1
# 171                                         2.2.1.1
# 172                                         5.3.1.1
# 173             ['2.7.4.14', '2.7.4.22', '2.7.4.4']
# 174                         ['2.6.1.42', '2.6.1.6']
# 175                                         6.4.1.2
# 176                                         2.1.2.3
# 177                                         4.3.2.1
# 178                                        2.4.2.14
# 179                         ['2.1.2.3', '3.5.4.10']
# 180                                        1.1.1.27
# 181                       ['1.1.1.299', '1.1.1.37']
# 182                                        3.1.3.25
# 183                                        2.7.1.11
# 184                                         6.3.5.3
# 185                                        2.7.1.40
# 186                                        2.1.1.45
# 187   ['2.6.1.1', '2.6.1.5', '2.6.1.57', '2.6.1.9']
# 188                                        6.2.1.16
# 189                                        1.1.1.34
#
#                                         model_rxn_name     rxn_id  \
# 0    2-Oxoadipate:lipoamde 2-oxidoreductase(decarbo...  2OXOADOXm
# 1         4 Hydroxyphenylpyruvateoxygen oxidoreductase    34HPPOR
# 2                       3 Dehydrosphinganine reductase     3DSPHR
# 3                3 hydroxyanthranilate 3 4 dioxygenase       3HAO
# 4     3-hydroxyisobutyryl-CoA hydrolase, mitochondrial  3HBCOAHLm
# 5    L-aminoadipate-semialdehyde dehydrogenase (NAD...    AASAD3m
# 6                          2 aminoadipate transaminase       AATA
# 7                         Acetyl-CoA C-acyltransferase   ACACT10m
# 8        Acetyl CoA C acetyltransferase  mitochondrial    ACACT1m
# 9                                    ATP-Citrate lyase      ACITL
# 10   2-methylacyl-coa dehydrogenase, trans-2-Methyl...   ACOAD10m
# 11                        Isovaleryl-coa dehydrogenase    ACOAD8m
# 12   2-methylacyl-coa dehydrogenase, 2-Methylprop-2...    ACOAD9m
# 13                                 Aconitate hydratase     ACONTm
# 14                             Adentylate kinase (GTP)       ADK3
# 15                               Adenylsuccinate lyase     ADSL1r
# 16                              Adenylosuccinate lyase     ADSL2r
# 17            Phosphoribosylaminoimidazole carboxylase      AIRCr
# 18                        2-oxoglutarate dehydrogenase      AKGDm
# 19                              L-alanine transaminase    ALATA_L
# 20                           2-aminomuconate reductase     AMCOXO
# 21                                        Arginase (m)      ARGNm
# 22                          Argininosuccinate synthase      ARGSS
# 23                      L-asparaginase (mitochondrial)      ASNNm
# 24         Asparagine synthase (glutamine-hydrolysing)      ASNS1
# 25                      Aspartate carbamoyltransferase      ASPCT
# 26                              Aspartate transaminase     ASPTAm
# 27                  ADP/ATP transporter, mitochondrial      ATPtm
# 28   Carbamoyl-phosphate synthase (ammonia) (mitoch...     CBPSam
# 29              Choline phosphate cytididyltransferase    CHLPCTD
# ..                                                 ...        ...
# 160             Phosphoribosylpyrophosphate synthetase      PRPPS
# 161                         Phosphoserine transaminase      PSERT
# 162               Phosphoserine phosphatase (L-serine)      PSP_L
# 163         Ribonucleoside-diphosphate reductase (ADP)      RNDR1
# 164         Ribonucleoside-diphosphate reductase (GDP)      RNDR2
# 165         Ribonucleoside-diphosphate reductase (CDP)      RNDR3
# 166         Ribonucleoside-diphosphate reductase (UDP)      RNDR4
# 167                   Ribulose 5-phosphate 3-epimerase        RPE
# 168                       Ribose-5-phosphate isomerase        RPI
# 169                                      Transaldolase       TALA
# 170                                      Transketolase       TKT1
# 171                                      Transketolase       TKT2
# 172                         Triose-phosphate isomerase        TPI
# 173                                         UMP kinase       UMPK
# 174                                Valine transaminase      VALTA
# 175                             Acetyl-CoA carboxylase     ACCOAC
# 176  Phosphoribosylaminoimidazolecarboxamide formyl...     AICART
# 177                            Argininosuccinate lyase      ARGSL
# 178  Glutamine phosphoribosyldiphosphate amidotrans...     GLUPRT
# 179                                 IMP cyclohydrolase       IMPC
# 180                            L-lactate dehydrogenase      LDH_L
# 181                               Malate dehydrogenase        MDH
# 182                         Myo-inositol 1-phosphatase      MI1PP
# 183                                Phosphofructokinase        PFK
# 184         Phosphoribosylformylglycinamidine synthase      PRFGS
# 185                                    Pyruvate kinase        PYK
# 186                               Thymidylate synthase       TMDS
# 187                              Tyrosine transaminase      TYRTA
# 188            Acetoacetyl-CoA:acetate CoA-transferase     AACOAT
# 189           Hydroxymethylglutaryl CoA reductase (ir)   HMGCOARx
#
#                                             rxn_string  \
# 0    2oxoadp_m + coa_m + nad_m --> co2_m + glutcoa_...
# 1                 34hpp_c + o2_c --> co2_c + hgentis_c
# 2       3dsphgn_c + h_c + nadph_c --> nadp_c + sphgn_c
# 3                  3hanthrn_c + o2_c --> cmusa_c + h_c
# 4         3hibutcoa_m + h2o_m --> 3hmp_m + coa_m + h_m
# 5    L2aadp6sa_m + h2o_m + nad_m --> L2aadp_m + 2.0...
# 6            2oxoadp_c + glu__L_c <=> L2aadp_c + akg_c
# 7              2maacoa_m + coa_m <=> accoa_m + ppcoa_m
# 8                      2.0 accoa_m --> aacoa_m + coa_m
# 9    atp_c + cit_c + coa_c --> accoa_c + adp_c + oa...
# 10            2mbcoa_m + fad_m --> 2mb2coa_m + fadh2_m
# 11             fad_m + ivcoa_m --> 3mb2coa_m + fadh2_m
# 12             fad_m + ibcoa_m --> 2mp2coa_m + fadh2_m
# 13                                    cit_m <=> icit_m
# 14                     amp_c + gtp_c <=> adp_c + gdp_c
# 15                           dcamp_c --> amp_c + fum_c
# 16                        25aics_c --> aicar_c + fum_c
# 17                     air_c + co2_c <=> 5aizc_c + h_c
# 18   akg_m + coa_m + nad_m --> co2_m + nadh_m + suc...
# 19               akg_c + ala__L_c <=> glu__L_c + pyr_c
# 20   amuco_c + h2o_c + h_c + nadph_c --> 2oxoadp_c ...
# 21                 arg__L_m + h2o_m --> orn_m + urea_m
# 22   asp__L_c + atp_c + citr__L_c --> amp_c + argsu...
# 23               asn__L_m + h2o_m --> asp__L_m + nh4_m
# 24   asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c ...
# 25           asp__L_c + cbp_c <=> cbasp_c + h_c + pi_c
# 26               akg_m + asp__L_m <=> glu__L_m + oaa_m
# 27                     adp_c + atp_m --> adp_m + atp_c
# 28   2.0 atp_m + hco3_m + nh4_m --> 2.0 adp_m + cbp...
# 29         cholp_c + ctp_c + h_c --> cdpchol_c + ppi_c
# ..                                                 ...
# 160             atp_c + r5p_c --> amp_c + h_c + prpp_c
# 161            3php_c + glu__L_c --> akg_c + pser__L_c
# 162              h2o_c + pser__L_c --> pi_c + ser__L_c
# 163       adp_c + trdrd_c --> dadp_c + h2o_c + trdox_c
# 164       gdp_c + trdrd_c --> dgdp_c + h2o_c + trdox_c
# 165       cdp_c + trdrd_c --> dcdp_c + h2o_c + trdox_c
# 166       trdrd_c + udp_c --> dudp_c + h2o_c + trdox_c
# 167                            ru5p__D_c <=> xu5p__D_c
# 168                                r5p_c <=> ru5p__D_c
# 169                    g3p_c + s7p_c <=> e4p_c + f6p_c
# 170                r5p_c + xu5p__D_c <=> g3p_c + s7p_c
# 171                e4p_c + xu5p__D_c <=> f6p_c + g3p_c
# 172                                   dhap_c <=> g3p_c
# 173                    atp_c + ump_c <=> adp_c + udp_c
# 174             akg_c + val__L_c <=> 3mob_c + glu__L_c
# 175  accoa_c + atp_c + hco3_c --> adp_c + h_c + mal...
# 176            10fthf_c + aicar_c <=> fprica_c + thf_c
# 177                      argsuc_c <=> arg__L_c + fum_c
# 178  gln__L_c + h2o_c + prpp_c --> glu__L_c + ppi_c...
# 179                         h2o_c + imp_c <=> fprica_c
# 180          lac__L_c + nad_c <=> h_c + nadh_c + pyr_c
# 181          mal__L_c + nad_c <=> h_c + nadh_c + oaa_c
# 182               h2o_c + mi1p__D_c --> inost_c + pi_c
# 183              atp_c + f6p_c --> adp_c + fdp_c + h_c
# 184  atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + ...
# 185              adp_c + h_c + pep_c --> atp_c + pyr_c
# 186                dump_c + mlthf_c --> dhf_c + dtmp_c
# 187            akg_c + tyr__L_c <=> 34hpp_c + glu__L_c
# 188  acac_c + atp_c + coa_c --> aacoa_c + amp_c + p...
# 189  2.0 h_x + hmgcoa_x + 2.0 nadph_x --> coa_x + m...
#
#                                        metabolite_dict  \
# 0    {2oxoadp_m: -1.0, coa_m: -1.0, nad_m: -1.0, co...
# 1    {34hpp_c: -1.0, o2_c: -1.0, co2_c: 1.0, hgenti...
# 2    {3dsphgn_c: -1.0, h_c: -1.0, nadph_c: -1.0, na...
# 3    {3hanthrn_c: -1.0, o2_c: -1.0, cmusa_c: 1.0, h...
# 4    {3hibutcoa_m: -1.0, h2o_m: -1.0, 3hmp_m: 1.0, ...
# 5    {L2aadp6sa_m: -1.0, h2o_m: -1.0, nad_m: -1.0, ...
# 6    {2oxoadp_c: -1.0, glu__L_c: -1.0, L2aadp_c: 1....
# 7    {2maacoa_m: -1.0, coa_m: -1.0, accoa_m: 1.0, p...
# 8            {accoa_m: -2.0, aacoa_m: 1.0, coa_m: 1.0}
# 9    {atp_c: -1.0, cit_c: -1.0, coa_c: -1.0, accoa_...
# 10   {2mbcoa_m: -1.0, fad_m: -1.0, 2mb2coa_m: 1.0, ...
# 11   {fad_m: -1.0, ivcoa_m: -1.0, 3mb2coa_m: 1.0, f...
# 12   {fad_m: -1.0, ibcoa_m: -1.0, 2mp2coa_m: 1.0, f...
# 13                          {cit_m: -1.0, icit_m: 1.0}
# 14   {amp_c: -1.0, gtp_c: -1.0, adp_c: 1.0, gdp_c: ...
# 15             {dcamp_c: -1.0, amp_c: 1.0, fum_c: 1.0}
# 16          {25aics_c: -1.0, aicar_c: 1.0, fum_c: 1.0}
# 17   {air_c: -1.0, co2_c: -1.0, 5aizc_c: 1.0, h_c: ...
# 18   {akg_m: -1.0, coa_m: -1.0, nad_m: -1.0, co2_m:...
# 19   {akg_c: -1.0, ala__L_c: -1.0, glu__L_c: 1.0, p...
# 20   {amuco_c: -1.0, h2o_c: -1.0, h_c: -1.0, nadph_...
# 21   {arg__L_m: -1.0, h2o_m: -1.0, orn_m: 1.0, urea...
# 22   {asp__L_c: -1.0, atp_c: -1.0, citr__L_c: -1.0,...
# 23   {asn__L_m: -1.0, h2o_m: -1.0, asp__L_m: 1.0, n...
# 24   {asp__L_c: -1.0, atp_c: -1.0, gln__L_c: -1.0, ...
# 25   {asp__L_c: -1.0, cbp_c: -1.0, cbasp_c: 1.0, h_...
# 26   {akg_m: -1.0, asp__L_m: -1.0, glu__L_m: 1.0, o...
# 27   {adp_c: -1.0, atp_m: -1.0, adp_m: 1.0, atp_c: ...
# 28   {atp_m: -2.0, hco3_m: -1.0, nh4_m: -1.0, adp_m...
# 29   {cholp_c: -1.0, ctp_c: -1.0, h_c: -1.0, cdpcho...
# ..                                                 ...
# 160  {atp_c: -1.0, r5p_c: -1.0, amp_c: 1.0, h_c: 1....
# 161  {3php_c: -1.0, glu__L_c: -1.0, akg_c: 1.0, pse...
# 162  {h2o_c: -1.0, pser__L_c: -1.0, pi_c: 1.0, ser_...
# 163  {adp_c: -1.0, trdrd_c: -1.0, dadp_c: 1.0, h2o_...
# 164  {gdp_c: -1.0, trdrd_c: -1.0, dgdp_c: 1.0, h2o_...
# 165  {cdp_c: -1.0, trdrd_c: -1.0, dcdp_c: 1.0, h2o_...
# 166  {trdrd_c: -1.0, udp_c: -1.0, dudp_c: 1.0, h2o_...
# 167                  {ru5p__D_c: -1.0, xu5p__D_c: 1.0}
# 168                      {r5p_c: -1.0, ru5p__D_c: 1.0}
# 169  {g3p_c: -1.0, s7p_c: -1.0, e4p_c: 1.0, f6p_c: ...
# 170  {r5p_c: -1.0, xu5p__D_c: -1.0, g3p_c: 1.0, s7p...
# 171  {e4p_c: -1.0, xu5p__D_c: -1.0, f6p_c: 1.0, g3p...
# 172                         {dhap_c: -1.0, g3p_c: 1.0}
# 173  {atp_c: -1.0, ump_c: -1.0, adp_c: 1.0, udp_c: ...
# 174  {akg_c: -1.0, val__L_c: -1.0, 3mob_c: 1.0, glu...
# 175  {accoa_c: -1.0, atp_c: -1.0, hco3_c: -1.0, adp...
# 176  {10fthf_c: -1.0, aicar_c: -1.0, fprica_c: 1.0,...
# 177        {argsuc_c: -1.0, arg__L_c: 1.0, fum_c: 1.0}
# 178  {gln__L_c: -1.0, h2o_c: -1.0, prpp_c: -1.0, gl...
# 179          {h2o_c: -1.0, imp_c: -1.0, fprica_c: 1.0}
# 180  {lac__L_c: -1.0, nad_c: -1.0, h_c: 1.0, nadh_c...
# 181  {mal__L_c: -1.0, nad_c: -1.0, h_c: 1.0, nadh_c...
# 182  {h2o_c: -1.0, mi1p__D_c: -1.0, inost_c: 1.0, p...
# 183  {atp_c: -1.0, f6p_c: -1.0, adp_c: 1.0, fdp_c: ...
# 184  {atp_c: -1.0, fgam_c: -1.0, gln__L_c: -1.0, h2...
# 185  {adp_c: -1.0, h_c: -1.0, pep_c: -1.0, atp_c: 1...
# 186  {dump_c: -1.0, mlthf_c: -1.0, dhf_c: 1.0, dtmp...
# 187  {akg_c: -1.0, tyr__L_c: -1.0, 34hpp_c: 1.0, gl...
# 188  {acac_c: -1.0, atp_c: -1.0, coa_c: -1.0, aacoa...
# 189  {h_x: -2.0, hmgcoa_x: -1.0, nadph_x: -2.0, coa...
#
#                               reactants  \
# 0             [2oxoadp_m, coa_m, nad_m]
# 1                       [34hpp_c, o2_c]
# 2             [3dsphgn_c, h_c, nadph_c]
# 3                    [3hanthrn_c, o2_c]
# 4                  [3hibutcoa_m, h2o_m]
# 5           [L2aadp6sa_m, h2o_m, nad_m]
# 6                 [2oxoadp_c, glu__L_c]
# 7                    aacoa_m, coa_m]
# 8                             [accoa_m]
# 9                 [atp_c, cit_c, coa_c]
# 10                    bcoa_m, fad_m]
# 11                     [fad_m, ivcoa_m]
# 12                     [fad_m, ibcoa_m]
# 13                              [cit_m]
# 14                       [amp_c, gtp_c]
# 15                            [dcamp_c]
# 16                           [25aics_c]
# 17                       [air_c, co2_c]
# 18                [akg_m, coa_m, nad_m]
# 19                    [akg_c, ala__L_c]
# 20       [amuco_c, h2o_c, h_c, nadph_c]
# 21                    [arg__L_m, h2o_m]
# 22         [asp__L_c, atp_c, citr__L_c]
# 23                    [asn__L_m, h2o_m]
# 24   [asp__L_c, atp_c, gln__L_c, h2o_c]
# 25                    [asp__L_c, cbp_c]
# 26                    [akg_m, asp__L_m]
# 27                       [adp_c, atp_m]
# 28               [atp_m, hco3_m, nh4_m]
# 29                [cholp_c, ctp_c, h_c]
# ..                                  ...
# 160                      [atp_c, r5p_c]
# 161                  [3php_c, glu__L_c]
# 162                  [h2o_c, pser__L_c]
# 163                    [adp_c, trdrd_c]
# 164                    [gdp_c, trdrd_c]
# 165                    [cdp_c, trdrd_c]
# 166                    [trdrd_c, udp_c]
# 167                         [ru5p__D_c]
# 168                             [r5p_c]
# 169                      [g3p_c, s7p_c]
# 170                  [r5p_c, xu5p__D_c]
# 171                  [e4p_c, xu5p__D_c]
# 172                            [dhap_c]
# 173                      [atp_c, ump_c]
# 174                   [akg_c, val__L_c]
# 175            [accoa_c, atp_c, hco3_c]
# 176                 [10fthf_c, aicar_c]
# 177                          [argsuc_c]
# 178           [gln__L_c, h2o_c, prpp_c]
# 179                      [h2o_c, imp_c]
# 180                   [lac__L_c, nad_c]
# 181                   [mal__L_c, nad_c]
# 182                  [h2o_c, mi1p__D_c]
# 183                      [atp_c, f6p_c]
# 184    [atp_c, fgam_c, gln__L_c, h2o_c]
# 185                 [adp_c, h_c, pep_c]
# 186                   [dump_c, mlthf_c]
# 187                   [akg_c, tyr__L_c]
# 188              [acac_c, atp_c, coa_c]
# 189            [h_x, hmgcoa_x, nadph_x]
#
#                                     products ANNOT_METANET  \
# 0                 [co2_m, glutcoa_m, nadh_m]     MNXR94818
# 1                         [co2_c, hgentis_c]     MNXR94843
# 2                          [nadp_c, sphgn_c]     MNXR94866
# 3                             [cmusa_c, h_c]     MNXR94889
# 4                       [3hmp_m, coa_m, h_m]     MNXR94891
# 5                    [L2aadp_m, h_m, nadh_m]     MNXR95158
# 6                          [L2aadp_c, akg_c]     MNXR95160
# 7                         [accoa_m, ppcoa_m]     MNXR95195
# 8                           [aacoa_m, coa_m]     MNXR95194
# 9              [accoa_c, adp_c, oaa_c, pi_c]     MNXR95268
# 10                      b2coa_m, fadh2_m]     MNXR95306
# 11                      b2coa_m, fadh2_m]     MNXR95318
# 12                      p2coa_m, fadh2_m]     MNXR95319
# 13                                  [icit_m]     MNXR95384
# 14                            [adp_c, gdp_c]     MNXR95452
# 15                            [amp_c, fum_c]     MNXR95493
# 16                          [aicar_c, fum_c]     MNXR95494
# 17                            [5aizc_c, h_c]     MNXR95646
# 18                 [co2_m, nadh_m, succoa_m]     MNXR95655
# 19                         [glu__L_c, pyr_c]     MNXR95698
# 20                [2oxoadp_c, nadp_c, nh4_c]     MNXR95807
# 21                           [orn_m, urea_m]     MNXR95945
# 22             [amp_c, argsuc_c, h_c, ppi_c]     MNXR95949
# 23                         [asp__L_m, nh4_m]     MNXR96056
# 24   [amp_c, asn__L_c, glu__L_c, h_c, ppi_c]     MNXR96059
# 25                      [cbasp_c, h_c, pi_c]     MNXR96080
# 26                         [glu__L_m, oaa_m]     MNXR96079
# 27                            [adp_m, atp_c]     MNXR96123
# 28                 [adp_m, cbp_m, h_m, pi_m]     MNXR96486
# 29                        [cdpchol_c, ppi_c]     MNXR96686
# ..                                       ...           ...
# 160                     [amp_c, h_c, prpp_c]    MNXR103215
# 161                       [akg_c, pser__L_c]    MNXR103225
# 162                         [pi_c, ser__L_c]    MNXR103260
# 163                 [dadp_c, h2o_c, trdox_c]    MNXR104060
# 164                 [dgdp_c, h2o_c, trdox_c]    MNXR104062
# 165                 [dcdp_c, h2o_c, trdox_c]    MNXR104064
# 166                 [dudp_c, h2o_c, trdox_c]    MNXR104066
# 167                              [xu5p__D_c]    MNXR104083
# 168                              [ru5p__D_c]    MNXR104084
# 169                           [e4p_c, f6p_c]    MNXR104715
# 170                           [g3p_c, s7p_c]    MNXR104868
# 171                           [f6p_c, g3p_c]    MNXR104869
# 172                                  [g3p_c]    MNXR104918
# 173                           [adp_c, udp_c]    MNXR105118
# 174                       ob_c, glu__L_c]     MNXR96230
# 175             [adp_c, h_c, malcoa_c, pi_c]     MNXR95219
# 176                        [fprica_c, thf_c]     MNXR95639
# 177                        [arg__L_c, fum_c]     MNXR95948
# 178                [glu__L_c, ppi_c, pram_c]    MNXR100287
# 179                               [fprica_c]    MNXR100783
# 180                     [h_c, nadh_c, pyr_c]    MNXR101040
# 181                     [h_c, nadh_c, oaa_c]    MNXR101439
# 182                          [inost_c, pi_c]    MNXR101570
# 183                      [adp_c, fdp_c, h_c]    MNXR102507
# 184    [adp_c, fpram_c, glu__L_c, h_c, pi_c]    MNXR103165
# 185                           [atp_c, pyr_c]    MNXR103371
# 186                          [dhf_c, dtmp_c]    MNXR104889
# 187                      [34hpp_c, glu__L_c]    MNXR105000
# 188                  [aacoa_c, amp_c, ppi_c]     MNXR95136
# 189                [coa_x, mev__R_x, nadp_x]    MNXR100659
#
#                                             Annot Keys  \
# 0    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 1    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 2    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 3    dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 4    dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 5    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 6    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 7    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 8    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 9    dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 10   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 11   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 12   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 13   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 14   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 15   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 16   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 17   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 18   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 19   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 20   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 21   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 22   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 23   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 24   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 25   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 26   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 27   dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 28   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 29   dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# ..                                                 ...
# 160  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 161  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 162  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 163  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 164  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 165  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 166  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 167  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 168  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 169  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 170  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 171  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 172  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 173  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 174  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 175  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 176  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 177  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 178  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 179  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 180  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 181  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 182  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 183  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 184  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 185  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 186  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
# 187  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 188  dict_keys(['SBO', 'bigg.reaction', 'biocyc', '...
# 189  dict_keys(['SBO', 'bigg.reaction', 'ec-code', ...
#
#                                           Annot Values  \
# 0    dict_values(['SBO:0000375', '2OXOADOXm', 'META...
# 1    dict_values(['SBO:0000375', '34HPPOR', 'META:4...
# 2    dict_values(['SBO:0000375', '3DSPHR', 'META:3-...
# 3    dict_values(['SBO:0000375', '3HAO', '1.13.11.6...
# 4    dict_values(['SBO:0000375', '3HBCOAHLm', '3.1....
# 5    dict_values(['SBO:0000375', 'AASAD3m', 'META:A...
# 6    dict_values(['SBO:0000375', 'AATA', 'META:2-AM...
# 7    dict_values(['SBO:0000375', 'ACACT10m', 'META:...
# 8    dict_values(['SBO:0000375', 'ACACT1m', 'META:A...
# 9    dict_values(['SBO:0000375', 'ACITL', 'META:ATP...
# 10   dict_values(['SBO:0000375', 'ACOAD10m', '1.3.9...
# 11   dict_values(['SBO:0000375', 'ACOAD8m', 'META:R...
# 12   dict_values(['SBO:0000375', 'ACOAD9m', 'META:M...
# 13   dict_values(['SBO:0000375', 'ACONTm', '4.2.1.3...
# 14   dict_values(['SBO:0000375', 'ADK3', 'META:RXN-...
# 15   dict_values(['SBO:0000375', 'ADSL1r', 'META:AM...
# 16   dict_values(['SBO:0000375', 'ADSL2r', 'META:AI...
# 17   dict_values(['SBO:0000375', 'AIRCr', '4.1.1.21...
# 18   dict_values(['SBO:0000375', 'AKGDm', 'META:2OX...
# 19   dict_values(['SBO:0000375', 'ALATA_L', ['META:...
# 20   dict_values(['SBO:0000375', 'AMCOXO', '1.5.1.-...
# 21   dict_values(['SBO:0000375', 'ARGNm', 'META:ARG...
# 22   dict_values(['SBO:0000375', 'ARGSS', 'META:ARG...
# 23   dict_values(['SBO:0000375', 'ASNNm', 'META:ASP...
# 24   dict_values(['SBO:0000375', 'ASNS1', 'META:ASN...
# 25   dict_values(['SBO:0000375', 'ASPCT', 'META:ASP...
# 26   dict_values(['SBO:0000375', 'ASPTAm', ['META:A...
# 27   dict_values(['SBO:0000375', 'ATPtm', '2.7.4.6'...
# 28   dict_values(['SBO:0000375', 'CBPSam', 'META:RX...
# 29   dict_values(['SBO:0000375', 'CHLPCTD', 'META:2...
# ..                                                 ...
# 160  dict_values(['SBO:0000375', 'PRPPS', '2.7.6.1'...
# 161  dict_values(['SBO:0000375', 'PSERT', 'META:PSE...
# 162  dict_values(['SBO:0000375', 'PSP_L', 'META:RXN...
# 163  dict_values(['SBO:0000375', 'RNDR1', 'META:ADP...
# 164  dict_values(['SBO:0000375', 'RNDR2', 'META:GDP...
# 165  dict_values(['SBO:0000375', 'RNDR3', 'META:CDP...
# 166  dict_values(['SBO:0000375', 'RNDR4', 'META:UDP...
# 167  dict_values(['SBO:0000375', 'RPE', 'META:RIBUL...
# 168  dict_values(['SBO:0000375', 'RPI', '5.3.1.6', ...
# 169  dict_values(['SBO:0000375', 'TALA', 'META:TRAN...
# 170  dict_values(['SBO:0000375', 'TKT1', '2.2.1.1',...
# 171  dict_values(['SBO:0000375', 'TKT2', 'META:2TRA...
# 172  dict_values(['SBO:0000375', 'TPI', 'META:TRIOS...
# 173  dict_values(['SBO:0000375', 'UMPK', 'META:RXN-...
# 174  dict_values(['SBO:0000375', 'VALTA', 'META:BRA...
# 175  dict_values(['SBO:0000375', 'ACCOAC', 'META:AC...
# 176  dict_values(['SBO:0000375', 'AICART', '2.1.2.3...
# 177  dict_values(['SBO:0000375', 'ARGSL', 'META:ARG...
# 178  dict_values(['SBO:0000375', 'GLUPRT', 'META:PR...
# 179  dict_values(['SBO:0000375', 'IMPC', 'META:IMPC...
# 180  dict_values(['SBO:0000375', 'LDH_L', 'META:L-L...
# 181  dict_values(['SBO:0000375', 'MDH', 'META:MALAT...
# 182  dict_values(['SBO:0000375', 'MI1PP', 'META:RXN...
# 183  dict_values(['SBO:0000375', 'PFK', '2.7.1.11',...
# 184  dict_values(['SBO:0000375', 'PRFGS', '6.3.5.3'...
# 185  dict_values(['SBO:0000375', 'PYK', 'META:PEPDE...
# 186  dict_values(['SBO:0000375', 'TMDS', '2.1.1.45'...
# 187  dict_values(['SBO:0000375', 'TYRTA', 'META:TYR...
# 188  dict_values(['SBO:0000375', 'AACOAT', 'META:AC...
# 189  dict_values(['SBO:0000375', 'HMGCOARx', '1.1.1...
#
#                                        Full Annotation
# 0    {'SBO': 'SBO:0000375', 'bigg.reaction': '2OXOA...
# 1    {'SBO': 'SBO:0000375', 'bigg.reaction': '34HPP...
# 2    {'SBO': 'SBO:0000375', 'bigg.reaction': '3DSPH...
# 3    {'SBO': 'SBO:0000375', 'bigg.reaction': '3HAO'...
# 4    {'SBO': 'SBO:0000375', 'bigg.reaction': '3HBCO...
# 5    {'SBO': 'SBO:0000375', 'bigg.reaction': 'AASAD...
# 6    {'SBO': 'SBO:0000375', 'bigg.reaction': 'AATA'...
# 7    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACACT...
# 8    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACACT...
# 9    {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACITL...
# 10   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...
# 11   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...
# 12   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACOAD...
# 13   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACONT...
# 14   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADK3'...
# 15   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADSL1...
# 16   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ADSL2...
# 17   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AIRCr...
# 18   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AKGDm...
# 19   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ALATA...
# 20   {'SBO': 'SBO:0000375', 'bigg.reaction': 'AMCOX...
# 21   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGNm...
# 22   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGSS...
# 23   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASNNm...
# 24   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASNS1...
# 25   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASPCT...
# 26   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ASPTA...
# 27   {'SBO': 'SBO:0000375', 'bigg.reaction': 'ATPtm...
# 28   {'SBO': 'SBO:0000375', 'bigg.reaction': 'CBPSa...
# 29   {'SBO': 'SBO:0000375', 'bigg.reaction': 'CHLPC...
# ..                                                 ...
# 160  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PRPPS...
# 161  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PSERT...
# 162  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PSP_L...
# 163  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR1...
# 164  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR2...
# 165  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR3...
# 166  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RNDR4...
# 167  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RPE',...
# 168  {'SBO': 'SBO:0000375', 'bigg.reaction': 'RPI',...
# 169  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TALA'...
# 170  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TKT1'...
# 171  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TKT2'...
# 172  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TPI',...
# 173  {'SBO': 'SBO:0000375', 'bigg.reaction': 'UMPK'...
# 174  {'SBO': 'SBO:0000375', 'bigg.reaction': 'VALTA...
# 175  {'SBO': 'SBO:0000375', 'bigg.reaction': 'ACCOA...
# 176  {'SBO': 'SBO:0000375', 'bigg.reaction': 'AICAR...
# 177  {'SBO': 'SBO:0000375', 'bigg.reaction': 'ARGSL...
# 178  {'SBO': 'SBO:0000375', 'bigg.reaction': 'GLUPR...
# 179  {'SBO': 'SBO:0000375', 'bigg.reaction': 'IMPC'...
# 180  {'SBO': 'SBO:0000375', 'bigg.reaction': 'LDH_L...
# 181  {'SBO': 'SBO:0000375', 'bigg.reaction': 'MDH',...
# 182  {'SBO': 'SBO:0000375', 'bigg.reaction': 'MI1PP...
# 183  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PFK',...
# 184  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PRFGS...
# 185  {'SBO': 'SBO:0000375', 'bigg.reaction': 'PYK',...
# 186  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TMDS'...
# 187  {'SBO': 'SBO:0000375', 'bigg.reaction': 'TYRTA...
# 188  {'SBO': 'SBO:0000375', 'bigg.reaction': 'AACOA...
# 189  {'SBO': 'SBO:0000375', 'bigg.reaction': 'HMGCO...
#
# [190 rows x 13 columns]

# %%
# UPDATE DF_EC so we dont need to run the scrape everytime
writer = pd.ExcelWriter('df_ec.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df_EC.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# # Overview:
#
# ## EC found in kinetic_df were found in df_EC where the location

# %%
#str.contains too strict of a criteria, not matching to lists

df1=df_EC[df_EC["EC_Comp"].str.contains("2.6.1.5", na=False)]

# %%
output=Kinetic_df.EC_Number.apply(match_col)

# %%
for index_kin in range(len(Kinetic_df)):
    ec_kin=Kinetic_df["EC Number"][index_kin]
    for index_ec in range(len(df_EC)):
        ec_df=df_EC["EC_Comp"][index_ec]

# %%
len(Kinetic_df)

# %%
len(Kinetic_df["EC Number"])

# %%
Kinetic_df_dropped["EC Number"]=Kinetic_df_dropped["EC Number"].apply(_strip_lower)

# %%
c1=0
c2=0
n_matches=[]
match_list=[]
RXN_EC=[]
ec_kinetic_list=[]

n_list=[]

for ec_kinetic in Kinetic_df_dropped["EC Number"]:
    ec_kinetic_list.append(ec_kinetic)
    n=0
    
    #print (ec_kinetic)
    for i in range(len(df_EC["ANNOT_EC"])):
        
        
        if type(df_EC["ANNOT_EC"][i])==list:
            for j in df_EC["ANNOT_EC"][i]:
                if ec_kinetic==j: 
                    n_matches.append(j)
                    c1+=1
                    n+=1
                    
        if type(df_EC["ANNOT_EC"][i])==str:
            if ec_kinetic==df_EC["ANNOT_EC"][i]:
                n_matches.append(df_EC["ANNOT_EC"][i])
                c2+=1
                n+=1
    match_list.append(n_matches)
    print (n)
                

print ("Match found in list", c1)
print ("Match found not list", c2)
print (c1+c2, len(Kinetic_df_dropped))

# %%
print (len(ec_kinetic_list))
print (len(match_list))

# %%
df_NEW=pd.DataFrame({"EC_Kinetic": ec_kinetic_list, "EC_scrape": match_list})
df_NEW

# %%
EC_scrape=[]
EC_model=[]
RXN_ID=[]
RXN_STRING=[]
ANNOT_BIGG=[]

c=0
for EC_kinetic in Kinetic_df_dropped["EC Number"]: 
    for i in range(len(df_EC["ANNOT_EC"])):
        Annot_ec=df_EC["ANNOT_EC"][i]
        if type(Annot_ec)==list:
            if EC_kinetic in Annot_ec: 
                c+=1
                EC_scrape.append(EC_kinetic)
                EC_model.append(Annot_ec)
                RXN_ID.append(df_EC["rxn_id"][i])
                RXN_STRING.append(df_EC["rxn_string"][i])
                ANNOT_BIGG.append(df_EC["ANNOT_BIGG"][i])
        elif type(Annot_ec)==str: 
            if str(EC_kinetic) ==str(Annot_ec):
                c+=1
                EC_scrape.append(EC_kinetic)
                EC_model.append(Annot_ec)
                RXN_ID.append(df_EC["rxn_id"][i])
                RXN_STRING.append(df_EC["rxn_string"][i])
                ANNOT_BIGG.append(df_EC["ANNOT_BIGG"][i])
                
            
print (c)

# %%
df=pd.DataFrame({"Scrape_EC": EC_scrape, "Model_ECs": EC_model, "Rxn_id": RXN_ID,
                 "Rxn_string": RXN_STRING , "Bigg_Annot": ANNOT_BIGG})

# %%
df_NEW=pd.DataFrame({"EC_Kinetic": EC_kinetic, "EC_scrape": EC_model, "RXN_ID": RXN_ID,
                     "RXN_string": RXN_STRING, "ANNOT_BIGG": ANNOT_BIGG})
df_NEW

# %%
writer = pd.ExcelWriter('KINETIC_DATASET_FINAL(EC_matched)', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
Kinetic_df_dropped.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# # Appendix

# %%
# OLD FUNCTION


def match_col(df_EC,):
    output_EC_all_matches=[]
    for i in range(len(df_EC)):
        match_list=[]
        if type(df_EC["ANNOT_EC"][i])==list:
            for j in range(len(df_EC["ANNOT_EC"][i])):
                if ec_kinetic== df_EC["ANNOT_EC"][i][j]:
                    print ("LIST: ", ec_kinetic,  df_EC["ANNOT_EC"][i][j])
                    match_list.append([i,j])
            
        if type(df_EC["ANNOT_EC"][i])==str:
            if ec_kinetic==df_EC["ANNOT_EC"][i]:
                print ("STR: ", ec_kinetic,  df_EC["ANNOT_EC"][i])
                match_list.append([i])
    output_EC_all_matches.append(match_list)
            
    return output_EC_all_matches
###

# %%
#str.contains too strict of a criteria, not matching to lists

df1=df_EC[df_EC["EC_Comp"].str.contains("2.6.1.5", na=False)]

# %%
# OLD FUNCTION


def match_col(df_EC,):
    output_EC_all_matches=[]
    for i in range(len(df_EC)):
        match_list=[]
        if type(df_EC["ANNOT_EC"][i])==list:
            for j in range(len(df_EC["ANNOT_EC"][i])):
                if ec_kinetic== df_EC["ANNOT_EC"][i][j]:
                    print ("LIST: ", ec_kinetic,  df_EC["ANNOT_EC"][i][j])
                    match_list.append([i,j])
            
        if type(df_EC["ANNOT_EC"][i])==str:
            if ec_kinetic==df_EC["ANNOT_EC"][i]:
                print ("STR: ", ec_kinetic,  df_EC["ANNOT_EC"][i])
                match_list.append([i])
    output_EC_all_matches.append(match_list)
            
    return output_EC_all_matches
###
